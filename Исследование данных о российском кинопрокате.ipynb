# %% [markdown]
# .

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Исследование данных о российском кинопрокате

# %% [markdown]
# **_Заказчик этого исследования — `Министерство культуры Российской Федерации`.<br>
# Необходимо `изучить рынок российского кинопроката` и `выявить текущие тренды`.<br><br>
# Особое внимание фильмам, которые получили государственную поддержку.<br><br>
# ` ` На сколько такие фильмы интересны зрителю?<br>
# ` ` Сколько фильмов выходило в прокат каждый год?<br>
# ` ` Менялась ли динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?<br>
# ` ` Влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год?<br>
# ` ` Фильмы с каким возрастным ограничением собрали больше всего денег в прокате?_**

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг.-Откройте-файлы-с-данными-и-объедините-их-в-один-датафрейм." data-toc-modified-id="Шаг.-Откройте-файлы-с-данными-и-объедините-их-в-один-датафрейм.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг. Откройте файлы с данными и объедините их в один датафрейм.</a></span><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Структура-и-типы-данных-в-колонках" data-toc-modified-id="Структура-и-типы-данных-в-колонках-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Структура и типы данных в колонках</a></span></li><li><span><a href="#Объединение-таблиц" data-toc-modified-id="Объединение-таблиц-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Объединение таблиц</a></span></li><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li><li><span><a href="#Шаг-1.-Вывод" data-toc-modified-id="Шаг-1.-Вывод-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Шаг 1. Вывод</a></span></li><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li></ul></li><li><span><a href="#Шаг.-Предобработка-данных" data-toc-modified-id="Шаг.-Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг. Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Шаг.-Проверьте-типы-данных" data-toc-modified-id="Шаг.-Проверьте-типы-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Шаг. Проверьте типы данных</a></span><ul class="toc-item"><li><span><a href="#Столбец-puNumber" data-toc-modified-id="Столбец-puNumber-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Столбец puNumber</a></span></li><li><span><a href="#Столбец-box_office" data-toc-modified-id="Столбец-box_office-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Столбец box_office</a></span></li><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li><li><span><a href="#Столбец-show_start_date" data-toc-modified-id="Столбец-show_start_date-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Столбец show_start_date</a></span></li><li><span><a href="#Столбец-film_studio" data-toc-modified-id="Столбец-film_studio-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Столбец film_studio</a></span></li><li><span><a href="#Столбец-production_country" data-toc-modified-id="Столбец-production_country-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Столбец production_country</a></span></li><li><span><a href="#Столбец-director" data-toc-modified-id="Столбец-director-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>Столбец director</a></span></li><li><span><a href="#Столбец-producer" data-toc-modified-id="Столбец-producer-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>Столбец producer</a></span></li><li><span><a href="#Столбец-refundable_support" data-toc-modified-id="Столбец-refundable_support-2.1.9"><span class="toc-item-num">2.1.9&nbsp;&nbsp;</span>Столбец refundable_support</a></span></li><li><span><a href="#Столбец-nonrefundable_support" data-toc-modified-id="Столбец-nonrefundable_support-2.1.10"><span class="toc-item-num">2.1.10&nbsp;&nbsp;</span>Столбец nonrefundable_support</a></span></li><li><span><a href="#Столбец-budget" data-toc-modified-id="Столбец-budget-2.1.11"><span class="toc-item-num">2.1.11&nbsp;&nbsp;</span>Столбец budget</a></span></li><li><span><a href="#Столбец-financing_source" data-toc-modified-id="Столбец-financing_source-2.1.12"><span class="toc-item-num">2.1.12&nbsp;&nbsp;</span>Столбец financing_source</a></span></li><li><span><a href="#Столбец-ratings" data-toc-modified-id="Столбец-ratings-2.1.13"><span class="toc-item-num">2.1.13&nbsp;&nbsp;</span>Столбец ratings</a></span></li><li><span><a href="#Столбец-genres" data-toc-modified-id="Столбец-genres-2.1.14"><span class="toc-item-num">2.1.14&nbsp;&nbsp;</span>Столбец genres</a></span></li><li><span><a href="#Удалим-вспомогательные-столбцы" data-toc-modified-id="Удалим-вспомогательные-столбцы-2.1.15"><span class="toc-item-num">2.1.15&nbsp;&nbsp;</span>Удалим вспомогательные столбцы</a></span></li><li><span><a href="#Данные.-Вывод" data-toc-modified-id="Данные.-Вывод-2.1.16"><span class="toc-item-num">2.1.16&nbsp;&nbsp;</span>Данные. Вывод</a></span></li><li><span><a href="#Проанализируем-пропуски" data-toc-modified-id="Проанализируем-пропуски-2.1.17"><span class="toc-item-num">2.1.17&nbsp;&nbsp;</span>Проанализируем пропуски</a></span></li><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---2.1.18"><span class="toc-item-num">2.1.18&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li></ul></li><li><span><a href="#Шаг.-Изучите-дубликаты-в-датафрейме" data-toc-modified-id="Шаг.-Изучите-дубликаты-в-датафрейме-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Шаг. Изучите дубликаты в датафрейме</a></span><ul class="toc-item"><li><span><a href="#Дубликаты-номера-прокатного-удостоверения" data-toc-modified-id="Дубликаты-номера-прокатного-удостоверения-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Дубликаты номера прокатного удостоверения</a></span></li><li><span><a href="#Полные-дубликаты" data-toc-modified-id="Полные-дубликаты-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Полные дубликаты</a></span></li><li><span><a href="#Неявные-дубликаты" data-toc-modified-id="Неявные-дубликаты-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Неявные дубликаты</a></span></li><li><span><a href="#Вывод-по-дубликатам" data-toc-modified-id="Вывод-по-дубликатам-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Вывод по дубликатам</a></span></li><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li></ul></li><li><span><a href="#Шаг.-Изучите-категориальные-значения" data-toc-modified-id="Шаг.-Изучите-категориальные-значения-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Шаг. Изучите категориальные значения</a></span><ul class="toc-item"><li><span><a href="#Категория---Тип-Фильма" data-toc-modified-id="Категория---Тип-Фильма-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Категория - Тип Фильма</a></span></li><li><span><a href="#Категория---Возрастная-категория" data-toc-modified-id="Категория---Возрастная-категория-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Категория - Возрастная категория</a></span></li><li><span><a href="#Категория---Жанр-Фильма" data-toc-modified-id="Категория---Жанр-Фильма-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Категория - Жанр Фильма</a></span></li><li><span><a href="#Вывод-по-столбцам-категорий" data-toc-modified-id="Вывод-по-столбцам-категорий-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Вывод по столбцам категорий</a></span></li><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li></ul></li><li><span><a href="#Шаг.-Проверьте-количественные-значения" data-toc-modified-id="Шаг.-Проверьте-количественные-значения-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Шаг. Проверьте количественные значения</a></span><ul class="toc-item"><li><span><a href="#Столбец-refundable_support" data-toc-modified-id="Столбец-refundable_support-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Столбец refundable_support</a></span></li><li><span><a href="#Столбец-nonrefundable_support" data-toc-modified-id="Столбец-nonrefundable_support-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Столбец nonrefundable_support</a></span></li><li><span><a href="#Столбец-budget" data-toc-modified-id="Столбец-budget-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Столбец budget</a></span></li><li><span><a href="#Столбец-box_office" data-toc-modified-id="Столбец-box_office-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Столбец box_office</a></span></li><li><span><a href="#Столбец-ratings" data-toc-modified-id="Столбец-ratings-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Столбец ratings</a></span></li><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---2.4.6"><span class="toc-item-num">2.4.6&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li></ul></li><li><span><a href="#Шаг.-Добавьте-новые-столбцы" data-toc-modified-id="Шаг.-Добавьте-новые-столбцы-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Шаг. Добавьте новые столбцы</a></span><ul class="toc-item"><li><span><a href="#Столбец-show_start_year" data-toc-modified-id="Столбец-show_start_year-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Столбец show_start_year</a></span></li><li><span><a href="#Столбцы-show_start_year-и-main_genres" data-toc-modified-id="Столбцы-show_start_year-и-main_genres-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Столбцы show_start_year и main_genres</a></span></li><li><span><a href="#Доля-государственной-поддержки-от-общего-бюджета-фильма" data-toc-modified-id="Доля-государственной-поддержки-от-общего-бюджета-фильма-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Доля государственной поддержки от общего бюджета фильма</a></span></li><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li></ul></li></ul></li><li><span><a href="#Шаг.-Проведите-исследовательский-анализ-данных" data-toc-modified-id="Шаг.-Проведите-исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг. Проведите исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Количество-фильмов-в-прокате-по-годам" data-toc-modified-id="Количество-фильмов-в-прокате-по-годам-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Количество фильмов в прокате по годам</a></span><ul class="toc-item"><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li><li><span><a href="#--ИСПРАВЛЕНО2--" data-toc-modified-id="--ИСПРАВЛЕНО2---3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>--ИСПРАВЛЕНО2--</a></span></li><li><span><a href="#Средняя-и-медианная-сумму-сборов-для-каждого-года" data-toc-modified-id="Средняя-и-медианная-сумму-сборов-для-каждого-года-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Средняя и медианная сумму сборов для каждого года</a></span></li><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li><li><span><a href="#Суммы-сборов-по-годам-и-возрастному-ограничению" data-toc-modified-id="Суммы-сборов-по-годам-и-возрастному-ограничению-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Суммы сборов по годам и возрастному ограничению</a></span></li><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li><li><span><a href="#--ИСПРАВЛЕНО2--" data-toc-modified-id="--ИСПРАВЛЕНО2---3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span>--ИСПРАВЛЕНО2--</a></span></li></ul></li></ul></li><li><span><a href="#Шаг.-Исследуйте-фильмы,-которые-получили-государственную-поддержку" data-toc-modified-id="Шаг.-Исследуйте-фильмы,-которые-получили-государственную-поддержку-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг. Исследуйте фильмы, которые получили государственную поддержку</a></span><ul class="toc-item"><li><span><a href="#Анализ-фильмов-с-гос-поддержкой" data-toc-modified-id="Анализ-фильмов-с-гос-поддержкой-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ фильмов с гос поддержкой</a></span><ul class="toc-item"><li><span><a href="#--ИСПРАВЛЕНО--" data-toc-modified-id="--ИСПРАВЛЕНО---4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>--ИСПРАВЛЕНО--</a></span></li></ul></li></ul></li><li><span><a href="#Шаг.-Напишите-общий-вывод" data-toc-modified-id="Шаг.-Напишите-общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг. Напишите общий вывод</a></span></li></ul></div>

# %%
def path_remover(path=''):
    import sys
    for el in sys.path:
        if el == path:
            sys.path.remove(path)
            
class Formatter(object):
    def __init__(self):
        self.types = {}
        self.htchar = '\t'
        self.lfchar = '\n'
        self.indent = 0
        self.set_formater(object, self.__class__.format_object)
        self.set_formater(dict, self.__class__.format_dict)
        self.set_formater(list, self.__class__.format_list)
        self.set_formater(tuple, self.__class__.format_tuple)

    def set_formater(self, obj, callback):
        self.types[obj] = callback

    def __call__(self, value, **args):
        for key in args:
            setattr(self, key, args[key])
        formater = self.types[type(value) if type(value) in self.types else object]
        return formater(self, value, self.indent)

    def format_object(self, value, indent):
        if 'DataFrame' in str(type(value)):
            return str(type(value))
        else:
            return repr(value)

    def format_dict(self, value, indent):
        items = [
            self.lfchar + self.htchar * (indent + 1) + repr(key) + ': ' +
            (self.types[type(value[key]) if type(value[key]) in self.types else object])(self, value[key], indent + 1)
            for key in value
        ]
        return '{%s}' % (','.join(items) + self.lfchar + self.htchar * indent)

    def format_list(self, value, indent):
        items = [
            self.lfchar + self.htchar * (indent + 1) + (self.types[type(item) if type(item) in self.types else object])(self, item, indent + 1)
            for item in value
        ]
        return '[%s]' % (','.join(items) + self.lfchar + self.htchar * indent)

    def format_tuple(self, value, indent):
        items = [
            self.lfchar + self.htchar * (indent + 1) + (self.types[type(item) if type(item) in self.types else object])(self, item, indent + 1)
            for item in value
        ]
        return '(%s)' % (','.join(items) + self.lfchar + self.htchar * indent)
        
        
def msgbox(msg, title='Внимание!',  msgtype='success', btn='Ok'):
    from IPython.display import HTML,Javascript, display
    
    if msgtype.upper() in ['ERROR', 'CRITICAL', 'DANGER']:
        msgtype = 'danger'
    
    style = HTML("""
        <style>
            .alert {
                margin: -10px;
            }
        </style>
    """)
    
    display(style)
    
    msg = '$("<p></p>").addClass("alert alert-' + msgtype + '").append("' + str(msg) + '")'
    
    body_msg = Javascript("""
        let m = require(
            ["base/js/dialog"], 
            function(dialog) {
                dialog.modal({
                    title: '""" + title + """',
                    body: """ + msg + """,
                    buttons: {
                        '""" + btn + """': {}},
                });
            }
            
        );
    """)
    display(body_msg)
    
    
def sum_rnd(summ, count, list_digit=None):
    from random import randrange
    
    summ_list = []
    
    for idx in range(count):
        summ_list.append(0)

        if (idx == 0 and idx != count-1):
            if list_digit:
                a = True
                rnd = 0
                while a == True:
                    rnd = randrange(summ-1)
                    if rnd in list(list_digit):
                        a = False
                summ_list[idx] = rnd
            else:
                summ_list[idx] = randrange(summ-1)
        elif (idx != 0 and idx == count-1):
            summ_list[idx] = summ - (sum(summ_list))
        else:
            if list_digit:
                a = True
                rnd = 0
                while a == True:
                    rnd = randrange(summ-summ_list[idx-1])
                    if rnd in list(list_digit):
                        a = False
                summ_list[idx] = rnd
            else:
                summ_list[idx] = randrange(summ-summ_list[idx-1])
    
    return summ_list

##########
#Function var_name

def get_caller_params():
    import re, inspect, ast
    # get the frame object for this function call
    thisframe = inspect.currentframe()

    # get the parent calling frames details
    frames = inspect.getouterframes(thisframe)

    # frame 0 is the frame of this function
    # frame 1 is the frame of the caller function (the one we want to inspect)
    # frame 2 is the frame of the code that calls the caller
    caller_function_name = frames[1][3]
    
    
    if 'var_name' in ''.join(inspect.findsource(frames[2][0])[0]):
        code_that_calls_caller = inspect.findsource(frames[2][0])[0]
    else:
        code_that_calls_caller = inspect.findsource(frames[3][0])[0]
    #code_that_calls_caller = inspect.findsource(frames[2][0])[0]
    
    
    print(code_that_calls_caller)
    # parse code to get nodes of abstract syntact tree of the call
    nodes = ast.parse(''.join(code_that_calls_caller))
    
    
    # find the node that calls the function
    i_expr = -1
    for (i, node) in enumerate(nodes.body):
        if _node_is_our_function_call(node, caller_function_name):
            i_expr = i
            break

    # line with the call start
    idx_start = nodes.body[i_expr].lineno - 1

    # line with the end of the call
    if i_expr < len(nodes.body) - 1:
        # next expression marks the end of the call
        idx_end = nodes.body[i_expr + 1].lineno - 1
    else:
        # end of the source marks the end of the call
        idx_end = len(code_that_calls_caller)

    call_lines = code_that_calls_caller[idx_start:idx_end]
    str_func_call = ''.join([line.strip() for line in call_lines])
    str_call_params = str_func_call[str_func_call.find('(') + 1:-1]
    params = [p.strip() for p in str_call_params.split(',')]

    return params


def _node_is_our_function_call(node, our_function_name):
    import re, inspect, ast
    node_is_call = hasattr(node, 'value') and isinstance(node.value, ast.Call)
    if not node_is_call:
        return False
    function_name_correct = hasattr(node.value.func, 'id') and node.value.func.id == our_function_name
    return function_name_correct

def var_name(*par_values):
    import os
    result = []
    par_names = get_caller_params()
    
    for name, val in zip(par_names, par_values):
        result.append("Variable name: '" + str(name) + "'; " + "Variable type: " + str(type(val)))
    return ' | '.join(result)

def color_nan_red(val, marker=None, table=None):

    general_style = 'font-weight:bold;text-transform: capitalize;'
    
    nan_class    = general_style + 'color: red;'
    unknow_class = general_style + 'color: #9c27b0;'
    value_class  = ''
    
    max_class    = general_style + 'color: #ff6f00;'
    min_class    = general_style + 'color: #0d64a1;'
    
    classes_list = []
    
    for i, cell in enumerate(val):
        if marker:
            if i in marker.keys():
                
                
                if ('str' in str(type(marker[i])) and 'str' in str(type(cell))):
                    if cell == marker[i]:
                        classes_list.append(nan_class)
                        continue
                elif 'list' in str(type(marker[i])):
                    if marker[i][0] == 'min' and cell == marker[i][1]:
                        classes_list.append(min_class)
                        continue
                    elif marker[i][0] == 'max' and cell == marker[i][1]:
                        classes_list.append(max_class)
                        continue
                    elif marker[i][0] == 'max_min' and cell in marker[i]:
                        if 'str' not in str(type(cell)):
                            if cell == min(item for item in marker[i][1:] if 'str' not in str(type(item))):
                                classes_list.append(min_class)
                                continue
                            elif cell == max(item for item in marker[i][1:] if 'str' not in str(type(item))):
                                classes_list.append(max_class)
                                continue
                        elif 'str' in str(type(cell)):
                            if cell == min(item for item in marker[i][1:] if 'str' in str(type(item))):
                                classes_list.append(min_class)
                                continue
                            elif cell == max(item for item in marker[i][1:] if 'str' in str(type(item))):
                                classes_list.append(max_class)
                                continue
                    elif cell in marker[i]:
                        if 'str' not in str(type(cell)):
                            if cell == min(item for item in marker[i] if 'str' not in str(type(item))):
                                classes_list.append(min_class)
                                continue
                            elif cell == max(item for item in marker[i] if 'str' not in str(type(item))):
                                classes_list.append(max_class)
                                continue
                            else:
                                classes_list.append(unknow_class)
                                continue
                        elif 'str' in str(type(cell)):
                            if cell == min(item for item in marker[i] if 'str' in str(type(item))):
                                classes_list.append(min_class)
                                continue
                            elif cell == max(item for item in marker[i] if 'str' in str(type(item))):
                                classes_list.append(max_class)
                                continue
                            else:
                                classes_list.append(unknow_class)
                                continue            
                    elif marker[i][0] == '>':
                        if 'list' in str(type(marker[i][1])):
                            if all(cell > j for j in marker[i][1]):
                                classes_list.append(nan_class)
                                continue
                        else:    
                            if cell > marker[i][1]:
                                classes_list.append(nan_class)
                                continue
                    elif marker[i][0] == '<':
                        if 'list' in str(type(marker[i][1])):
                            if all(cell < j for j in marker[i][1]):
                                classes_list.append(min_class)
                                continue
                        else:    
                            if cell < marker[i][1]:
                                classes_list.append(min_class)
                                continue
                    elif marker[i][0] == '=':
                        if cell == marker[i][1]:
                            classes_list.append(unknow_class)
                            continue
                        if cell in marker[i][1]:
                            classes_list.append(unknow_class)
                            continue
                    elif marker[i][0] == 'top':
                        if cell in list(table.iloc[:, i].head(marker[i][1])):
                            classes_list.append(unknow_class)
                            continue
                    elif marker[i][0] == 'out':
                        if cell in list(table.iloc[:, i].tail(marker[i][1])):
                            classes_list.append(unknow_class)
                            continue
                    
                                
                elif ('str' not in str(type(marker[i])) and 'str' not in str(type(cell))) and  cell >= marker[i]:
                    classes_list.append(nan_class)
                    continue 
        
        if pd.isna(cell):
            classes_list.append(nan_class)
            continue
        elif cell == 'unknown':
            classes_list.append(unknow_class)
            continue
        
        classes_list.append(value_class)
        continue
        
    return classes_list
    
def color_sea_war(val):
    return ['color: white;text-align:center !important;' if v == 0 else 'color: rgba(0, 0, 0, 0);background: rgba(0, 78, 145, 0.8);text-align:center !important;'
                for v in val]

def set_format(*args):
    print(args)
    
    for i, idx in enumerate(args[0]):
        print(i, ":", idx)
        
    if 'str' in str(type(args[1])):
        if 'float' in str(type(args[0])):
            return args[1].format(args[0])
        else:
            return args[0]
    elif 'list' in str(type(args[1])):
        if args[1][0] == 'datetime':
            return datetime.strptime(args[0], args[1][1]).strftime(args[1][2])
        elif args[1][0] == 'float':
            print(args[1][1],':', args[0])
            return args[1][1].format(args[0])
          
    return args[0]

def check_float(val,format='default'):
    if 'float' in str(type(val)):
        if format == 'default':
            return val
        else:
            return format.format(val)
    else:
        return val
    
def render(*args, format='default', border='false', position='center_header', marker=None, name='', width='', vartype=False):
    '''
    format   = {:.2f} Заменяет все float числа в формат
    format   = [ [[column_list], [type_format, value_format]] ] - применяет указанный формат к указанным столбцам.
    
        примеры:
        format=[ [['column_1','column_2'], '{:.2f}'] ]
        format=[ [['column_1','column_2'], ['float', '{:.2f}']] ]
        format=[ [['column_1','column_2'], ['datetime', '%Y%m%dT%H%M%S', '%d.%m.%Y %H:%M:%S']] ]
        format=[ [['column_1','column_2'], '<b style="color:red">{}</b>'] ] - применяем стиль к значению
    
    format   = 'json' - преобразовывает в json формат
    
    border   = display(d) | horizont(h) | vertical(v)
    
    position = left | center | right | left_header | center_header | right_header
    
    marker   = [['column_name', value]] все значения >=  value будут помечены красным цветом
    
    marker   = [['column_name', 'max_min']] будут отмечены максимальное и минимальное значение цветом
    marker   = [['column_name', 'min']]
    marker   = [['column_name', 'max']]
    
    marker   = [['column_name', ['>', 1000]]]
    marker   = [['column_name', ['<', 'value']]]
    
    name     = 'Test title'  Добавляет описание к таблице
    
    width    = auto | 100% | 300 | 600 | 900 Делает ширину таблицы, указаного значения
    
    type     = True Выводит имя переменной и его тип
    '''
    
    
    
    border_style   = ''
    position_style = ''
    
    title          = ''
    width_value    = ''
    type_value     = ''
    
    if name != '':
        title = ' data-title="' + name + '" '
        
    if width != '':
        width_value = ' data-width="' + width + '" '
    
    if vartype == True:
        type_value = ' data-type="[template]" '
    
    if border == 'display' or border == 'd':
        border_style = ' border_display'
    elif border == 'horizont' or border == 'h':
        border_style = ' border_horizont'
    elif border == 'vertical' or border == 'v':
        border_style = ' border_vertical'
    else:
        border_style = ''
    
    
    if position == 'left':
        position_style = ' position_left'
    elif position == 'center':
        position_style = ' position_center'
    elif position == 'right':
        position_style = ' position_right'
    elif position == 'left_header':
        position_style = ' position_left_header'
    elif position == 'center_header':
        position_style = ' position_center_header'
    elif position == 'right_header':
        position_style = ' position_right_header'
    else:
        position_style = ''
    
    
    
    if 'Series' in str(type(args[0])) or 'DataFrame' in str(type(args[0])): 
        df = args[0]
    else:
        df = args
    
    if 'Series' in str(type(df)): df = df.to_frame()
    
    if 'Series' in str(type(df)) or 'DataFrame' in str(type(df)):
        
        render_df = df.copy()
        
        
        
        if len(render_df.index) == 0:
            render_df.loc[render_df.shape[0]] = ''
        
        
        
        columns = render_df.columns
        need_columns = {}
        
        if marker:
            for need_clmn in marker:
                for i, clmn in enumerate(columns):
                    if need_clmn[0] == clmn:
                        if need_clmn[1] in ['min', 'max', 'max_min']:
                            if need_clmn[1] == 'min':
                                need_columns[i] = ['min', df[clmn].min()]
                            elif need_clmn[1] == 'max':
                                need_columns[i] = ['max', df[clmn].max()]
                            elif need_clmn[1] == 'max_min':
                                need_columns[i] = ['max_min', df[clmn].min(), df[clmn].max()]
                        else:
                            need_columns[i] = need_clmn[1]

        if vartype == True:
            type_value = type_value.replace("[template]", var_name(render_df))
            print(render_df, var_name(render_df))   
        
        #Render Style
        render_df = render_df.style.set_table_attributes('class="table_border' + border_style + position_style + '"' + title + width_value + type_value).apply(color_nan_red,marker=need_columns,table=df, axis=1)
        
        #print(str(type(render_df))) 
        
        #render_df.format(escape='html')
        
 
        if format != 'default':
            if 'str' in str(type(format)):
                render_df = render_df.format(lambda x: format.format(x) if 'float' in str(type(x)) else x )
            elif 'list' in str(type(format)):
                need_columns = {}
                for list_format in format:

                    s_type = None
                    s_type = list_format[1]
                    
                    for clmns_list in list_format[0]:
                        if 'str' in str(type(s_type)):
                            need_columns[clmns_list] = str_format(s_type)
                            continue
                        elif 'list' in str(type(s_type)):

                            if s_type[0] == 'float':
                                need_columns[clmns_list] = float_format(s_type[1])
                                continue
                            
                            elif s_type[0] == 'datetime':
                                need_columns[clmns_list] = time_format(s_type[1], s_type[2])
                                continue
                            
                            elif s_type[0] == 'link':
                                need_columns[clmns_list] = link_format(s_type[1])
                                continue
                            
                            else:
                                continue
                
                #print(need_columns)
                render_df = render_df.format(formatter=need_columns)
                                                
    else: 
        list_args = []
        
        for value in df: 
            #Render float format
            if format != 'default':
                if format == 'json':
                    pretty = Formatter()
                    list_args.append(pretty(value))
                else:
                    list_args.append(str(check_float(value,format)))
            else:
                list_args.append(str(value))
        
        render_df = ' '.join(list_args).replace('<', '&#60;').replace('>', '&#62;')
        
        if vartype == True:
            type_value = type_value.replace("[template]", var_name(render_df))
            print(df, var_name(df))
            
        from IPython.display import HTML
        render_df = HTML('<p class="value" ' + title + type_value + '><code>' + str(render_df) + '</code></p>')
        
        
    return display(render_df)


def import_style(width_page=-1):
    import os
    
    file_path = os.path.join(os.path.abspath(os.curdir), 'Settings', 'style.css')
    #print(file_path)

    #print(True)
    #open text file in read mode
    text_file = open(file_path, "r")

    #read whole file to a string
    data = text_file.read()

    #close file
    text_file.close()
    
    if width_page != -1:
        data = data.replace('/*#notebook-container', '#notebook-container').replace('[width]', str(width_page) + 'px').replace('width*/', '')
    
    from IPython.core.display import HTML
    style = HTML("""
        <style>
            .table_border[data-width='auto'],
            .table_border[data-width='auto'] thead,
            .table_border[data-width='auto'] tbody
            {width:auto;}
            
            .table_border[data-width='100%'],
            .table_border[data-width='100%'] thead,
            .table_border[data-width='100%'] tbody
            {width:100%;}
            
            .table_border[data-width='300']
            {width:300px;}
            .table_border[data-width='300'] thead,
            .table_border[data-width='300'] tbody
            {width:285px;}
            
            .table_border[data-width='600']
            {width:600px;}
            .table_border[data-width='600'] thead,
            .table_border[data-width='600'] tbody
            {width:585px;}
            
            .table_border[data-width='900']
            {width:900px;}
            .table_border[data-width='900'] thead,
            .table_border[data-width='900'] tbody
            {width:885px;}
            
            .table_border[data-width]
            {display: inline-grid;}
            .table_border[data-width] thead,
            .table_border[data-width] tbody
            {display: inline-table;}
        </style>
    """)
    display(style)
    return data
    
def testik(a='Test'):
    print(a)


def str_format(y):
    return lambda x: y.format(x)
    
def float_format(y):
    return lambda x: y.format(x)

def link_format(y):
    if y != '':
        return lambda x: '<a href="{}" title="{}">{}</a>'.format(x, y, y)
    else:
        return lambda x: '<a href="{}" title="{}">{}</a>'.format(x, x, x)
    
def time_format(y, z):
    if y == '':
        y = '%Y%m%dT%H%M%S'
    if z == '':
        z = '%d.%m.%Y %H:%M:%S'
    return lambda x: datetime.strptime(x, y).strftime(z)

# %% [markdown]
# .

# %%
# %%HTML
# <style>
#
#     a.bkmk_link {
#         text-decoration: none !important;
#     }
#
#     a.bkmk_link:hover em strong,
#     a.bkmk_link:hover strong em
#     {
#         background: none;
#         transition: background-color 1000ms linear;
#         border: 1px solid rgba(0, 0, 0, 0.1);
#         box-shadow: inset 1px 3px 6px 0px rgba(0, 0, 0, 0.1);
#     }
#
#     div.ow_fl {
#         overflow: auto;
#     }
#
#     div.ow_fl p {
#         display:flex;
#     }
#
#     .rendered_html :link {
#         text-decoration: none;
#     }
#
#     a:hover, a:focus {
#         color: #1a466c;
#         text-decoration: underline;
#     }
#
#     #notebook-container {
#         /*width: 1700px;*/
#     }
#
#     #notebook-container .cell:nth-child(6),
#     #notebook-container .cell:nth-child(8)
#     {
#         display: none;
#     }
#
#
#     table {float: left;}
#     table td, table th, table tr {
#         text-align:left !important;
#     }
#
#     .menu_table thead,
#     .menu_table tbody,
#     .menu_table tr
#     {
#         border: none !important;
#         background: none !important;
#         cursor: default;
#     }
#
#     .menu_table thead {
#         display: none;
#     }
#
#     .clearfix {
#         clear: both;
#     }
#
#
#     /*----BLOCKS-------------*/
#
#     .rendered_html em del
#     {
#         text-decoration: none;
#         border: 1px solid gray;
#         border-radius: 10px;
#         padding: 2px;
#         background: bisque;
#         box-shadow: 1px 1px 3px grey;
#         font-style: italic;
#         font-weight: bold;
#         color: brown;
#         line-height: 30px;
#     }
#
#     .rendered_html del {
#         text-decoration: none !important;
#     }
#
#
#     .rendered_html strong em,
#     .rendered_html em strong
#     {
#
#         display: block;
#         border-radius: 5px;
#         padding: 15px;
#         font-style: normal !important;
#         text-decoration: none;
#         transition: background-color 300ms linear;
#     }
#
#     .rendered_html strong em
#     {
#         background: rgba(66, 165, 245, 0.2);
#         color: rgba(0, 0, 0, 0.8);
#         font-weight: normal;
#     }
#
#     .rendered_html em strong
#     {
#         background: rgba(232, 245, 233, 1);
#         color: rgba(0, 0, 0, 0.8);
#         font-weight: normal;
#     }
#
#     .rendered_html strong em code,
#     .rendered_html em strong code
#     {
#         background: white;
#         border-radius: 4px;
#         padding: 2px !important;
#     }
#
#
#     /*-----TABLE---------*/
#
#     .table_border {
#         border-radius: 10px;
#         border: 1px solid #ccc !important;
#         margin: 5px;
#         margin-top: 40px !important;
#         padding: 5px;
#         display: inline-block;
#         cursor: default;
#         box-shadow: 5px 4px 5px 1px rgba(0, 0, 0, 0.07);
#     }
#
#     .table_border:before,
#     p.value:before
#     {
#         content: attr(data-title);
#         position: absolute;
#         display: block;
#         margin-block: auto;
#         margin-top: -25px;
#         /*color: rgb(0 0 0 / 30%);*/
#         color: #4caf50;
#         font-size: 10px;
#     }
#
#     p:before
#     {
#         margin-top: -15px !important;
#     }
#
#     p.value
#     {
#         padding-top: 40px;
#     }
#
#     .table_border thead,
#     .table_border thead tr,
#     .table_border thead th {
#         color: #03a9f4;
#         vertical-align: middle;
#     }
#
#
#     .table_border thead tr
#     {
#         background: rgba(66, 165, 245, 0.2) !important;
#         border-bottom: 1px solid #b2ebf2 !important;
#         padding: 1px;
#     }
#
#     .table_border tbody td:hover
#     {
#         font-weight: bold;
#         color: #03a9f4;
#     }
#
#     .table_border thead tr:first-child th:first-child {
#         border-radius: 10px 0px 0px 0px;
#     }
#
#     .table_border thead tr:first-child th:last-child {
#         border-radius: 0px 10px 0px 0px;
#     }
#
#     .table_border tbody tr:last-child:hover
#     {
#         border-radius: 0px 0px 10px 10px;
#         padding: 0px;
#     }
#
#     .table_border tbody tr:last-child:hover th,
#     .table_border tbody tr:last-child:hover td {
#         background: antiquewhite !important;
#     }
#
#     .table_border tbody tr:hover,
#     .table_border tbody tr:hover th,
#     .table_border tbody tr:hover td,
#     .table_border tbody tr:hover > th,
#     .table_border tbody td.active
#     {
#         background: rgba(66, 165, 245, 0.2) !important;
#     }
#
#     .table_border tbody tr:last-child:hover th,
#     .table_border tbody tr:last-child:hover td:first-child {
#         border-radius: 0px 0px 0px 10px;
#         display: table-cell;
#     }
#
#     .table_border tbody tr:last-child:hover td:last-child {
#         border-radius: 0px 0px 10px 0px;
#         display: table-cell;
#     }
#
#     .table_border tbody tr,
#     .table_border tbody th,
#     .table_border tbody td
#     {
#         background: white;
#     }
#
#     .table_border tbody td {
#         min-width: 120px;
#     }
#
#     .table_border tbody tr .row_heading {
#         color: rgba(0,0,0,0.2)
#     }
#
#     .table_border td.table_border_td_nan {
#         font-weight: bold;
#         text-transform: capitalize;
#         color: red;
#     }
#
#     .table_border tbody tr:hover .row_heading {
#         color: #1565c0;
#     }
#
#     /*
#     ++++++++++++++++++++++
#     .table_border {
#         border-radius: 13px;
#         border: 1px solid #ccc !important;
#         margin: 5px;
#         padding: 5px;
#         display: inline-block;
#         cursor: default;
#         box-shadow: 5px 4px 5px 1px rgba(0, 0, 0, 0.07);
#     }
#
#     .table_border table,
#     {
#         border-collapse: separate;
#     }
#
#     .table_border thead,
#     .table_border thead tr,
#     .table_border thead th
#     {
#         text-align: center !important;
#         color: #03a9f4;
#     }
#
#
#     .table_border thead th
#     {
#         border-right: 1px solid;
#     }
#
#     .table_border thead th:last-child
#     {
#         border-right: none;
#     }
#
#     .table_border thead
#     {
#         display: table-caption;
#         border: none !important;
#     }
#
#     .table_border tbody
#     {
#         border: none !important;
#         display: table-cell;
#     }
#
#     ++++++++++++++++++++++
#     .table_border thead tr
#     {
#         background: rgba(66, 165, 245, 0.2) !important;
#         border-bottom: 1px solid #b2ebf2 !important;
#         display: table-row;
#         padding: 1px;
#     }
#
#     ++++++++++++++++++++++
#     .table_border thead tr:first-child th:first-child {
#         display: table-cell;
#         border-radius: 10px 0px 0px 0px;
#     }
#     ++++++++++++++++++++++
#     .table_border thead tr:first-child th:last-child {
#         display: table-cell;
#         border-radius: 0px 10px 0px 0px;
#     }
#
#     .table_border thead th
#     {
#         word-break: inherit;
#     }
#
#     .table_border th, .table_border tbody td {
#         width: 110px;
#         word-break: break-word;
#     }
#
#     .table_border tbody tr
#     {
#         background: none !important;
#     }
#
#     ++++++++++++++++++++++
#     .table_border tbody tr:hover,
#     .table_border tbody td.active
#     {
#         background: rgba(66, 165, 245, 0.2) !important;
#     }
#
#     ++++++++++++++++++++++
#     .table_border tbody td:hover
#     {
#         font-weight: bold;
#         color: #03a9f4;
#     }
#
#     .table_border tbody tr:last-child:hover
#     {
#         border-radius: 0px 0px 10px 10px;
#         display: block;
#         padding: 0px;
#         background: antiquewhite !important;
#     }
#
#     /*.table_border th,
#     .table_border td
#     {
#         width: 250px !important;
#         word-break: break-word;
#     }*/
#
#
#     .sea_war th,
#     .sea_war td
#     {
#         width: 26px !important;
#     }
#
#     .sea_war tbody th,
#     .sea_war tbody td
#     {
#         border: 1px solid rgba(0,0,0,0.1);
#     }
#
#     .sea_war tbody th
#     {
#         color: rgba(0,0,0,0.5);
#         text-align: center !important;
#     }
#
#     /*---------------Borders------------------------*/
#
#     /* border_horizont  */
#     .border_horizont tbody th,
#     .border_horizont tbody td
#     {
#         border-bottom: 1px solid rgba(0,0,0,0.04);
#     }
#
#     .border_horizont tbody tr:last-child th,
#     .border_horizont tbody tr:last-child td
#     {
#         border-bottom: none;
#     }
#
#     /* border_vertical  */
#     .border_vertical tbody th,
#     .border_vertical tbody td
#     {
#         border-right: 1px solid rgba(0,0,0,0.04);
#     }
#
#     .border_vertical tbody td:last-child
#     {
#         border-right: none;
#     }
#
#     /* border_display  */
#     .border_display tbody th,
#     .border_display tbody td
#     {
#         border: 1px solid rgba(0,0,0,0.04);
#     }
#     .border_display tbody th,
#     .border_display tbody td
#     {
#         border-left: none;
#         border-top: none;
#     }
#     .border_display tbody td:last-child
#     {
#        border-right: none;
#     }
#     .border_display tbody tr:last-child th,
#     .border_display tbody tr:last-child td
#     {
#         border-bottom: none;
#     }
#
#
#     /* positions  */
#
#     .position_left thead th,
#     .position_left tbody td {
#         text-align: left !important;
#     }
#
#     .position_center thead th,
#     .position_center tbody td {
#         text-align: center !important;
#     }
#
#     .position_right thead th,
#     .position_right tbody td {
#         text-align: right !important;
#     }
#
#     .position_left_header thead th {
#         text-align: left !important;
#     }
#
#     .position_center_header thead th {
#         text-align: center !important;
#     }
#     .position_right_header thead th {
#         text-align: right !important;
#     }
#
#     /*---------------Code------------------------*/
#     .rendered_html p code,
#     .rendered_html ul code,
#     .rendered_html pre code[class*="custom"]
#     {
#         background-color: #d9edfd;
#         color: #4c4c4c;
#         font-size: 16px !important;
#         border-radius: 10px;
#         font-weight: bold;
#         border: 1px solid #ccc !important;
#         padding: 5px !important;
#         line-height: 19px !important;
#         display: inline-block;
#         margin: 5px 0px 0px 0px;
#         word-break: break-word;
#     }
#
#     .rendered_html code span[class*="-bold"]
#     {
#         font-weight: bold;
#     }
#
#     .rendered_html code span[class*="-italic"]
#     {
#         font-style: italic;
#     }
#
#     .rendered_html code span[class*="-marker"]
#     {
#         background: #ffeb3b8c;
#         font-weight: bold;
#         border: 1px solid #9e9e9e;
#         box-shadow: 1px 1px 5px 0px #00000045;
#         border-radius: 4px;
#         padding: 2px;
#         opacity: 0.8;
#         line-height: 30px;
#     }
#
#     .rendered_html code[class*="error"] {
#         color: red !important;
#         background-color: rgba(244, 67, 54, 0.1) !important;
#         font-weight: normal !important;
#     }
#
#     .rendered_html code[class*="warning"] {
#         color: #ff9800 !important;
#         background-color: rgba(244, 243, 54, 0.1) !important;
#         font-weight: normal !important;
#     }
#
#     .rendered_html code[class*="info"] {
#         color: green !important;
#         background-color: rgb(54, 244, 91, 0.1) !important;
#         font-weight: normal !important;
#     }
#
#     .rendered_html code[class*="word"] {
#         color: #00bcd4 !important;
#         background-color: rgba(54, 195, 244, 0.1) !important;
#         font-weight: normal !important;
#     }
#
#     /*---------------Imgs------------------------*/
#     .rendered_html img
#     {
#         border-radius: 16px;
#         border: 1px solid rgb(0 0 0 / 25%);
#         box-shadow: 5px 6px 8px 1px hsl(0deg 0% 0% / 25%);
#         padding: 4px;
#         margin-bottom: 10px;
#         max-width: 65em;
#     }
#
#     #ipython_notebook:after {
#         content: '@alefair кодит';
#         position: relative;
#         color: #2196f3;
#         bottom: 7px;
#         right: -35px;
#     }
# </style>
# Out:
# <style>
#
#     a.bkmk_link {
#         text-decoration: none !important;
#     }
#
#     a.bkmk_link:hover em strong,
#     a.bkmk_link:hover strong em
#     {
#         background: none;
#         transition: background-color 1000ms linear;
#         border: 1px solid rgba(0, 0, 0, 0.1);
#         box-shadow: inset 1px 3px 6px 0px rgba(0, 0, 0, 0.1);
#     }
#
#     div.ow_fl {
#         overflow: auto;
#     }
#
#     div.ow_fl p {
#         display:flex;
#     }
#
#     .rendered_html :link {
#         text-decoration: none;
#     }
#
#     a:hover, a:focus {
#         color: #1a466c;
#         text-decoration: underline;
#     }
#
#     #notebook-container {
#         /*width: 1700px;*/
#     }
#
#     #notebook-container .cell:nth-child(6),
#     #notebook-container .cell:nth-child(8)
#     {
#         display: none;
#     }
#
#
#     table {float: left;}
#     table td, table th, table tr {
#         text-align:left !important;
#     }
#
#     .menu_table thead,
# ...

# %% [markdown]
# **Импорт библиотек**

# %%
# %matplotlib inline

import pandas as pd
from datetime import datetime
from bs4 import BeautifulSoup

from IPython.display import Markdown as md
from matplotlib import pyplot as plt

import numpy as np

import os
from os import listdir
from os.path import isfile, join, isdir

# %% [markdown]
# **Вспомогательные функции и переменные**

# %%
def try_parse(var, type_obj):
    b = None
    
    try:
        b = type_obj(var)
    except:
        return 'Ошибка: Не смог преобразовать {} в {}'.format(var, type_obj.__name__ )
    
    return b


def procents_change(val, digit_count=1):
    if "%" in str(val):  
        return float(str(int(val.strip('%'))/10))
    else:
        return float(val)


def main_value(val):
    return str(val).strip().split(',')[0]

# %% [markdown]
# ## Шаг. Откройте файлы с данными и объедините их в один датафрейм.
#
# Объедините данные таким образом, чтобы все объекты из датасета `mkrf_movies` обязательно вошли в получившийся датафрейм.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_0" aria-expanded="false" aria-controls="collapseHint_0">Подсказка</button>
#         </div>
#         <div id="collapseHint_0" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на тип данных столбца, по которому будете соединять датафреймы. Тип данных этих столбцов должен быть одинаковым в обоих датафреймах.
#             </div>
#         </div>
#     </div>
# </div>

# %%
#Считываем датасеты
movies = pd.read_csv('/datasets/mkrf_movies.csv')
shows  = pd.read_csv('/datasets/mkrf_shows.csv')

render(movies.head(2))
render(shows.head(2))

display(md("<br>[| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <style  type="text/css" >
# #T_700ac_row0_col9,#T_700ac_row0_col10,#T_700ac_row0_col11,#T_700ac_row0_col12,#T_700ac_row1_col7,#T_700ac_row1_col9,#T_700ac_row1_col10,#T_700ac_row1_col11,#T_700ac_row1_col12{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  red;
# ...

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Файл mkrf_movies.csv
#
# _**` `<br>
# `::  title                  ::` — название фильма<br>
# `::  puNumber               ::` — номер прокатного удостоверения<br>
# `::  show_start_date        ::` — дата премьеры фильма<br>
# `::  type                   ::` — тип фильма<br>
# `::  film_studio            ::` — студия-производитель<br>
# `::  production_country     ::` — страна-производитель<br>
# `::  director               ::` — режиссёр<br>
# `::  producer               ::` — продюсер<br>
# `::  age_restriction        ::` — возрастная категория<br>
# `::  refundable_support     ::` — объём возвратных средств государственной поддержки<br>
# `::  nonrefundable_support  ::` — объём невозвратных средств государственной поддержки<br>
# `::  financing_source       ::` — источник государственного финансирования<br>
# `::  budget                 ::` — общий бюджет фильма<br>
# `::  ratings                ::` — рейтинг фильма на КиноПоиске<br>
# `::  genres                 ::` — жанр фильма<br>
# ` `**_
#
#
# Файл mkrf_shows.csv
#
# _**` `<br>
# `::  puNumber                ::` — номер прокатного удостоверения<br>
# `::  box_office              ::` — сборы в рублях<br>
# ` `**_
#
# <br>[| Назад к Содержанию](#Содержание)<hr>

# %% [markdown]
# .

# %% [markdown]
# ### Структура и типы данных в колонках

# %%
render('Структура и типы данных в колонках')
movies.info()

print()
print()

shows.info()

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <p class="value" ><code>Структура и типы данных в колонках</code></p>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
# ...

# %% [markdown]
# ### Объединение таблиц

# %% [markdown]
# Для того, чтобы объединить таблицы нужно убедиться, что названия столбцов одинаковые и тип данных в столбце одинаковый.
#
# Но после анализа данных видим, что столбец `puNumber` в таблице `mkrf_movies` имеет тип `object`, а должен - `int`.
#
# На этом этапе переведем тип столбца  в `int` и объединим таблицы. В столбце отсуствуют пропуски, а значит не надо заполнять пустые значения!

# %%
column_name = "puNumber"

print('Столбец',column_name,'был типом:', movies[column_name].dtypes)

try:
    movies[column_name] = (
        movies[column_name]
            .astype('int')
    )
    print('Тип столбца стал:', movies[column_name].dtypes)
except:
    print('При преобразовании столбца в int произошла ошибка, попробуем выяснить какие значения сбоят!')
    
    movies[column_name + '_wrong'] = movies[column_name].apply(try_parse, type_obj=int)
    
    err_numbers = movies.loc[movies[column_name + '_wrong'].str.contains("ошибка", case=False, na=False)][column_name]
    
    render(err_numbers)
    
    print('Обнаружили ', len(err_numbers), 'некорректных значений для столбца', column_name)
    print('Заменим их на -1')
    
    movies.loc[(movies[column_name].isin(err_numbers.tolist())), column_name] = -1
    
    print('Проверим результат и снова попробуем преобразовать столбец в int')
    
    render(movies.query('{} == -1'.format(column_name)))
    
    movies[column_name] = (
        movies[column_name]
            .astype('int')
    )

print()
print()
print('Объединяем 2 таблицы')

data = movies.merge(shows, on=column_name, how='left')

render(data.head())
print()
render('Посмотрим на структуру объединенной таблицы')
data.info()

display(
    md(
        "**_Все данные вошли_**"
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# Столбец puNumber был типом: object
# При преобразовании столбца в int произошла ошибка, попробуем выяснить какие значения сбоят!
# <style  type="text/css" >
# </style><table id="T_85bad_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >puNumber</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_85bad_level0_row0" class="row_heading level0 row0" >1797</th>
#                         <td id="T_85bad_row0_col0" class="data row0 col0" >нет</td>
#             </tr>
#     </tbody></table>
# Обнаружили  1 некорректных значений для столбца puNumber
# Заменим их на -1
# Проверим результат и снова попробуем преобразовать столбец в int
# <style  type="text/css" >
# #T_b4835_row0_col9,#T_b4835_row0_col10,#T_b4835_row0_col11,#T_b4835_row0_col12,#T_b4835_row0_col13,#T_b4835_row0_col14{
#             font-weight: bold;
#             text-transform:  capitalize;
# ...

# %% [markdown]
# ### Шаг 1. Вывод

# %% [markdown]
# Анализируя источник данных и, сравнивая данные с описанием данных, найдены следующие нарушения:
#
# <div class="alert alert-danger">
#     <p>Из первого же среза видим, что есть явные и не явные дубликаты. Надо их удалить. Явных причин для этого нет. Данные везде одинаковые. отличается только <b>puNumber</b> и кое-где <b>show_start_date</b></p>
# </div>
#
# <a class="bkmk_link" href="#Столбец-box_office">**_Столбец `box_office (сборы в рублях)` - Есть пропуски_**</a>
#
# <a class="bkmk_link" href="#Столбец-show_start_date">_**Столбец `show_start_date (дата премьеры фильма)` - Необходимо перевести в datetime**_</a>
#
# <a class="bkmk_link" href="#Столбец-film_studio">**_Столбец `film_studio (студия-производитель)` - Есть пропуски_**</a>
#
# <a class="bkmk_link" href="#Столбец-production_country">_**Столбец `production_country (страна-производитель)` - Есть пропуски**_</a>
#
# <a class="bkmk_link" href="#Столбец-director">**_Столбец `director (режиссёр)` - Есть пропуски_**</a>
#
# <a class="bkmk_link" href="#Столбец-producer">_**Столбец `producer (продюсер)` - Есть пропуски**_</a>
#
# <a class="bkmk_link" href="#Столбец-refundable_support">**_Столбец `refundable_support (объём возвратных средств государственной поддержки)` - Есть пропуски_**</a>
#
# <a class="bkmk_link" href="#Столбец-nonrefundable_support">_**Столбец `nonrefundable_support (объём невозвратных средств государственной поддержки)` - Есть пропуски**_</a>
#
# <a class="bkmk_link" href="#Столбец-budget">**_Столбец `budget (общий бюджет фильма)` - Есть пропуски_**</a>
#
# <a class="bkmk_link" href="#Столбец-financing_source">_**Столбец `financing_source (источник государственного финансирования)` - Есть пропуски**_</a>
#
# <a class="bkmk_link" href="#Столбец-ratings">**_Столбец `ratings (рейтинг фильма на КиноПоиске)` - Есть пропуски и необходимо перевести в float_**</a>
#
# <a class="bkmk_link" href="#Столбец-genres">_**Столбец `genres (жанр фильма)` - Есть пропуски**_</a>
#
# ```
# - Мы выяснили какие проблемы нам придется устранять
# - Объединили 2 отчета, отчет объединен успешно
# ```
#
# <br> [| Назад к Содержанию](#Содержание)<hr>

# %% [markdown]
# ## Шаг. Предобработка данных

# %% [markdown]
# <div class="alert alert-warning">
#     <p>Попробуем подобрать альтернативное значение в пропущенных строчках проблемных столбцов</p>
# </div>

# %% [markdown]
# ### Шаг. Проверьте типы данных
#
# - Проверьте типы данных в датафрейме и преобразуйте их там, где это необходимо.

# %% [markdown]
# #### Столбец puNumber

# %%
column_name = "puNumber"

render('Столбец "{}" - номер прокатного удостоверения'.format(column_name))

display(
    md(
        '_**Можем изменить столбец `{}` привести к типу <b>int</b>**_'.format(column_name)
    )
)

data[column_name] = data[column_name].astype('int')

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "puNumber" - номер прокатного удостоверения</code></p>
# _**Можем изменить столбец `puNumber` привести к типу <b>int</b>**_
# Тип столбца стал: `int64`
# [| Назад к Выводу](#Шаг-1.-Вывод)<hr>

# %% [markdown]
# #### Столбец box_office

# %%
column_name = "box_office"

render('Столбец "{}" - сборы в рублях'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

render('На первый взгляд ничего общего нет. Оставим столбец пока без изменений. Да и средние показатели мы не сможем указать.')

display(
    md(
        '_**Можем изменить столбец `{}` привести к типу <b>float</b>**_'.format(column_name)
    )
)

#data[column_name] = data[column_name].fillna(0)

data[column_name] = data[column_name].astype('float')

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

render('Посмотрим на данные')

render(data[column_name].describe())

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "box_office" - сборы в рублях</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец show_start_date

# %%
column_name = "show_start_date"

render('Столбец "{}" - дата премьеры фильма'.format(column_name))

display(
    md(
        "Для анализа данных нам время не надо учитывать в дате премьеры, по этому приведем к формату: `'%Y-%m-%d'`"
    )
)

data[column_name] = pd.to_datetime(data[column_name], format = '%Y-%m-%d')


display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
        +'<hr>'
    )
)
display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "show_start_date" - дата премьеры фильма</code></p>
# Для анализа данных нам время не надо учитывать в дате премьеры, по этому приведем к формату: `'%Y-%m-%d'`
# Тип столбца стал: `datetime64[ns, UTC]`<hr>
# [| Назад к Выводу](#Шаг-1.-Вывод)<hr>

# %% [markdown]
# #### Столбец film_studio

# %%
column_name = "film_studio"

render('Столбец "{}" - студия-производитель'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(18),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

render('На первый взгляд ничего общего нет. Оставим столбец пока без изменений')
print('Видим явный дубликат - Ян Антонышев. Но с дубликатами разберемся позже')
print('Пропуски здесь не сможем заменить - нечем')

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "film_studio" - студия-производитель</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец production_country

# %%
column_name = "production_country"

render('Столбец "{}" - страна-производитель'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

print("Мы видим всего 2 пропуска, попробуем их заполнить своими силами, хоть они и не влияют на общую картину")

#ЕРАЛАШ-----------
render((
    data
        .loc[data['film_studio']
        .str.contains("ЕРАЛАШ", case=False, na=False)][column_name]
        .value_counts()
), name="ЕРАЛАШ")

print('Страна производства "ЕРАЛАШ" - в основном Россия, заполним пустоты')

data.loc[(
    data['film_studio']
        .str.contains("ЕРАЛАШ", case=False, na=False)
    , column_name)] = 'Россия'

#-----------ЕРАЛАШ


#Мульт личности--------
render((
    data
        .loc[data['title']
        .str.contains("Мульт личности", case=False, na=False)][column_name]
        .value_counts()
), name="Мульт личности")

print('К сожалению в наших данных только одна запись про "Мульт личности"')
print('Обратимся к Кинопоиск(https://www.kinopoisk.ru/series/487219/) и попробуем заполнить все недостающие столбцы, как сможем :-)')


#Cтудия-производитель
data.loc[(
    data['film_studio']
        .str.contains("Мульт личности", case=False, na=False)
    , column_name)] = 'Concept Space / Prostranstvo Idey'

#Страна-Производитель
data.loc[(
    data['title']
        .str.contains("Мульт личности", case=False, na=False)
    , column_name)] = 'Россия'

#Режиссер
data.loc[(
    data['director']
        .str.contains("Мульт личности", case=False, na=False)
    , column_name)] = 'Василий Пичул, Юрий Владовский'

#Продюссер
data.loc[(
    data['producer']
        .str.contains("Мульт личности", case=False, na=False)
    , column_name)] = 'Константин Эрнст, Марина Даниелян, Дэвид Либерман, Даниил Либерман, Анна Либерман, Дмитрий Азадов'

#---------Мульт личности

print()
print()
print('Проверим снова пустые строки')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "production_country" - страна-производитель</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# #T_57b82_row0_col5,#T_57b82_row0_col9,#T_57b82_row0_col10,#T_57b82_row0_col11,#T_57b82_row0_col12,#T_57b82_row1_col4,#T_57b82_row1_col5,#T_57b82_row1_col6,#T_57b82_row1_col7,#T_57b82_row1_col9,#T_57b82_row1_col10,#T_57b82_row1_col11,#T_57b82_row1_col12,#T_57b82_row1_col16{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  red;
# ...

# %% [markdown]
# #### Столбец director

# %%
column_name = "director"

render('Столбец "{}" - режиссёр'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

print()
print()
render('На первый взгляд ничего общего нет. Оставим столбец пока без изменений. Пустые значения нечем заменить')


display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "director" - режиссёр</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец producer

# %%
column_name = "producer"

render('Столбец "{}" - продюсер'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

render('На первый взгляд ничего общего нет. Оставим столбец пока без изменений.  Пустые значения нечем заменить')

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "producer" - продюсер</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец refundable_support

# %%
column_name = "refundable_support"

render('Столбец "{}" - объём возвратных средств государственной поддержки'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

render('На первый взгляд ничего общего нет. Оставим столбец пока без изменений. Да и средние показатели мы не сможем указать.')

display(
    md(
        '_**Можем изменить столбец `{}` привести к типу <b>float32</b>**_'.format(column_name)
    )
)


data[column_name] = data[column_name].astype('float')

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "refundable_support" - объём возвратных средств государственной поддержки</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец nonrefundable_support

# %%
column_name = "nonrefundable_support"

render('Столбец "{}" - объём невозвратных средств государственной поддержки'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

render('На первый взгляд ничего общего нет. Оставим столбец пока без изменений. Да и средние показатели мы не сможем указать.')

display(
    md(
        '_**Можем изменить столбец `{}` привести к типу <b>float32</b>**_'.format(column_name)
    )
)


data[column_name] = data[column_name].astype('float')

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "nonrefundable_support" - объём невозвратных средств государственной поддержки</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец budget

# %%
column_name = "budget"

render('Столбец "{}" - объём невозвратных средств государственной поддержки'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

render('На первый взгляд ничего общего нет. Оставим столбец пока без изменений. Да и средние показатели мы не сможем указать.')

display(
    md(
        '_**Можем изменить столбец `{}` привести к типу <b>float32</b>**_'.format(column_name)
    )
)

data[column_name] = data[column_name].astype('float')

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "budget" - объём невозвратных средств государственной поддержки</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец financing_source

# %%
column_name = "financing_source"

render('Столбец "{}" - объём невозвратных средств государственной поддержки'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

render('На первый взгляд ничего общего нет. Оставим столбец пока без изменений')

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "financing_source" - объём невозвратных средств государственной поддержки</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец ratings

# %%
column_name = "ratings"

render('Столбец "{}" - рейтинг фильма на КиноПоиске'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

render('На первый взгляд ничего общего нет. Оставим столбец пока без изменений')

display(
    md(
        '_**Можем изменить столбец `{}` привести к типу <b>float32</b>**_'.format(column_name)
    )
)



try:
    data[column_name] = data[column_name].fillna(0)
    data[column_name] = data[column_name].astype('float')
except:
    print("При попытке преобразовать в float32 мы поймали ошибку, посмотрим где ошибка")
    
    data[column_name + '_wrong'] = data[column_name].apply(try_parse, type_obj=float)
    
    
    err_numbers = data.loc[data[column_name + '_wrong'].str.contains("ошибка", case=False, na=False)][column_name]
    
    render(err_numbers)
    
    print('Обнаружили ', len(err_numbers), 'некорректных значений для столбца', column_name)
    print("Преобразуем число из формата 99% в Формат 9.9")
    
    data[column_name] = data[column_name].apply(procents_change)
    
    print('Проверим результат и снова попробуем преобразовать столбец в float')
    
    render(data.loc[data[column_name + '_wrong'].str.contains("ошибка", case=False, na=False)])
    
    data[column_name] = data[column_name].fillna(0)
    data[column_name] = data[column_name].astype('float')

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

render('посмотрим на фильмы с рейтингом больше 9.0')

render(
    data
        .query('{} > 9.0'.format(column_name))
)


render("После анализа таблицы решил проверить на Кинопоиске и как оказалось, что все значения, которые имели проценты - ошибочные данные, но зато мы смогли преобразовать столбец в float.")

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "ratings" - рейтинг фильма на КиноПоиске</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец genres

# %%
column_name = "genres"

render('Столбец "{}" - объём невозвратных средств государственной поддержки'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками:')

render(
    data[data[column_name].isna()].head(10),
    name='Количество пустых строк: {}'.format(len(data[data[column_name].isna()]))
)

render('На первый взгляд ничего общего нет. Оставим столбец пока без изменений')

display(md("[| Назад к Выводу](#Шаг-1.-Вывод)<hr>"))
# Out:
# <p class="value" ><code>Столбец "genres" - объём невозвратных средств государственной поддержки</code></p>
# Проверим есть ли зависимость между данными и пропусками:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Удалим вспомогательные столбцы

# %%
del data['puNumber_wrong']
del data['ratings_wrong']

# %% [markdown]
# #### Данные. Вывод

# %% [markdown]
# _**<b>Вывод:</b><br><br>
# *` ` <span style="margin-right:10px"></span> Как таковых причин отсуствия пропусков пока не выявлено, однако можно проследить, что некоторые столбцы имеют одинаковое количество пропусков*<br><br>
# *` ` <span style="margin-right:10px"></span> Выяснили, что в рейтинге часть строк были выставлены некорректно - в процентах, заменили на числа с плавающей запятой*<br><br>
# *` ` <span style="margin-right:10px"></span> Дабавили столбец `box_office`*<br><br>
# *` ` <span style="margin-right:10px"></span> Часть столбцов преобразовали в int32 и в float32 для экономии памяти*<br><br>
# *` ` <span style="margin-right:10px"></span> Обнаружили явные дубликаты*<br><br>
# *` ` <span style="margin-right:10px"></span> Дополнили данными взятых с Кинопоиск*<br>
# *` ` <span style="margin-right:10px"></span> Заменили пропуски 0, где это необходимо и по возможности*<br>**_

# %%
render('Структура и типы данных в колонках до и после')
# Out:
# <p class="value" ><code>Структура и типы данных в колонках до и после</code></p>

# %% [markdown]
# <div style="overflow: auto;">
#
# |Было|Стало|
# |----|-----|
# |![image.png](attachment:image.png)|![image-6.png](attachment:image-6.png)|
#
# </div>
#
# [| Назад к Содержанию](#Содержание)<hr>

# %% [markdown]
# #### Проанализируем пропуски

# %%
render(
    data
        .isna()
        .sum()
        .reset_index(name='count')
        .rename(columns={'index':'column_name'})
)

render("Видим зависимость, что у столбцов 'refundable_support', 'nonrefundable_support', 'budget', 'financing_source' одинаковое количество пропусков, это может говорить о том, что у этих фильмов не было гос поддержки ")

render("Видим, что у сборов тоже есть пропуски, возможно по этим данным нет информации по сборам в России, или просто ошибка данных")
# Out:
# <style  type="text/css" >
# </style><table id="T_2fd17_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >column_name</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2fd17_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2fd17_row0_col0" class="data row0 col0" >title</td>
#                         <td id="T_2fd17_row0_col1" class="data row0 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_2fd17_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2fd17_row1_col0" class="data row1 col0" >puNumber</td>
#                         <td id="T_2fd17_row1_col1" class="data row1 col1" >0</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ### Шаг. Изучите дубликаты в датафрейме
# - Проверьте, есть ли в данных дубликаты. Опишите причины, которые могли повлиять на появление дублей.

# %% [markdown]
# <p>Основным признаком присутствия дубликатов может быть одинаковое название. </p>
# <div class="alert alert-warning">
#     <p>Но здесь нужно быть аккуратнее, ведь под одним и тем же названием может быть абсолютно разные фильмы!</p>
# </div>
# <p>По этому для выборки нам еще понадобится номер прокатного удостоверения, режиссер и допустим страна-производитель.</p>

# %% [markdown]
# #### Дубликаты номера прокатного удостоверения

# %% [markdown]
# **_Посмотрим дубликаты, где `номер прокатного удостоверения` повторяется больше 1 раза_**

# %%
puNumber_dupl = (
    data[['puNumber']]
        .value_counts()
        .reset_index(name="count")
        .query("count > 1")
    )

render(
    puNumber_dupl
    , name='Дубликаты номера прокатного удостоверения'
)

render(data[data['puNumber'].isin(puNumber_dupl['puNumber'])])
# Out:
# <style  type="text/css" >
# </style><table id="T_b081f_" class="table_border position_center_header" data-title="Дубликаты номера прокатного удостоверения" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >puNumber</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b081f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b081f_row0_col0" class="data row0 col0" >221054410</td>
#                         <td id="T_b081f_row0_col1" class="data row0 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_b081f_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b081f_row1_col0" class="data row1 col0" >221154310</td>
#                         <td id="T_b081f_row1_col1" class="data row1 col1" >2</td>
#             </tr>
#     </tbody></table>
# ...

# %% [markdown]
# <div class="alert alert-danger">
#     <p>Мы обнаружили явные ошибки:</p>
#     <p>- Под одним и тем же номером находятся разные фильмы, разные режиссеры и в частности страна-производитель</p>
#     <br>
#     <p>Придется провести анализ и устанить ошибки. В этом нам поможет <b>Сайт Министерства Культуры РФ</b> и <i>раздел реестра прокатных удостоверений</i> <a href="https://culture.gov.ru/services/reestr-prokatnykh-udostovereniy/">ссылка тут</a></p>
#     <p>А также в наших исследованиях нам поможет сайт <a href="https://www.kinopoisk.ru/">Кинопоиск</a></p>
# </div>

# %%
display(
    md(
        '**_'
        + 'Как жениться и остаться холостым'
        + '_**'
        + '<br><b>Или</b><br><br>'
        + '_**'
        + 'Иоанна - женщина на папском престоле /По роману Донны Вулфольк Кросс/'
        + '**_'
    )
)

columns = ['Дата выдачи удостоверения','Номер удостоверения','Год выхода','Цвет','Возрастная Категория','Право на использование']

#Как жениться и остаться холостым
new_data = [
            ['19.12.2007', 221333607, 2006, 'Цветной', '14+', 'Кабельное ТВ в гостиницах'],
            ['09.02.2007', 121002007, 2006, 'Цветной', '14+', 'Все права'],
            ['03.12.2010', 221142510, 2006, 'Цветной', '14+', 'Кабельное ТВ в гостиницах'],
            ['17.12.2010', 221154310, 2006, 'Цветной', '14+', 'Видео по запросу - неисключительные права']
        ]

render(
    pd.DataFrame(new_data, columns=columns)
    , name='По запросу *Как жениться и остаться холостым* 4 результата:'
    , marker=[['Номер удостоверения', [221154310]]]
)

#Иоанна - женщина на папском престоле /По роману Донны Вулфольк Кросс/
new_data = [
            ['03.12.2010', 221141710, 2009, 'Цветной', '14+', 'Кабельное ТВ в гостиницах'],
            ['17.12.2010', 221154310, 2009, 'Цветной', '14+', 'Видео по запросу - неисключительные права'],
            ['25.03.2010', 121005410, 2009, 'Цветной', '14+', 'Все права']
        ]

render(
    pd.DataFrame(new_data, columns=columns)
    , name='По запросу *Иоанна - женщина на папском престоле /По роману Донны Вулфольк Кросс/* 3 результата:'
    , marker=[['Номер удостоверения', [221154310]]]
)
# Out:
# **_Как жениться и остаться холостым_**<br><b>Или</b><br><br>_**Иоанна - женщина на папском престоле /По роману Донны Вулфольк Кросс/**_
# <style  type="text/css" >
# #T_3d162_row3_col1{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  #0d64a1;
#         }</style><table id="T_3d162_" class="table_border position_center_header" data-title="По запросу *Как жениться и остаться холостым* 4 результата:" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Дата выдачи удостоверения</th>        <th class="col_heading level0 col1" >Номер удостоверения</th>        <th class="col_heading level0 col2" >Год выхода</th>        <th class="col_heading level0 col3" >Цвет</th>        <th class="col_heading level0 col4" >Возрастная Категория</th>        <th class="col_heading level0 col5" >Право на использование</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <p>Очевидно, что 17 декабря 2010 года допустили ошибку и двум фильмам присвоили один и тот же номер прокатного удостоверения.</p>
#     <p>Прежде, чем принять решение, какой номер прокатного удостоверения применить, посмотрим, а есть ли такие же названия + такой же режиссер в наших данных</p>
# </div>

# %%
title_dupl = (
    data[['title', 'director']]
        .value_counts()
        .reset_index(name="count")
        .sort_values(by='title', ascending=True)
        .query('title in ["Как жениться и остаться холостым", "Иоанна - женщина на папском престоле /По роману Донны Вулфольк Кросс/"]')
    )

render(
    title_dupl.head(10)
)

render('Есть дубликат и по названию + режиссер')

print()
print()
print('Посмотрм по подробнее')

render(data[data['title'].isin(title_dupl['title'])].sort_values(by='title', ascending=True))
# Out:
# <style  type="text/css" >
# </style><table id="T_4b322_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >title</th>        <th class="col_heading level0 col1" >director</th>        <th class="col_heading level0 col2" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4b322_level0_row0" class="row_heading level0 row0" >40</th>
#                         <td id="T_4b322_row0_col0" class="data row0 col0" >Иоанна - женщина на папском престоле /По роману Донны Вулфольк Кросс/</td>
#                         <td id="T_4b322_row0_col1" class="data row0 col1" >Зенке Вортманн</td>
#                         <td id="T_4b322_row0_col2" class="data row0 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_4b322_level0_row1" class="row_heading level0 row1" >330</th>
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <p>Как мы видим по таблице дубликатов:</p>
#     <br>
#     <p>- <b>Иоанна - женщина на папском престоле /По роману Донны Вулфольк Кросс/</b> Дубли связаны с разным прокатным удостоверением. Оставим одно - 121005410 ("Все права")</p>
#     <br>
#     <p>- <b>Как жениться и остаться холостым</b> Дубли связаны с разным прокатным удостоверением. Оставим одно - 121002007 ("Все права")</p>
# </div>

# %%
data.loc[(
    data['title']
        .str.contains("Иоанна - женщина на папском престоле /По роману Донны Вулфольк Кросс/", case=False, na=False)
    , 'puNumber')] = 121002007


data.loc[(
    data['title']
        .str.contains("Как жениться и остаться холостым", case=False, na=False)
    , 'puNumber')] = 121005410

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <br> [| Назад к Содержанию](#Содержание)<hr>

# %%
display(
    md(
        '**_'
        + 'Анализируй это!'
        + '_**'
        + '<br><b>Или все-таки</b><br><br>'
        + '_**'
        + 'Анализируй то!'
        + '**_'
        + '<br>Очень Близкие названия и даты выхода очень близко. Будет непросто, но постараемся :-)<br><br>'
    )
)

columns = ['Дата выдачи удостоверения','Номер удостоверения','Год выхода','Цвет','Возрастная Категория','Право на использование']

#Анализируй это!
new_data = [
            ['25.05.2010', 221054410, 1999, 'Цветной', '14+', 'Blue Ray-домашнее видео'],
            ['15.12.2010', 221147310, 1999, 'Цветной', '14+', 'Домашнее видео - DVD, Blu-Ray'],
            ['27.01.2006', 221010106, 1999, 'Цветной', '14+', 'Домашнее видео-VHS,DVD'],
            ['29.03.2000', 221043600, 1999, 'Цветной', '14+', 'Домашнее видео, публичное видео, демонстрация в гостиницах'],
            ['06.01.2000', 121000400, 1999, 'Цветной', '14+', 'Театральный (неисключительные права)'],
            ['15.01.2003', 221008803, 1999, 'Цветной', '14+', 'Домашнее видео-VHS,DVD']
        ]

render(
    pd.DataFrame(new_data, columns=columns)
    , name='По запросу *Анализируй это!* 6 результатов:'
    , marker=[['Номер удостоверения', [221054410]]]
)

#Анализируй то!
new_data = [
            ['25.05.2010', 221054410, 2002, 'Цветной', '12+', 'Blue Ray-домашнее видео'],
            ['27.01.2006', 221010006, 2002, 'Цветной', '12+', 'Домашнее видео-VHS,DVD'],
            ['17.03.2003', 121004303, 2002, 'Цветной', '12+', 'Театральный (неисключительные права)']
        ]

render(
    pd.DataFrame(new_data, columns=columns)
    , name='По запросу *Анализируй то!* 3 результата:'
    , marker=[['Номер удостоверения', [221054410]]]
)
# Out:
# **_Анализируй это!_**<br><b>Или все-таки</b><br><br>_**Анализируй то!**_<br>Очень Близкие названия и даты выхода очень близко. Будет непросто, но постараемся :-)<br><br>
# <style  type="text/css" >
# #T_de9e3_row0_col1{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  #0d64a1;
#         }</style><table id="T_de9e3_" class="table_border position_center_header" data-title="По запросу *Анализируй это!* 6 результатов:" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Дата выдачи удостоверения</th>        <th class="col_heading level0 col1" >Номер удостоверения</th>        <th class="col_heading level0 col2" >Год выхода</th>        <th class="col_heading level0 col3" >Цвет</th>        <th class="col_heading level0 col4" >Возрастная Категория</th>        <th class="col_heading level0 col5" >Право на использование</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <p>Очевидно, что 25 февраля 2010 года допустили ошибку и двум фильмам присвоили один и тот же номер прокатного удостоверения. Хотя это не мудренно, названия очень похожи!</p>
#         <p>Прежде, чем принять решение, какой номер прокатного удостоверения применить, посмотрим, а есть ли такие же названия + такой же режиссер в наших данных</p>
# </div>

# %%
title_dupl = (
    data[['title', 'director']]
        .value_counts()
        .reset_index(name="count")
        .sort_values(by='title', ascending=True)
        .query('title in ["Анализируй это!", "Анализируй то!"]')
    )

render(
    title_dupl.head(10)
)

render('Есть дубликат и по названию + режиссер')

print()
print()
print('Посмотрм по подробнее')

render(data[data['title'].isin(title_dupl['title'])].sort_values(by='title', ascending=True))
# Out:
# <style  type="text/css" >
# </style><table id="T_2d3cd_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >title</th>        <th class="col_heading level0 col1" >director</th>        <th class="col_heading level0 col2" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2d3cd_level0_row0" class="row_heading level0 row0" >4514</th>
#                         <td id="T_2d3cd_row0_col0" class="data row0 col0" >Анализируй то!</td>
#                         <td id="T_2d3cd_row0_col1" class="data row0 col1" >Гарольд Реймис</td>
#                         <td id="T_2d3cd_row0_col2" class="data row0 col2" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_2d3cd_level0_row1" class="row_heading level0 row1" >431</th>
#                         <td id="T_2d3cd_row1_col0" class="data row1 col0" >Анализируй это!</td>
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <p>Как мы видим по таблице дубликатов:</p>
#     <br>
#     <p>- <b>Анализируй это!</b> Дубль есть с созвучным названием, однако укажем другой номер - 121000400 ("Театральный (неисключительные права)")</p>
#     <br>
#     <p>- <b>Анализируй то!</b> Дубли связаны с разным прокатным удостоверением, однако укажем другой номер - 121004303 ("Театральный (неисключительные права)")</p>
# </div>

# %%
data.loc[(
    data['title']
        .str.contains("Анализируй это!", case=False, na=False)
    , 'puNumber')] = 121000400


data.loc[(
    data['title']
        .str.contains("Анализируй то!", case=False, na=False)
    , 'puNumber')] = 121004303

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <br> [| Назад к Содержанию](#Содержание)<hr>

# %%
render('Проверим, остались ли дубликаты в номерах прокатных удостоверений:')

puNumber_dupl = (
    data[['puNumber']]
        .value_counts()
        .reset_index(name="count")
        .query("count > 1")
    )

render(
    puNumber_dupl
    , name='Дубликаты номера прокатного удостоверения'
)

render(
    (
        data[data['puNumber']
            .isin(puNumber_dupl['puNumber'])]
            .sort_values(by='title', ascending=True)
    )
)
# Out:
# <p class="value" ><code>Проверим, остались ли дубликаты в номерах прокатных удостоверений:</code></p>
# <style  type="text/css" >
# </style><table id="T_145f5_" class="table_border position_center_header" data-title="Дубликаты номера прокатного удостоверения" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >puNumber</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_145f5_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_145f5_row0_col0" class="data row0 col0" >121002007</td>
#                         <td id="T_145f5_row0_col1" class="data row0 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_145f5_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_145f5_row1_col0" class="data row1 col0" >121005410</td>
# ...

# %% [markdown]
# <div class="alert alert-danger">
#     <p>А вот и неявный дубликаты, от которых будем избавляться в следующем разделе</p>
# </div>
#
# <br> [| Назад к Содержанию](#Содержание)<hr>

# %% [markdown]
# #### Полные дубликаты

# %%
data = data.sort_values(
        by = 'box_office',
        ascending = False
    ).drop_duplicates(
        subset=['title', 'director']
    )

# %% [markdown]
# #### Неявные дубликаты

# %% [markdown]
# Чтобы нам обнаружить неявные дубликаты нам нужно сделать срез по названию и режиссеру, и по количеству таких результатов больше 1

# %%
title_dupl = (
    data[['title', 'director']]
        .value_counts()
        .reset_index(name="count")
        .sort_values(by='title', ascending=True)
        .query("count > 1")
    )


#data without duplicates
data_wt_duplicate = (
    data
        .sort_values('title', ascending=False)
        .drop_duplicates(['title', 'director'])
)

data_wt_duplicate = data_wt_duplicate.sort_index()


title_dupl = (
    data_wt_duplicate[['title', 'director']]
        .value_counts()
        .reset_index(name="count")
        .sort_values(by='title', ascending=True)
        .query("count > 1")
    )

render(
    title_dupl.head(10)
    , name='Дубликаты по названию и режиссеру. Количество: ' + str(len(title_dupl))
)


render(
    data_wt_duplicate.head(5),
    name='data_wt_duplicate | Таблица без дубликатов'
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <style  type="text/css" >
# </style><table id="T_70eca_" class="table_border position_center_header" data-title="Дубликаты по названию и режиссеру. Количество: 0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >title</th>        <th class="col_heading level0 col1" >director</th>        <th class="col_heading level0 col2" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70eca_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_70eca_row0_col0" class="data row0 col0" ></td>
#                         <td id="T_70eca_row0_col1" class="data row0 col1" ></td>
#                         <td id="T_70eca_row0_col2" class="data row0 col2" ></td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Вывод по дубликатам

# %% [markdown]
# _**<b>Вывод:</b><br><br>
# *` ` <span style="margin-right:10px"></span> У нас были строки, где номер прокатного удостоверения повторялось больше 1 раза. Исправили*<br><br>
# *` ` <span style="margin-right:10px"></span> Были дубли по названию + режиссер. Исправили*<br><br>
# *` ` <span style="margin-right:10px"></span> Убрали полные дубликаты*<br><br>
# *` ` <span style="margin-right:10px"></span> Устранили более  536 записей неявных дубликатов*<br><br>
# *` ` <span style="margin-right:10px"></span> Дополнили данными взятых с Кинопоиск*<br>**_

# %% [markdown]
# ### Шаг. Изучите категориальные значения
#
# - Посмотрите, какая общая проблема встречается почти во всех категориальных столбцах;
# - Исправьте проблемные значения в поле `type`.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_1" aria-expanded="false" aria-controls="collapseHint_1">Подсказка</button>
#         </div>
#         <div id="collapseHint_1" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# В поле <code>type</code> есть несколько значений, у которых появился пробел в начале строки. Самый простой способ их «починить» -- использовать метод <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html#pandas.Series.str.strip">.str.strip</a>. Этот метод удаляет все пробелы, которые встречаются в начале и в конце строки. Применяют его таким образом:<br>
# <code>df['type'].str.strip()</code>
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# #### Категория - Тип Фильма

# %%
column_name = 'type'

render(
    (
        data_wt_duplicate[column_name]
            .value_counts()
            .reset_index(name="count")
            .sort_values(by='index', ascending=True)
    )
)

display(
    md(
        '**_'
        + 'Видим, что есть проблемные названия в `"{}"`, скорее всего в названии присутствуют пробелы. Удалим их и проверим результат'.format(column_name)
        + '_**'
    )
)

data_wt_duplicate[column_name] = data_wt_duplicate[column_name].str.strip()


render(
    (
        data_wt_duplicate[column_name]
            .value_counts()
            .reset_index(name="count")
            .sort_values(by='count', ascending=False)
    )
)

display(
    md(
        '_**'
        + 'Отличный результат! Идем дальше!'
        + '**_'
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <style  type="text/css" >
# </style><table id="T_17126_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17126_level0_row0" class="row_heading level0 row0" >7</th>
#                         <td id="T_17126_row0_col0" class="data row0 col0" > Анимационный</td>
#                         <td id="T_17126_row0_col1" class="data row0 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_17126_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_17126_row1_col0" class="data row1 col0" > Художественный</td>
#                         <td id="T_17126_row1_col1" class="data row1 col1" >1373</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# #### Категория - Возрастная категория

# %%
column_name = 'age_restriction'

render(
    (
        data_wt_duplicate[column_name]
            .value_counts()
            .reset_index(name="count")
            .sort_values(by='count', ascending=False)
    )
)



display(
    md(
        '_**'
        + 'Проблем нет. Идем дальше!'
        + '**_'
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <style  type="text/css" >
# </style><table id="T_efbfa_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_efbfa_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_efbfa_row0_col0" class="data row0 col0" >«16+» - для детей старше 16 лет</td>
#                         <td id="T_efbfa_row0_col1" class="data row0 col1" >2520</td>
#             </tr>
#             <tr>
#                         <th id="T_efbfa_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_efbfa_row1_col0" class="data row1 col0" >«12+» - для детей старше 12 лет</td>
#                         <td id="T_efbfa_row1_col1" class="data row1 col1" >1490</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# #### Категория - Жанр Фильма

# %%
column_name = 'genres'

render(
    (
        data_wt_duplicate[column_name]
            .value_counts()
            .reset_index(name="count")
            .sort_values(by='index', ascending=True)
            .head(10)
    )
    , name="Более 700 жанров"
)

display(
    md(
        '**_'
        + 'Здесь ситуация другая. Мы можем многие категории объединить в общий жанр, `только аниме`, `только ужасы` и т.д. Приведем к такому виду.'.format(column_name)
        + '<br>'
        + 'Будем считать, что первый жанр является основным, а остальные вспомогательные'
        + '_**'
    )
)

try:
    del data_wt_duplicate["main_" + column_name]
except:
    pass

data_wt_duplicate.insert(
    data_wt_duplicate.columns.get_loc(column_name) + 1, 
    "main_" + column_name, 
    data_wt_duplicate[column_name].apply(main_value)
)

#data_wt_duplicate[column_name + "_general"] = data_wt_duplicate[column_name].apply(main_value)


render(
    (
        data_wt_duplicate["main_" + column_name]
            .value_counts()
            .reset_index(name="count")
            .sort_values(by='count', ascending=False)
    )
    , marker=[
        ['index', ['nan']]
    ]
)

display(
    md(
        '_**'
        + 'К сожалению есть жанр - `"nan"`, это там, где есть пропуски. Их много и в ручную не целесообразно обрабатывать.<br>'
        + 'Но это всеравно отличный результат! Посмотрим на эти данные'
        + '**_'
    )
)

render(data_wt_duplicate.query('{} == "nan"'.format("main_" + column_name)).head(10))

render('Много разных интересных фильмов и жанров, но их слишком много. Пока оставим так')

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <style  type="text/css" >
# </style><table id="T_41157_" class="table_border position_center_header" data-title="Более 700 жанров" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_41157_level0_row0" class="row_heading level0 row0" >417</th>
#                         <td id="T_41157_row0_col0" class="data row0 col0" >аниме,мультфильм</td>
#                         <td id="T_41157_row0_col1" class="data row0 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_41157_level0_row1" class="row_heading level0 row1" >107</th>
#                         <td id="T_41157_row1_col0" class="data row1 col0" >аниме,мультфильм,боевик</td>
#                         <td id="T_41157_row1_col1" class="data row1 col1" >10</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# #### Вывод по столбцам категорий

# %% [markdown]
# _**<b>Что мы узнали:</b><br><br>
# *` ` Самый популярный тип кино `Художественный - 5303`, за ним `Анимационный - 771` и закрывает тройку `Документальный - 283`*<br>
# *` ` Чаще всего это кино для детей `старше 16 лет - 2521`, для детей `старше 12 лет` чуть меньше` - 1491`, а `для совершеннолетних - 1438`*<br>
# *` ` И на удивление всем больше всего нравится `жанр драма c 1560`, удивило ее значение, за ней `жанр комедия c 647`, куда наша жизнь без юмора, и закрывает тройку `жанр боевик с 522`<br><br>
# К сожалению `есть пропуски` и их количество поставило их на второе место нашего топа - `целых 968`*<br>
# *` ` Почти во всех столбцах категорий, есть проблемы написания категории, дубликаты. Лично я бы использовал идентификатор категории, а не ее написание в общей таблице. Этим было бы проще управлять*<br>**_
#
# <div class="alert alert-warning">
#     <p>Какое оно идеальное кино?<br></p>
#     <br>
#     <p><b>Это художественный фильм в жанре драма для лиц старше 16 лет.</b></p>
#     <p>Погрустили и идем дальше</p>
# </div>
#
# <br> [| Назад к Содержанию](#Содержание)<hr>

# %% [markdown]
# ### Шаг. Проверьте количественные значения
#
# - Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_budget" aria-expanded="false" aria-controls="collapseHint_budget">Подсказка</button>
#         </div>
#         <div id="collapseHint_budget" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на описание столбца <code>budget</code>. Как этот столбец соотносится с двумя другими: <code>refundable_support</code> и <code>nonrefundable_support</code>?
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# По описанию столбца "budget" в него уже включен объем государственной поддержки.

# %% [markdown]
# Также можем построить диаграммы и визально посмотреть на данные

# %% [markdown]
# #### Столбец refundable_support

# %%
column_name = 'refundable_support'

item_type = 'объём возвратных средств государственной поддержки'
item_init = 'руб'

render('Столбец "{}" - {}'.format(column_name, item_type))

render(data_wt_duplicate[column_name].describe())
render('Есть нулевые значения... Ой, как не хорошо... Уберем из рассчетов нулевые значения')

new_data = data_wt_duplicate[data_wt_duplicate[column_name] > 0][column_name]

render(new_data.describe())

cell_min = new_data.min()
cell_max = new_data.max()
cell_median = new_data.median()
cell_mean =   new_data.mean()

(
    new_data
        .sort_values()
        .plot(
            title = 'Столбец "{}"'.format(column_name),
            
            y=column_name, 
            kind = 'hist', 
            bins = 20, 
            range=(cell_min, cell_max),
            grid=True,
        )
        .set(
            xlabel = 'Сумма',
            ylabel = 'Количество'
        )
)

plt.show()


render(
    data_wt_duplicate.query('{} == @cell_min'.format(column_name)).head(1),
    name='Фильм, где минимальный ' + item_type
)

render(
    data_wt_duplicate.query('{} == @cell_max'.format(column_name)).head(1),
    name='Фильм, где максимальный ' + item_type
)

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "**_" 
        + "<br>"
        + "**_"
        + "Что ж, Фильм С Джеки Чаном и Арнольдом Шварценеггером `'Тайна Печати Дракона'` потребовал больше средств государственной поддержки, аж в 180 млн руб. Я сначала не поверил, но после проверки в интернете - это оказалось правдой."
        + "А что по поводу `'Сдается дом со всеми неудобствами'` помощь гос поддержки составила - 35 млн руб, наверное, весь гонарар пошел на отличную игру Светланы Ходченковой"
        + "_**"
        + "<br><br>"
        + "Любопытный факт: оба фильма зрители оценили в рейтинг 5.8 и оба поддержал Фонд кино."
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <p class="value" ><code>Столбец "refundable_support" - объём возвратных средств государственной поддержки</code></p>
# <style  type="text/css" >
# </style><table id="T_51b0e_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >refundable_support</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_51b0e_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_51b0e_row0_col0" class="data row0 col0" >332.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_51b0e_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_51b0e_row1_col0" class="data row1 col0" >11864457.831325</td>
#             </tr>
#             <tr>
#                         <th id="T_51b0e_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# #### Столбец nonrefundable_support

# %%
column_name = 'nonrefundable_support'

item_type = 'объём невозвратных средств государственной поддержки'
item_init = 'руб'

render('Столбец "{}" - {}'.format(column_name, item_type))

render(data_wt_duplicate[column_name].describe())
render('Есть нулевые значения... Ой, как не хорошо... Уберем из рассчетов нулевые значения')

new_data = data_wt_duplicate[data_wt_duplicate[column_name] > 0][column_name]

render(new_data.describe())

cell_min = new_data.min()
cell_max = new_data.max()
cell_median = new_data.median()
cell_mean =   new_data.mean()

(
    new_data
        .sort_values()
        .plot(
            title = 'Столбец "{}"'.format(column_name),
            
            y=column_name, 
            kind = 'hist', 
            bins = 20, 
            range=(cell_min, cell_max),
            grid=True,
        )
        .set(
            xlabel = 'Сумма',
            ylabel = 'Количество'
        )
)

plt.show()


render(
    data_wt_duplicate.query('{} == @cell_min'.format(column_name)).head(1),
    name='Фильм, где минимальный ' + item_type
)

render(
    data_wt_duplicate.query('{} == @cell_max'.format(column_name)).head(1),
    name='Фильм, где максимальный ' + item_type
)

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "**_" 
        + "<br>"
        + "**_"
        + "`33 млн руб` гос поддержки на съемки о величайшем озере Мира - `'Байкал - Сердце мира 3D'`! Кстати: <b>Английскую версию озвучил сам Леонардо Ди Каприо!</b>"
        + "<br><br>"
        + "3 секунды и выигрыш сборной СССР по баскетболу в фильме -  `'Движение вверх'` Фонд Кино поддержал - `400 млн руб`, только посмотрите на этот состав актеров: Машков, Смоляков, Башаров, Гармаш"
        + '<br>'
        + 'И не зря, фильм окупился и показал лучшие `кассовые сборы 1678 млд руб` - за всю историю отечественного кино!'
        + "_**"
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <p class="value" ><code>Столбец "nonrefundable_support" - объём невозвратных средств государственной поддержки</code></p>
# <style  type="text/css" >
# </style><table id="T_377aa_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >nonrefundable_support</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_377aa_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_377aa_row0_col0" class="data row0 col0" >332.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_377aa_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_377aa_row1_col0" class="data row1 col0" >48980988.891566</td>
#             </tr>
#             <tr>
#                         <th id="T_377aa_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# #### Столбец budget

# %%
column_name = 'budget'

item_type = 'общий бюджет фильма'
item_init = 'руб'

render('Столбец "{}" - {}'.format(column_name, item_type))

render(data_wt_duplicate[column_name].describe())
render('Есть нулевые значения... Ой, как не хорошо... Уберем из рассчетов нулевые значения')

new_data = data_wt_duplicate[data_wt_duplicate[column_name] > 0][column_name]

render(new_data.describe())

cell_min = new_data.min()
cell_max = new_data.max()
cell_median = new_data.median()
cell_mean =   new_data.mean()

(
    new_data
        .sort_values()
        .plot(
            title = 'Столбец "{}"'.format(column_name),
            
            y=column_name, 
            kind = 'hist', 
            bins = 20, 
            range=(cell_min, cell_max),
            grid=True,
        )
        .set(
            xlabel = 'Сумма',
            ylabel = 'Количество'
        )
)

plt.show()


render(
    data_wt_duplicate.query('{} == @cell_min'.format(column_name)).head(1),
    name='Фильм, где минимальный ' + item_type
)

render(
    data_wt_duplicate.query('{} == @cell_max'.format(column_name)).head(1),
    name='Фильм, где максимальный ' + item_type
)

render('Нужно еще проверить на ошибки. Может Бюджет меньше, чем суммарная гос поддержка?')
render(
    data_wt_duplicate.query('budget < refundable_support or budget < nonrefundable_support'.format(column_name))
)

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "**_" 
        + "<br>"
        + "**_"
        + "Честно говоря, я ничего не слышал про фильм `'Я умею вязать'` и его провальные сборы - 801370 рублей. Увы.</b>"
        + "<br>"
        + "Ого, бюджет `Дуxless 2` = 0, хотя из госбюджета было потрачено не плохие деньги, явно, что в данных ошибка!"
        +"<br>"
        + "И снова у нас в лидерах самый многобюджетный условно 'руский' фильм - `'Тайна Печати Дракона'`" 
        + "_**"
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <p class="value" ><code>Столбец "budget" - общий бюджет фильма</code></p>
# <style  type="text/css" >
# </style><table id="T_40831_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >budget</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40831_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_40831_row0_col0" class="data row0 col0" >332.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_40831_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_40831_row1_col0" class="data row1 col0" >127229716.683735</td>
#             </tr>
#             <tr>
#                         <th id="T_40831_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_40831_row2_col0" class="data row2 col0" >188588333.115158</td>
# ...

# %% [markdown]
# #### Столбец box_office

# %%
column_name = 'box_office'

item_type = 'сборы в рублях'
item_init = 'руб'

render('Столбец "{}" - {}'.format(column_name, item_type))

render(data_wt_duplicate[column_name].describe())
render('Есть нулевые значения... Ой, как не хорошо... Уберем из рассчетов нулевые значения')

new_data = data_wt_duplicate[data_wt_duplicate[column_name] > 0][column_name]

render(new_data.describe())

cell_min = new_data.min()
cell_max = new_data.max()
cell_median = new_data.median()
cell_mean =   new_data.mean()

(
    new_data
        .sort_values()
        .plot(
            title = 'Столбец "{}"'.format(column_name),
            
            y=column_name, 
            kind = 'hist', 
            bins = 20, 
            range=(cell_min, cell_max),
            grid=True,
        )
        .set(
            xlabel = 'Сумма',
            ylabel = 'Количество'
        )
)

plt.show()


render(
    data_wt_duplicate.query('{} == @cell_min'.format(column_name)).head(1),
    name='Фильм, где минимальный ' + item_type
)

render(
    data_wt_duplicate.query('{} == @cell_max'.format(column_name)).head(1),
    name='Фильм, где максимальный ' + item_type
)

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "**_" 
        + "<br>"
        + "**_"
        + "Сомневаюсь, что сборы могут составлять 40 рублей, а это фильм `'Жестокий романс'`, фильм с рейтингов 8.1! Явно в данных ошибка!</b>"
        + "<br><br>"
        + "`'Холоп'`! Нет, это не слова Ивана Васильевича, а фильм с гос поддержкой и просто отличными кассовыми сборами!" 
        + "_**"
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <p class="value" ><code>Столбец "box_office" - сборы в рублях</code></p>
# <style  type="text/css" >
# </style><table id="T_eb3e2_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >box_office</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eb3e2_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_eb3e2_row0_col0" class="data row0 col0" >3131.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_eb3e2_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_eb3e2_row1_col0" class="data row1 col0" >77138102.968742</td>
#             </tr>
#             <tr>
#                         <th id="T_eb3e2_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# #### Столбец ratings

# %%
column_name = 'ratings'

item_type = 'рейтинг фильма на КиноПоиске'
item_init = ''

render('Столбец "{}" - {}'.format(column_name, item_type))

render(data_wt_duplicate[column_name].describe())
render('Есть нулевые значения... Ой, как не хорошо... Уберем из рассчетов нулевые значения')

new_data = data_wt_duplicate[data_wt_duplicate[column_name] > 0][column_name]

render(new_data.describe())

cell_min = new_data.min()
cell_max = new_data.max()
cell_median = new_data.median()
cell_mean =   new_data.mean()

(
    new_data
        .sort_values()
        .plot(
            title = 'Столбец "{}"'.format(column_name),
            
            y=column_name, 
            kind = 'hist', 
            bins = 20, 
            range=(cell_min, cell_max),
            grid=True,
        )
        .set(
            xlabel = 'Сумма',
            ylabel = 'Количество'
        )
)

plt.show()


render(
    data_wt_duplicate.query('{} == @cell_min'.format(column_name)).head(1),
    name='Фильм, где минимальный ' + item_type
)

render(
    data_wt_duplicate.query('{} == @cell_max'.format(column_name)).head(1),
    name='Фильм, где максимальный ' + item_type
)

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "**_" 
        + "<br>"
        + "**_"
        + "Очень удивительно! 1 балл, серьезно? `'Взломать блогеров'` Про Блоггеров? Бекмамбетов? И все равно 1 балл? мдааа...</b>"
        + "<br><br>"
        + "А вот в лидерах фильм `'Прошлое'` просто с высоким рейтингом 9.9, даже переплюнули фильм `Зеленая Миля`. Но после проверки на Кинопоиск, оказалось, что у этого  фильма рейтинг - `6.7`, и это явно не очепятка, точно в данных `рейтинг` ошибка!" 
        + "_**"
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <p class="value" ><code>Столбец "ratings" - рейтинг фильма на КиноПоиске</code></p>
# <style  type="text/css" >
# </style><table id="T_26b12_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ratings</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_26b12_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_26b12_row0_col0" class="data row0 col0" >6803.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_26b12_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_26b12_row1_col0" class="data row1 col0" >5.553182</td>
#             </tr>
#             <tr>
#                         <th id="T_26b12_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_26b12_row2_col0" class="data row2 col0" >2.480124</td>
# ...

# %% [markdown]
# ### Шаг. Добавьте новые столбцы

# %% [markdown]
# - Создайте столбец с информацией о годе проката. Выделите год из даты премьеры фильма.

# %% [markdown]
# #### Столбец show_start_year

# %%
try:
    del data_wt_duplicate['show_start_year']
except:
    pass


data_wt_duplicate.insert(
    data_wt_duplicate.columns.get_loc('show_start_date') + 1, 
    'show_start_year', 
    data_wt_duplicate['show_start_date'].dt.year
)

render(data_wt_duplicate.head(1))

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <style  type="text/css" >
# #T_d1c62_row0_col10,#T_d1c62_row0_col11,#T_d1c62_row0_col12,#T_d1c62_row0_col13,#T_d1c62_row0_col17{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  red;
# ...

# %% [markdown]
# - Создайте два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_2" aria-expanded="false" aria-controls="collapseHint_2">Подсказка</button>
#         </div>
#         <div id="collapseHint_2" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Чтобы создать такие столбцы, лучше всего использовать собственную функцию. Эту функцию можно применить к двум столбцам сразу.
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# #### Столбцы show_start_year и main_genres

# %%
try:
    del data_wt_duplicate['main_director']
except:
    pass

data_wt_duplicate.insert(
    data_wt_duplicate.columns.get_loc('director') + 1, 
    'main_director', 
    data_wt_duplicate['director'].apply(main_value)
)

render('Столбец "main_genres" мы создале ранее, при объединении жанра в общую группу')

render(data_wt_duplicate.head(1))

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <p class="value" ><code>Столбец "main_genres" мы создале ранее, при объединении жанра в общую группу</code></p>
# <style  type="text/css" >
# #T_e0180_row0_col11,#T_e0180_row0_col12,#T_e0180_row0_col13,#T_e0180_row0_col14,#T_e0180_row0_col18{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  red;
# ...

# %% [markdown]
# - Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %% [markdown]
# #### Доля государственной поддержки от общего бюджета фильма

# %%
try:
    del data_wt_duplicate['part_support_of_budget']
except:
    pass

data_wt_duplicate.insert(
    data_wt_duplicate.columns.get_loc('budget') + 1, 
    'part_support_of_budget', 
    ((data_wt_duplicate['refundable_support'] + data_wt_duplicate['nonrefundable_support']) / data_wt_duplicate['budget'])*100
)

render('Т.к. в процессе вычислений может быть infinity, проверим структуру столбца "part_support_of_budget"')

render(data_wt_duplicate["part_support_of_budget"].describe())

render('Как мы видим у нас все-таки есть деления на 0')
render('Заменяем infinity на nan')


data_wt_duplicate['part_support_of_budget'] = data_wt_duplicate['part_support_of_budget'].replace(float('inf'), np.nan)

render(data_wt_duplicate.query('budget > 0').head(10))


display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <p class="value" ><code>Т.к. в процессе вычислений может быть infinity, проверим структуру столбца "part_support_of_budget"</code></p>
# <style  type="text/css" >
# #T_f5dec_row2_col0{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  red;
#         }</style><table id="T_f5dec_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >part_support_of_budget</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5dec_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_f5dec_row0_col0" class="data row0 col0" >332.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f5dec_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_f5dec_row1_col0" class="data row1 col0" >inf</td>
#             </tr>
# ...

# %% [markdown]
# ## Шаг. Проведите исследовательский анализ данных

# %% [markdown]
# - Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах.

# %% [markdown]
# ### Количество фильмов в прокате по годам

# %%
item_type = 'количество фильмов по годам'
item_init = ''

data_all_count_by_year = (
        data_wt_duplicate
        .query('show_start_year > 0')['show_start_year']
        .value_counts()
        .reset_index(name="all_count")
        .sort_values(by='index', ascending=True)
    )



data_count_by_year = (
        data_wt_duplicate
        .query('show_start_year > 0 & box_office > 0')['show_start_year']
        .value_counts()
        .reset_index(name="box_office_count")
        .sort_values(by='index', ascending=True)
    )



data_count_by_year = data_count_by_year.merge(data_all_count_by_year, on='index', how='right')

data_count_by_year['part_of_total_count'] = data_count_by_year['box_office_count']/data_count_by_year['box_office_count'].sum() * 100
data_count_by_year['part_of_total_count_by_box_office'] = data_count_by_year['box_office_count']/data_count_by_year['all_count'] * 100


render(
    data_count_by_year,
    format=[
        [['part_of_total_count', 'part_of_total_count_by_box_office'], '{:.2f}%']
    ],
    name=item_type + '; общее количество: ' + str(data_count_by_year['box_office_count'].sum())
)

cell_min =    data_count_by_year['box_office_count'].min()
cell_max =    data_count_by_year['box_office_count'].max()
cell_median = data_count_by_year['box_office_count'].median()
cell_mean =   data_count_by_year['box_office_count'].mean()


render(data_count_by_year['box_office_count'].describe())

(
    data_count_by_year
        .plot(
            kind='line',
            
            style='o-',
            
            y='box_office_count',
            x='index',
            
            figsize=(16,8),
            
            grid=True,
            
            title=item_type
        )
        .set(
                xlabel = 'Год',
                ylabel = 'Количество Фильмов в год'
            )
)

plt.show()

(
    data_count_by_year
        .plot(
            kind='pie',
            
            y='box_office_count',
            ylabel='',
            labels=data_count_by_year['index'],
            
            figsize=(16,8),
            
            title=item_type,
            
            subplots=True,
            autopct='%1.2f%%',
            counterclock=False, 
            shadow=True
        )
)

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

(
    data_count_by_year
        .plot(
            kind='barh',
            
            y='part_of_total_count_by_box_office',
            x='index',
            
            ylabel='',
            
            figsize=(16,8),
            
            title='Доля фильмов с пракатом от общего количества фильмов',
        ).set(
                ylabel = 'Год',
                xlabel = 'доля в %'
            )
)

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "**_" 
        + "<br>"
        + "**_"
        + "Очень мало фильмов выходило `в 2010 году`, а пик пришелся `в 2016 и в 2019 году`. Что там такое выходило? Ааа... "
        + "<br>"
        + "Мстители: Финал, Джентельмены, Джокер, Человек-Паук: Вдали от дома, Паразиты..."
        + "<br><br>"
        + "Хит за хитом... Верните мой 2019 :-)"
        + "<br><br>"
        + "Как мы видим доля прокатных фильмов самая высокая была `в 2017 году - 71.40%`, а самая низкая `в 2010 году - 12.66%`"
        + "_**"
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <style  type="text/css" >
# </style><table id="T_dd1d1_" class="table_border position_center_header" data-title="количество фильмов по годам; общее количество: 3107" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >box_office_count</th>        <th class="col_heading level0 col2" >all_count</th>        <th class="col_heading level0 col3" >part_of_total_count</th>        <th class="col_heading level0 col4" >part_of_total_count_by_box_office</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd1d1_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dd1d1_row0_col0" class="data row0 col0" >2010</td>
#                         <td id="T_dd1d1_row0_col1" class="data row0 col1" >97</td>
#                         <td id="T_dd1d1_row0_col2" class="data row0 col2" >766</td>
# ...

# %% [markdown]
# - С помощью сводной таблицы посчитайте среднюю и медианную сумму сборов для каждого года.

# %% [markdown]
# #### Средняя и медианная сумму сборов для каждого года

# %%
index_name           = 'show_start_year'
title_parameter_name = 'Сумма сборов'

column_name          = 'box_office'
agg_func_list        = ['count', 'median', 'mean', 'min', 'max']

title_name           = 'Зависимость сборов по годам'

item_type            = 'сумма сборов'
item_init            = 'руб'


pivot = (
    data_wt_duplicate
        .query('{} > 0'.format(column_name))
        .pivot_table(
            index   = index_name, 
            values  = column_name, 
            aggfunc = agg_func_list
        )
)

pivot.columns = agg_func_list

render(pivot)

render(pivot.describe())

cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['median'].median()
cell_mean =   pivot['median'].mean()

(
    pivot
        .query('count > 0')
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            ylabel=title_parameter_name, 
            xlabel='Год',

            ylim=(cell_min, cell_max),

            grid=True
        )
)



#Нарисуем диаграмму
plt.show()

#Получим общие сборы по годам
data_sum_by_year = (
        data_wt_duplicate
        .query('{} > 0 & box_office > 0'.format(index_name))
        .groupby(index_name)['box_office'].sum()
        .reset_index()
        .sort_values(by=index_name, ascending=True)
    )

render(data_sum_by_year)

(
    data_sum_by_year
        .plot(
            kind='pie',
            
            y='box_office',
            ylabel='',
            labels=data_sum_by_year[index_name],
            
            figsize=(16,8),
            
            title=item_type,
            
            subplots=True,
            autopct='%1.2f%%',
            counterclock=False, 
            shadow=True
        )
)

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

min_year            = '2010'
min_year_box_office = data_sum_by_year['box_office'].min()
max_year            = '2019'
max_year_box_office = data_sum_by_year['box_office'].max()


display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "**_" 
        + "<br>"
        + "**_"
        + "Очень любопытно, что `в 2010 году` были на столько малые сборы в России, хотя в то время выходили отличные шедевры:"
        + "<br>"
        + "Начало Нолана с Ди Каприо, Как приручить дракона, Гарри Поттер и Дары Смерти: Часть 1, Железный Человек2 и т.д."
        + "<br><br>"
        + "Хит за хитом. надо проверить на кинопоиске сумму сборов, мне кажется в этих данных явная ошибка, нужно будет сказать коллегам"
        + "<br><br>"
        + "По тому что минимальные сборы уж точно не могут быть 40 рублей. Вы что)))"
        + "<br><br>"
        + "Минимальные сборы по годам были в {} и составляла: {} рублей, а самые максимальные сборы в {} и составили: {} рублей".format(min_year,min_year_box_office,max_year,max_year_box_office)
        + "_**"
    )
)

render(
    data_wt_duplicate
        .query('0 < {} < 1000'.format(column_name))
        .head(20)
    , name='ТОП 20, где сборы меньше 1000 рублей'
)

render('Есть предположение, что в данной статистике указаны рубли времен СССР. т.е.в среднем в 100 раз нужно увеличивать сборы. Так что эти данные некорректно сравнивать, но мы молодцы, что это выяснили :-)')

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <style  type="text/css" >
# </style><table id="T_1174e_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >max</th>    </tr>    <tr>        <th class="index_name level0" >show_start_year</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1174e_level0_row0" class="row_heading level0 row0" >2010</th>
#                         <td id="T_1174e_row0_col0" class="data row0 col0" >97</td>
#                         <td id="T_1174e_row0_col1" class="data row0 col1" >1916.000000</td>
# ...

# %% [markdown]
# - Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %% [markdown]
# #### Суммы сборов по годам и возрастному ограничению

# %%
df = data_wt_duplicate.query('(0 < box_office) & (2015 <= show_start_year <= 2019)')

pivot = (
    df
        .groupby(["show_start_year", "age_restriction"])["box_office"]
        .sum()
        .reset_index()
)

render(
    pivot.loc[pivot.groupby("show_start_year")["box_office"].idxmax()]
)

(
    pivot.loc[pivot.groupby("show_start_year")["box_office"].idxmax()]
        .plot(
            y='box_office',
            x='show_start_year',
            
            kind='barh',
            
            figsize=(16,8),
            
            grid=True
        )
        .set(
                xlabel = 'Сумма сборов в год',
                ylabel = 'Год'
            )
)

plt.show()


box_office_by_age_restriction = (
    df
        .pivot_table(
            index='show_start_year',
            columns = 'age_restriction',
            values = 'box_office',
            aggfunc = 'sum'
        )
)


render(
    box_office_by_age_restriction
    , marker=[
        ['«0+» - для любой зрительской аудитории', 'max_min'],
        ['«6+» - для детей старше 6 лет',          'max_min'],
        ['«12+» - для детей старше 12 лет',        'max_min'],
        ['«16+» - для детей старше 16 лет',        'max_min'],
        ['«18+» - запрещено для детей',            'max_min'],
    ]
)

print('Построим графики для каждой категории')

xlabel = 'Год'
ylabel = 'Сумма сборов в год'

xclmn = 'show_start_year'
yclmn = 'box_office'


#'«0+» - для любой зрительской аудитории'
catg_name = '«0+» - для любой зрительской аудитории'

(
    box_office_by_age_restriction[catg_name]
        .plot(x=xclmn,y=yclmn,style='o-',title=catg_name,grid=True)
        .set(xlabel=xlabel,ylabel=ylabel)
)
plt.xticks(range(2015, 2020, 1))
plt.show()


#«6+» - для детей старше 6 лет
catg_name = '«6+» - для детей старше 6 лет'

(
    box_office_by_age_restriction[catg_name]
        .plot(x=xclmn,y=yclmn,style='o-',title=catg_name,grid=True)
        .set(xlabel=xlabel,ylabel=ylabel)
)
plt.xticks(range(2015, 2020, 1))
plt.show()


#«12+» - для детей старше 12 лет
catg_name = '«12+» - для детей старше 12 лет'

(
    box_office_by_age_restriction[catg_name]
        .plot(x=xclmn,y=yclmn,style='o-',title=catg_name,grid=True)
        .set(xlabel=xlabel,ylabel=ylabel)
)
plt.xticks(range(2015, 2020, 1))
plt.show()


#«16+» - для детей старше 16 лет
catg_name = '«16+» - для детей старше 16 лет'

(
    box_office_by_age_restriction[catg_name]
        .plot(x=xclmn,y=yclmn,style='o-',title=catg_name,grid=True)
        .set(xlabel=xlabel,ylabel=ylabel)
)
plt.xticks(range(2015, 2020, 1))
plt.show()


#«18+» - запрещено для детей
catg_name = '«18+» - запрещено для детей'

(
    box_office_by_age_restriction[catg_name]
        .plot(x=xclmn,y=yclmn,style='o-',title=catg_name,grid=True)
        .set(xlabel=xlabel,ylabel=ylabel)
)
plt.xticks(range(2015, 2020, 1))
plt.show()


#Общий график
catg_name = 'Общий график'

(
    box_office_by_age_restriction
        .sort_values(by=['show_start_year'], ascending=False)
        .plot(title=catg_name,grid=True,kind='barh',figsize=(16,8))
        .set(ylabel=xlabel,xlabel=ylabel)
)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()


display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` Как мы видим каждый год возрастная категория разная, но четко прослеживается лидер - `«16+» - для детей старше 16 лет`*"
        + "<br>"
        + "*` ` Также обратили внимание, что самые кассовые сборы были `в 2017 году`, но мы то помним, что тогда вышел фильм `'Движение вверх'`, который является самым кассовым фильмом по сборам за всю историю отечественного кино!*"
        + "**_" 
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <style  type="text/css" >
# </style><table id="T_5a16c_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >show_start_year</th>        <th class="col_heading level0 col1" >age_restriction</th>        <th class="col_heading level0 col2" >box_office</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5a16c_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_5a16c_row0_col0" class="data row0 col0" >2015</td>
#                         <td id="T_5a16c_row0_col1" class="data row0 col1" >«12+» - для детей старше 12 лет</td>
#                         <td id="T_5a16c_row0_col2" class="data row0 col2" >13616082008.909998</td>
#             </tr>
#             <tr>
#                         <th id="T_5a16c_level0_row1" class="row_heading level0 row1" >7</th>
# ...

# %% [markdown]
# ## Шаг. Исследуйте фильмы, которые получили государственную поддержку
#
# На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг.

# %% [markdown]
# ### Анализ фильмов с гос поддержкой

# %%
df = data_wt_duplicate.query('(0 < box_office) & (0 < refundable_support or 0 < nonrefundable_support) & (0 < budget)')[['title', 'show_start_year', 'part_support_of_budget', 'budget', 'ratings', 'age_restriction', 'box_office']]

#Получим профит от проката фильма
df['profit'] = df['box_office'] - df['budget']

render(
    df
        .sort_values(by='ratings', ascending=False)
        .head(20)
    , name='ТОП-20 лучших фильмов с высоким рейтингом'
    , format='{:.1f}'
    , marker=[
        ['profit', ['<', 0]]
    ]
)


render(
    df
        .sort_values(by='part_support_of_budget', ascending=False)
        .head(20)
    , name='ТОП-20 лучших фильмов с высокой гос поддержкой'
    , format='{:.1f}'
    , marker=[
        ['profit', ['<', 0]]
    ]
)

render(
    df
        .sort_values(by='box_office', ascending=False)
        .head(5)
    , name='ТОП-5 лучших фильмов с высокой окупаемостью'
    , format='{:.1f}'
    , marker=[
        ['profit', ['<', 0]]
    ]
)



catg_name = 'Фильмы с высокой окупаемостью'
xlabel = 'Окупаемость Фильма'
ylabel = 'Рейтинг'
(
    df
        .plot(x='ratings',y='profit',style='*',title=catg_name,grid=True,figsize=(16,8))
        .set(ylabel=xlabel,xlabel=ylabel)
)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()



catg_name = 'Фильмы с высоким бюджетом'
xlabel = 'Бюджет Фильма'
ylabel = 'Рейтинг'
(
    df
        .plot(x='ratings',y='budget',style='*',title=catg_name,grid=True,figsize=(16,8))
        .set(ylabel=xlabel,xlabel=ylabel)
)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()



catg_name = 'Фильмы с гос поддержкой'
xlabel = 'Процент участия гос поддержки'
ylabel = 'Рейтинг'
(
    df
        .plot(x='ratings',y='part_support_of_budget',style='*',title=catg_name,grid=True,figsize=(16,8))
        .set(ylabel=xlabel,xlabel=ylabel)
)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()



display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` Как показал отчет: `высокий рейтинг не говорит о том, что фильм окупился`. Вот так*"
        + "<br>"
        + "*` ` Мы видим, что даже с 65% гос поддержкой и высоким рейтингом и хорошим бюджетом окупаемость просто отрицательная и каждый год похожая ситуация.*"
        + "<br>"
        + "*` ` И вот мы подошли к топу лучших фильмов по окупаемости. Как оказалось, коммерческие фильмы с хорошим бюджетом и с минимальной гос поддержкой имеют более высокую окупаемость и эти фильмы имеют больше, чем средний рейтинг - `7.0`*"
        + "<br>"
        + "*` ` Все эти фильмы в большинстве случаев имеют возрастное ограничение - `«12+» - для детей старше 12 лет`*"
        + "**_" 
    )
)

display(md("<br> [| Назад к Содержанию](#Содержание)<hr>"))
# Out:
# <style  type="text/css" >
# #T_c7695_row0_col7,#T_c7695_row1_col7,#T_c7695_row3_col7,#T_c7695_row5_col7,#T_c7695_row6_col7,#T_c7695_row7_col7,#T_c7695_row8_col7,#T_c7695_row9_col7,#T_c7695_row10_col7,#T_c7695_row11_col7,#T_c7695_row12_col7,#T_c7695_row13_col7,#T_c7695_row14_col7,#T_c7695_row15_col7,#T_c7695_row16_col7,#T_c7695_row17_col7,#T_c7695_row19_col7{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  #0d64a1;
# ...

# %% [markdown]
# ## Шаг. Напишите общий вывод

# %% [markdown]
# **О чем мы узнали?**
#
# - В предоставленных данных есть пропуски и есть ошибки, о них надо сообщить коллегам.
#
# - Мы объединили данные с данными о прокате, чтобы видеть всю картину
#
# - Посмотрели на структуру данных и рассмотрели на данные каждого столбца, где есть пропуски.
#
# - Преобразовали int64 -> int32, float64 -> float32, и из object в datatime
#
# - Мы исправляли явные и неявные дубликаты и сравнивали данные с сайтом Кинопоиск и с сайтой Министерства Культуры РФ - реест прокатных удостоверений
#
# - Изучили кактегории и исправили их названия, Изучили влияние категорий на прокат, объединили категории жанр в общую категорию
#
# - Проверили столбцы объёма возвратных и невозвратных средств, а также изучили бюджет фильмов и сборы в рублях
#
# - Добавили столбец с годом выпуска, который получили из даты выхода в прокат
#
# - Добавили столбец главного режиссера фильма
#
# - Изучили самый дорогой фильм в прокате и самый дешевый по сборам
#
# - Посмотрели долю гос поддержки в каждом фильме
#
# - Узнали, что очень мало фильмов выходило в 2011 году, а пик пришелся в 2019 году
#
# - Обратили внимание, что самые кассовые сборы были в 2017 году, но мы то помним, что тогда вышел фильм 'Движение вверх' - сымый кассовый фильм за всю историю отечественного кинопроката
#
# - А также выяснили, что самый большой объем государственных средств был предоставлен для фильма с известными актерами  Джеки Чаном и Арнольдом Шварценеггером 'Тайна Печати Дракона', гос поддержка составила аж 180000000 рублей возвратных средств
#
# - И в итоге узнали, что самый идеальный фильм это - **художественный фильм в жанре драма для лиц старше 16 лет!**
#
# **_Я предлагаю обратить внимание на жанр Драма с возрастным ограничением +12. И использовать госбюджет не больше 20%. Это будет золотая середина :-)<br>
# Для сравнения предложил обратить внимание на фильмы "Движение вверх", "Холоп", "Последний богатырь"_**
#
# Хотелось бы закончить цитатой, которую мы выяснили в ходе последнего исследования - **Высокий рейтинг не говорит о том, что фильм окупился, да он может провалился в прокате, но зато он оставил свой след в истории!**
#
#
# <br> [| Назад к Содержанию](#Содержание)<hr>
