# %% [markdown]
# .

# %% [markdown]
#  ![image-4.png](attachment:image-4.png)
#
#  # Исследование объявлений о продаже квартир

# %% [markdown]
# **_В вашем распоряжении данные сервиса `Яндекc Недвижимость` — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. `Ваша задача — установить параметры`. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.<br><br>
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма._**

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Структура-и-типы-данных-в-колонках" data-toc-modified-id="Структура-и-типы-данных-в-колонках-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Структура и типы данных в колонках</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-проблемных-столбцов" data-toc-modified-id="Анализ-проблемных-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ проблемных столбцов</a></span><ul class="toc-item"><li><span><a href="#Столбец-[&quot;first_day_exposition&quot;]" data-toc-modified-id="Столбец-[&quot;first_day_exposition&quot;]-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Столбец ["first_day_exposition"]</a></span></li><li><span><a href="#Столбец-[&quot;ceiling_height&quot;]" data-toc-modified-id="Столбец-[&quot;ceiling_height&quot;]-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Столбец ["ceiling_height"]</a></span></li><li><span><a href="#Столбец-[&quot;floors_total&quot;]" data-toc-modified-id="Столбец-[&quot;floors_total&quot;]-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Столбец ["floors_total"]</a></span></li><li><span><a href="#Столбец-[&quot;living_area&quot;]" data-toc-modified-id="Столбец-[&quot;living_area&quot;]-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Столбец ["living_area"]</a></span></li><li><span><a href="#Столбец-[&quot;is_apartment&quot;]" data-toc-modified-id="Столбец-[&quot;is_apartment&quot;]-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Столбец ["is_apartment"]</a></span></li><li><span><a href="#Столбец-[&quot;kitchen_area&quot;]" data-toc-modified-id="Столбец-[&quot;kitchen_area&quot;]-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Столбец ["kitchen_area"]</a></span></li><li><span><a href="#Столбец-[&quot;balcony&quot;]" data-toc-modified-id="Столбец-[&quot;balcony&quot;]-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>Столбец ["balcony"]</a></span></li><li><span><a href="#Столбец-[&quot;locality_name&quot;]" data-toc-modified-id="Столбец-[&quot;locality_name&quot;]-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>Столбец ["locality_name"]</a></span></li><li><span><a href="#Столбец-[&quot;airports_nearest&quot;]" data-toc-modified-id="Столбец-[&quot;airports_nearest&quot;]-2.1.9"><span class="toc-item-num">2.1.9&nbsp;&nbsp;</span>Столбец ["airports_nearest"]</a></span></li><li><span><a href="#Столбец-[&quot;cityCenters_nearest&quot;]" data-toc-modified-id="Столбец-[&quot;cityCenters_nearest&quot;]-2.1.10"><span class="toc-item-num">2.1.10&nbsp;&nbsp;</span>Столбец ["cityCenters_nearest"]</a></span></li><li><span><a href="#Столбец-[&quot;parks_around3000&quot;]" data-toc-modified-id="Столбец-[&quot;parks_around3000&quot;]-2.1.11"><span class="toc-item-num">2.1.11&nbsp;&nbsp;</span>Столбец ["parks_around3000"]</a></span></li><li><span><a href="#Столбец-[&quot;parks_nearest&quot;]" data-toc-modified-id="Столбец-[&quot;parks_nearest&quot;]-2.1.12"><span class="toc-item-num">2.1.12&nbsp;&nbsp;</span>Столбец ["parks_nearest"]</a></span></li><li><span><a href="#Столбец-[&quot;ponds_around3000&quot;]" data-toc-modified-id="Столбец-[&quot;ponds_around3000&quot;]-2.1.13"><span class="toc-item-num">2.1.13&nbsp;&nbsp;</span>Столбец ["ponds_around3000"]</a></span></li><li><span><a href="#Столбец-[&quot;ponds_nearest&quot;]" data-toc-modified-id="Столбец-[&quot;ponds_nearest&quot;]-2.1.14"><span class="toc-item-num">2.1.14&nbsp;&nbsp;</span>Столбец ["ponds_nearest"]</a></span></li><li><span><a href="#Столбец-[&quot;days_exposition&quot;]" data-toc-modified-id="Столбец-[&quot;days_exposition&quot;]-2.1.15"><span class="toc-item-num">2.1.15&nbsp;&nbsp;</span>Столбец ["days_exposition"]</a></span></li><li><span><a href="#Столбец-[&quot;last_price&quot;]" data-toc-modified-id="Столбец-[&quot;last_price&quot;]-2.1.16"><span class="toc-item-num">2.1.16&nbsp;&nbsp;</span>Столбец ["last_price"]</a></span></li></ul></li><li><span><a href="#Смотрим-на-результат-изменений" data-toc-modified-id="Смотрим-на-результат-изменений-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Смотрим на результат изменений</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Категория-этажа-квартиры" data-toc-modified-id="Категория-этажа-квартиры-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Категория этажа квартиры</a></span></li><li><span><a href="#Cоотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей" data-toc-modified-id="Cоотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Cоотношение жилой и общей площади, а также отношение площади кухни к общей</a></span></li><li><span><a href="#Смотрим-на-результат-изменений" data-toc-modified-id="Смотрим-на-результат-изменений-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Смотрим на результат изменений</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Площадь,-цена,-число-комнат,-высота-потолков" data-toc-modified-id="Площадь,-цена,-число-комнат,-высота-потолков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Площадь, цена, число комнат, высота потолков</a></span><ul class="toc-item"><li><span><a href="#Площадь-квартиры-в-квадратных-метрах" data-toc-modified-id="Площадь-квартиры-в-квадратных-метрах-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Площадь квартиры в квадратных метрах</a></span></li><li><span><a href="#Цена-на-недвижимость" data-toc-modified-id="Цена-на-недвижимость-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Цена на недвижимость</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Число комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Высота потолков</a></span></li><li><span><a href="#Общий-вывод-по-данным-параметров" data-toc-modified-id="Общий-вывод-по-данным-параметров-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Общий вывод по данным параметров</a></span></li></ul></li><li><span><a href="#Время-продажи-квартиры" data-toc-modified-id="Время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Время продажи квартиры</a></span><ul class="toc-item"><li><span><a href="#Теория" data-toc-modified-id="Теория-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Теория</a></span></li><li><span><a href="#Срок-объявления" data-toc-modified-id="Срок-объявления-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Срок объявления</a></span></li><li><span><a href="#Вывод-по-срокам-объявлений" data-toc-modified-id="Вывод-по-срокам-объявлений-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Вывод по срокам объявлений</a></span></li></ul></li><li><span><a href="#Работаем-с-&quot;хорошим&quot;-источником-данных" data-toc-modified-id="Работаем-с-&quot;хорошим&quot;-источником-данных-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Работаем с "хорошим" источником данных</a></span><ul class="toc-item"><li><span><a href="#Очистка-от-аномалий" data-toc-modified-id="Очистка-от-аномалий-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Очистка от аномалий</a></span></li><li><span><a href="#Анализ-данных-без-учета-аномальных-дней" data-toc-modified-id="Анализ-данных-без-учета-аномальных-дней-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Анализ данных без учета аномальных дней</a></span></li><li><span><a href="#Выводы-по-измененным-данным-по-сроку-объявления-без-аномалий" data-toc-modified-id="Выводы-по-измененным-данным-по-сроку-объявления-без-аномалий-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Выводы по измененным данным по сроку объявления без аномалий</a></span></li></ul></li><li><span><a href="#Факторы,-влияющие-на-стоимость-квартиры" data-toc-modified-id="Факторы,-влияющие-на-стоимость-квартиры-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Факторы, влияющие на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-квадратного-метра-от-общей-площади" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-общей-площади-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Зависимость цены квадратного метра от общей площади</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-количества-комнат" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-количества-комнат-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Зависимость цены квадратного метра от количества комнат</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-этажа(первого-или-последнего)" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-этажа(первого-или-последнего)-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Зависимость цены квадратного метра от этажа(первого или последнего)</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-удаленности-от-центра" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-удаленности-от-центра-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Зависимость цены квадратного метра от удаленности от центра</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-дня-даты-размещения-объявления" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-дня-даты-размещения-объявления-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Зависимость цены квадратного метра от дня даты размещения объявления</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-месяца-даты-размещения--объявления" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-месяца-даты-размещения--объявления-4.4.6"><span class="toc-item-num">4.4.6&nbsp;&nbsp;</span>Зависимость цены квадратного метра от месяца даты размещения  объявления</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-года-даты-размещения--объявления" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-года-даты-размещения--объявления-4.4.7"><span class="toc-item-num">4.4.7&nbsp;&nbsp;</span>Зависимость цены квадратного метра от года даты размещения  объявления</a></span></li></ul></li><li><span><a href="#10-населенных-пунктов-с-наибольшим-числом-объявлений" data-toc-modified-id="10-населенных-пунктов-с-наибольшим-числом-объявлений-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>10 населенных пунктов с наибольшим числом объявлений</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-удаленности-от-центра-в-г.-Санкт-Петербург" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-удаленности-от-центра-в-г.-Санкт-Петербург-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Зависимость цены квадратного метра от удаленности от центра в г. Санкт-Петербург</a></span></li><li><span><a href="#Факторы,-влияющие-на-стоимость-квартиры-в-центре-Санкт-Петербурга" data-toc-modified-id="Факторы,-влияющие-на-стоимость-квартиры-в-центре-Санкт-Петербурга-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Факторы, влияющие на стоимость квартиры в центре Санкт-Петербурга</a></span><ul class="toc-item"><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Анализ данных</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-общей-площади-в-центре-Санкт-Петербурга" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-общей-площади-в-центре-Санкт-Петербурга-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Зависимость цены квадратного метра от общей площади в центре Санкт-Петербурга</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-количества-комнат-в-центре-Санкт-Петербурга" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-количества-комнат-в-центре-Санкт-Петербурга-4.7.3"><span class="toc-item-num">4.7.3&nbsp;&nbsp;</span>Зависимость цены квадратного метра от количества комнат в центре Санкт-Петербурга</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-этажа(первого-или-последнего)-в-центре-Санкт-Петербурга" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-этажа(первого-или-последнего)-в-центре-Санкт-Петербурга-4.7.4"><span class="toc-item-num">4.7.4&nbsp;&nbsp;</span>Зависимость цены квадратного метра от этажа(первого или последнего) в центре Санкт Петербурга</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-удаленности-от-центра-города-Санкт-Петербург" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-удаленности-от-центра-города-Санкт-Петербург-4.7.5"><span class="toc-item-num">4.7.5&nbsp;&nbsp;</span>Зависимость цены квадратного метра от удаленности от центра города Санкт-Петербург</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-дня-даты-размещения-объявления-в-центре-Санкт-Петербурга" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-дня-даты-размещения-объявления-в-центре-Санкт-Петербурга-4.7.6"><span class="toc-item-num">4.7.6&nbsp;&nbsp;</span>Зависимость цены квадратного метра от дня даты размещения объявления в центре Санкт-Петербурга</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-месяца-даты-размещения-объявления-в-центре-Санкт-Петербурга" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-месяца-даты-размещения-объявления-в-центре-Санкт-Петербурга-4.7.7"><span class="toc-item-num">4.7.7&nbsp;&nbsp;</span>Зависимость цены квадратного метра от месяца даты размещения объявления в центре Санкт Петербурга</a></span></li><li><span><a href="#Зависимость-цены-квадратного-метра-от-года-даты-размещения-объявления-в-центре-Санкт-Петербурга" data-toc-modified-id="Зависимость-цены-квадратного-метра-от-года-даты-размещения-объявления-в-центре-Санкт-Петербурга-4.7.8"><span class="toc-item-num">4.7.8&nbsp;&nbsp;</span>Зависимость цены квадратного метра от года даты размещения объявления в центре Санкт-Петербурга</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %%
import pandas as pd
from datetime import datetime
from bs4 import BeautifulSoup

def path_remover(path=''):
    import sys
    for el in sys.path:
        if el == path:
            sys.path.remove(path)
            
class Formatter(object):
    def __init__(self):
        self.types = {}
        self.htchar = '\t'
        self.lfchar = '\n'
        self.indent = 0
        self.set_formater(object, self.__class__.format_object)
        self.set_formater(dict, self.__class__.format_dict)
        self.set_formater(list, self.__class__.format_list)
        self.set_formater(tuple, self.__class__.format_tuple)

    def set_formater(self, obj, callback):
        self.types[obj] = callback

    def __call__(self, value, **args):
        for key in args:
            setattr(self, key, args[key])
        formater = self.types[type(value) if type(value) in self.types else object]
        return formater(self, value, self.indent)

    def format_object(self, value, indent):
        if 'DataFrame' in str(type(value)):
            return str(type(value))
        else:
            return repr(value)

    def format_dict(self, value, indent):
        items = [
            self.lfchar + self.htchar * (indent + 1) + repr(key) + ': ' +
            (self.types[type(value[key]) if type(value[key]) in self.types else object])(self, value[key], indent + 1)
            for key in value
        ]
        return '{%s}' % (','.join(items) + self.lfchar + self.htchar * indent)

    def format_list(self, value, indent):
        items = [
            self.lfchar + self.htchar * (indent + 1) + (self.types[type(item) if type(item) in self.types else object])(self, item, indent + 1)
            for item in value
        ]
        return '[%s]' % (','.join(items) + self.lfchar + self.htchar * indent)

    def format_tuple(self, value, indent):
        items = [
            self.lfchar + self.htchar * (indent + 1) + (self.types[type(item) if type(item) in self.types else object])(self, item, indent + 1)
            for item in value
        ]
        return '(%s)' % (','.join(items) + self.lfchar + self.htchar * indent)
        
        
def msgbox(msg, title='Внимание!',  msgtype='success', btn='Ok'):
    from IPython.display import HTML,Javascript, display
    
    if msgtype.upper() in ['ERROR', 'CRITICAL', 'DANGER']:
        msgtype = 'danger'
    
    style = HTML("""
        <style>
            .alert {
                margin: -10px;
            }
        </style>
    """)
    
    display(style)
    
    msg = '$("<p></p>").addClass("alert alert-' + msgtype + '").append("' + str(msg) + '")'
    
    body_msg = Javascript("""
        let m = require(
            ["base/js/dialog"], 
            function(dialog) {
                dialog.modal({
                    title: '""" + title + """',
                    body: """ + msg + """,
                    buttons: {
                        '""" + btn + """': {}},
                });
            }
            
        );
    """)
    display(body_msg)
    
    
def sum_rnd(summ, count, list_digit=None):
    from random import randrange
    
    summ_list = []
    
    for idx in range(count):
        summ_list.append(0)

        if (idx == 0 and idx != count-1):
            if list_digit:
                a = True
                rnd = 0
                while a == True:
                    rnd = randrange(summ-1)
                    if rnd in list(list_digit):
                        a = False
                summ_list[idx] = rnd
            else:
                summ_list[idx] = randrange(summ-1)
        elif (idx != 0 and idx == count-1):
            summ_list[idx] = summ - (sum(summ_list))
        else:
            if list_digit:
                a = True
                rnd = 0
                while a == True:
                    rnd = randrange(summ-summ_list[idx-1])
                    if rnd in list(list_digit):
                        a = False
                summ_list[idx] = rnd
            else:
                summ_list[idx] = randrange(summ-summ_list[idx-1])
    
    return summ_list

##########
#Function var_name

def get_caller_params():
    import re, inspect, ast
    # get the frame object for this function call
    thisframe = inspect.currentframe()

    # get the parent calling frames details
    frames = inspect.getouterframes(thisframe)

    # frame 0 is the frame of this function
    # frame 1 is the frame of the caller function (the one we want to inspect)
    # frame 2 is the frame of the code that calls the caller
    caller_function_name = frames[1][3]
    
    
    if 'var_name' in ''.join(inspect.findsource(frames[2][0])[0]):
        code_that_calls_caller = inspect.findsource(frames[2][0])[0]
    else:
        code_that_calls_caller = inspect.findsource(frames[3][0])[0]
    #code_that_calls_caller = inspect.findsource(frames[2][0])[0]
    
    
    print(code_that_calls_caller)
    # parse code to get nodes of abstract syntact tree of the call
    nodes = ast.parse(''.join(code_that_calls_caller))
    
    
    # find the node that calls the function
    i_expr = -1
    for (i, node) in enumerate(nodes.body):
        if _node_is_our_function_call(node, caller_function_name):
            i_expr = i
            break

    # line with the call start
    idx_start = nodes.body[i_expr].lineno - 1

    # line with the end of the call
    if i_expr < len(nodes.body) - 1:
        # next expression marks the end of the call
        idx_end = nodes.body[i_expr + 1].lineno - 1
    else:
        # end of the source marks the end of the call
        idx_end = len(code_that_calls_caller)

    call_lines = code_that_calls_caller[idx_start:idx_end]
    str_func_call = ''.join([line.strip() for line in call_lines])
    str_call_params = str_func_call[str_func_call.find('(') + 1:-1]
    params = [p.strip() for p in str_call_params.split(',')]

    return params


def _node_is_our_function_call(node, our_function_name):
    import re, inspect, ast
    node_is_call = hasattr(node, 'value') and isinstance(node.value, ast.Call)
    if not node_is_call:
        return False
    function_name_correct = hasattr(node.value.func, 'id') and node.value.func.id == our_function_name
    return function_name_correct

def var_name(*par_values):
    import os
    result = []
    par_names = get_caller_params()
    
    for name, val in zip(par_names, par_values):
        result.append("Variable name: '" + str(name) + "'; " + "Variable type: " + str(type(val)))
    return ' | '.join(result)

def color_nan_red(val, marker=None, table=None):

    general_style = 'font-weight:bold;text-transform: capitalize;'
    
    nan_class    = general_style + 'color: red;'
    unknow_class = general_style + 'color: #9c27b0;'
    value_class  = ''
    
    max_class    = general_style + 'color: #ff6f00;'
    min_class    = general_style + 'color: #0d64a1;'
    
    classes_list = []
    
    for i, cell in enumerate(val):
        if marker:
            if i in marker.keys():
                
                
                if ('str' in str(type(marker[i])) and 'str' in str(type(cell))):
                    if cell == marker[i]:
                        classes_list.append(nan_class)
                        continue
                elif 'list' in str(type(marker[i])):
                    if marker[i][0] == 'min' and cell == marker[i][1]:
                        classes_list.append(min_class)
                        continue
                    elif marker[i][0] == 'max' and cell == marker[i][1]:
                        classes_list.append(max_class)
                        continue
                    elif marker[i][0] == 'max_min' and cell in marker[i]:
                        if 'str' not in str(type(cell)):
                            if cell == min(item for item in marker[i][1:] if 'str' not in str(type(item))):
                                classes_list.append(min_class)
                                continue
                            elif cell == max(item for item in marker[i][1:] if 'str' not in str(type(item))):
                                classes_list.append(max_class)
                                continue
                        elif 'str' in str(type(cell)):
                            if cell == min(item for item in marker[i][1:] if 'str' in str(type(item))):
                                classes_list.append(min_class)
                                continue
                            elif cell == max(item for item in marker[i][1:] if 'str' in str(type(item))):
                                classes_list.append(max_class)
                                continue
                    elif cell in marker[i]:
                        if 'str' not in str(type(cell)):
                            if cell == min(item for item in marker[i] if 'str' not in str(type(item))):
                                classes_list.append(min_class)
                                continue
                            elif cell == max(item for item in marker[i] if 'str' not in str(type(item))):
                                classes_list.append(max_class)
                                continue
                            else:
                                classes_list.append(unknow_class)
                                continue
                        elif 'str' in str(type(cell)):
                            if cell == min(item for item in marker[i] if 'str' in str(type(item))):
                                classes_list.append(min_class)
                                continue
                            elif cell == max(item for item in marker[i] if 'str' in str(type(item))):
                                classes_list.append(max_class)
                                continue
                            else:
                                classes_list.append(unknow_class)
                                continue            
                    elif marker[i][0] == '>':
                        if 'list' in str(type(marker[i][1])):
                            if all(cell > j for j in marker[i][1]):
                                classes_list.append(nan_class)
                                continue
                        else:    
                            if cell > marker[i][1]:
                                classes_list.append(nan_class)
                                continue
                    elif marker[i][0] == '<':
                        if 'list' in str(type(marker[i][1])):
                            if all(cell < j for j in marker[i][1]):
                                classes_list.append(min_class)
                                continue
                        else:    
                            if cell < marker[i][1]:
                                classes_list.append(min_class)
                                continue
                    elif marker[i][0] == '=':
                        if cell == marker[i][1]:
                            classes_list.append(unknow_class)
                            continue
                        if cell in marker[i][1]:
                            classes_list.append(unknow_class)
                            continue
                    elif marker[i][0] == 'top':
                        if cell in list(table.iloc[:, i].head(marker[i][1])):
                            classes_list.append(unknow_class)
                            continue
                    elif marker[i][0] == 'out':
                        if cell in list(table.iloc[:, i].tail(marker[i][1])):
                            classes_list.append(unknow_class)
                            continue
                    
                                
                elif ('str' not in str(type(marker[i])) and 'str' not in str(type(cell))) and  cell >= marker[i]:
                    classes_list.append(nan_class)
                    continue 
        
        if pd.isna(cell):
            classes_list.append(nan_class)
            continue
        elif cell == 'unknown':
            classes_list.append(unknow_class)
            continue
        
        classes_list.append(value_class)
        continue
        
    return classes_list
    
def color_sea_war(val):
    return ['color: white;text-align:center !important;' if v == 0 else 'color: rgba(0, 0, 0, 0);background: rgba(0, 78, 145, 0.8);text-align:center !important;'
                for v in val]

def set_format(*args):
    print(args)
    
    for i, idx in enumerate(args[0]):
        print(i, ":", idx)
        
    if 'str' in str(type(args[1])):
        if 'float' in str(type(args[0])):
            return args[1].format(args[0])
        else:
            return args[0]
    elif 'list' in str(type(args[1])):
        if args[1][0] == 'datetime':
            return datetime.strptime(args[0], args[1][1]).strftime(args[1][2])
        elif args[1][0] == 'float':
            print(args[1][1],':', args[0])
            return args[1][1].format(args[0])
          
    return args[0]

def check_float(val,format='default'):
    if 'float' in str(type(val)):
        if format == 'default':
            return val
        else:
            return format.format(val)
    else:
        return val
    
def render(*args, format='default', border='false', position='center_header', marker=None, name='', width='', vartype=False):
    '''
    format   = {:.2f} Заменяет все float числа в формат
    format   = [ [[column_list], [type_format, value_format]] ] - применяет указанный формат к указанным столбцам.
    
        примеры:
        format=[ [['column_1','column_2'], '{:.2f}'] ]
        format=[ [['column_1','column_2'], ['float', '{:.2f}']] ]
        format=[ [['column_1','column_2'], ['datetime', '%Y%m%dT%H%M%S', '%d.%m.%Y %H:%M:%S']] ]
        format=[ [['column_1','column_2'], '<b style="color:red">{}</b>'] ] - применяем стиль к значению
    
    format   = 'json' - преобразовывает в json формат
    
    border   = display(d) | horizont(h) | vertical(v)
    
    position = left | center | right | left_header | center_header | right_header
    
    marker   = [['column_name', value]] все значения >=  value будут помечены красным цветом
    
    marker   = [['column_name', 'max_min']] будут отмечены максимальное и минимальное значение цветом
    marker   = [['column_name', 'min']]
    marker   = [['column_name', 'max']]
    
    marker   = [['column_name', ['>', 1000]]]
    marker   = [['column_name', ['<', 'value']]]
    
    name     = 'Test title'  Добавляет описание к таблице
    
    width    = auto | 100% | 300 | 600 | 900 Делает ширину таблицы, указаного значения
    
    type     = True Выводит имя переменной и его тип
    '''
    
    
    
    border_style   = ''
    position_style = ''
    
    title          = ''
    width_value    = ''
    type_value     = ''
    
    if name != '':
        title = ' data-title="' + name + '" '
        
    if width != '':
        width_value = ' data-width="' + width + '" '
    
    if vartype == True:
        type_value = ' data-type="[template]" '
    
    if border == 'display' or border == 'd':
        border_style = ' border_display'
    elif border == 'horizont' or border == 'h':
        border_style = ' border_horizont'
    elif border == 'vertical' or border == 'v':
        border_style = ' border_vertical'
    else:
        border_style = ''
    
    
    if position == 'left':
        position_style = ' position_left'
    elif position == 'center':
        position_style = ' position_center'
    elif position == 'right':
        position_style = ' position_right'
    elif position == 'left_header':
        position_style = ' position_left_header'
    elif position == 'center_header':
        position_style = ' position_center_header'
    elif position == 'right_header':
        position_style = ' position_right_header'
    else:
        position_style = ''
    
    
    
    if 'Series' in str(type(args[0])) or 'DataFrame' in str(type(args[0])): 
        df = args[0]
    else:
        df = args
    
    if 'Series' in str(type(df)): df = df.to_frame()
    
    if 'Series' in str(type(df)) or 'DataFrame' in str(type(df)):
        
        render_df = df.copy()
        
        
        
        if len(render_df.index) == 0:
            render_df.loc[render_df.shape[0]] = ''
        
        
        
        columns = render_df.columns
        need_columns = {}
        
        if marker:
            for need_clmn in marker:
                for i, clmn in enumerate(columns):
                    if need_clmn[0] == clmn:
                        if need_clmn[1] in ['min', 'max', 'max_min']:
                            if need_clmn[1] == 'min':
                                need_columns[i] = ['min', df[clmn].min()]
                            elif need_clmn[1] == 'max':
                                need_columns[i] = ['max', df[clmn].max()]
                            elif need_clmn[1] == 'max_min':
                                need_columns[i] = ['max_min', df[clmn].min(), df[clmn].max()]
                        else:
                            need_columns[i] = need_clmn[1]

        if vartype == True:
            type_value = type_value.replace("[template]", var_name(render_df))
            print(render_df, var_name(render_df))   
        
        #Render Style
        render_df = render_df.style.set_table_attributes('class="table_border' + border_style + position_style + '"' + title + width_value + type_value).apply(color_nan_red,marker=need_columns,table=df, axis=1)
        
        #print(str(type(render_df))) 
        
        #render_df.format(escape='html')
        
 
        if format != 'default':
            if 'str' in str(type(format)):
                render_df = render_df.format(lambda x: format.format(x) if 'float' in str(type(x)) else x )
            elif 'list' in str(type(format)):
                need_columns = {}
                for list_format in format:

                    s_type = None
                    s_type = list_format[1]
                    
                    for clmns_list in list_format[0]:
                        if 'str' in str(type(s_type)):
                            need_columns[clmns_list] = str_format(s_type)
                            continue
                        elif 'list' in str(type(s_type)):

                            if s_type[0] == 'float':
                                need_columns[clmns_list] = float_format(s_type[1])
                                continue
                            
                            elif s_type[0] == 'datetime':
                                need_columns[clmns_list] = time_format(s_type[1], s_type[2])
                                continue
                            
                            elif s_type[0] == 'link':
                                need_columns[clmns_list] = link_format(s_type[1])
                                continue
                            
                            else:
                                continue
                
                #print(need_columns)
                render_df = render_df.format(formatter=need_columns)
                                                
    else: 
        list_args = []
        
        for value in df: 
            #Render float format
            if format != 'default':
                if format == 'json':
                    pretty = Formatter()
                    list_args.append(pretty(value))
                else:
                    list_args.append(str(check_float(value,format)))
            else:
                list_args.append(str(value))
        
        render_df = ' '.join(list_args).replace('<', '&#60;').replace('>', '&#62;')
        
        if vartype == True:
            type_value = type_value.replace("[template]", var_name(render_df))
            print(df, var_name(df))
            
        from IPython.display import HTML
        render_df = HTML('<p class="value" ' + title + type_value + '><code>' + str(render_df) + '</code></p>')
        
        
    return display(render_df)


def import_style(width_page=-1):
    import os
    
    file_path = os.path.join(os.path.abspath(os.curdir), 'Settings', 'style.css')
    #print(file_path)

    #print(True)
    #open text file in read mode
    text_file = open(file_path, "r")

    #read whole file to a string
    data = text_file.read()

    #close file
    text_file.close()
    
    if width_page != -1:
        data = data.replace('/*#notebook-container', '#notebook-container').replace('[width]', str(width_page) + 'px').replace('width*/', '')
    
    from IPython.core.display import HTML
    style = HTML("""
        <style>
            .table_border[data-width='auto'],
            .table_border[data-width='auto'] thead,
            .table_border[data-width='auto'] tbody
            {width:auto;}
            
            .table_border[data-width='100%'],
            .table_border[data-width='100%'] thead,
            .table_border[data-width='100%'] tbody
            {width:100%;}
            
            .table_border[data-width='300']
            {width:300px;}
            .table_border[data-width='300'] thead,
            .table_border[data-width='300'] tbody
            {width:285px;}
            
            .table_border[data-width='600']
            {width:600px;}
            .table_border[data-width='600'] thead,
            .table_border[data-width='600'] tbody
            {width:585px;}
            
            .table_border[data-width='900']
            {width:900px;}
            .table_border[data-width='900'] thead,
            .table_border[data-width='900'] tbody
            {width:885px;}
            
            .table_border[data-width]
            {display: inline-grid;}
            .table_border[data-width] thead,
            .table_border[data-width] tbody
            {display: inline-table;}
        </style>
    """)
    display(style)
    return data
    
def testik(a='Test'):
    print(a)


def str_format(y):
    return lambda x: y.format(x)
    
def float_format(y):
    return lambda x: y.format(x)

def link_format(y):
    if y != '':
        return lambda x: '<a href="{}" title="{}">{}</a>'.format(x, y, y)
    else:
        return lambda x: '<a href="{}" title="{}">{}</a>'.format(x, x, x)
    
def time_format(y, z):
    if y == '':
        y = '%Y%m%dT%H%M%S'
    if z == '':
        z = '%d.%m.%Y %H:%M:%S'
    return lambda x: datetime.strptime(x, y).strftime(z)

# %%
# %%HTML
# <style>
#
#     div.ow_fl {
#         overflow: auto;
#     }
#
#     div.ow_fl p {
#         display:flex;
#     }
#
#     .rendered_html :link {
#         text-decoration: none;
#     }
#
#     a:hover, a:focus {
#         color: #1a466c;
#         text-decoration: underline !important;
#     }
#
#     #notebook-container {
#         /*width: 1700px;*/
#     }
#
#     #notebook-container .cell:nth-child(4) {
#         display: none;
#     }
#
#     #notebook-container .cell:nth-child(5) {
#         display: none;
#     }
#
#     table {float: left;}
#     table td, table th, table tr {
#         text-align:left !important;
#     }
#
#     .menu_table thead,
#     .menu_table tbody,
#     .menu_table tr
#     {
#         border: none !important;
#         background: none !important;
#         cursor: default;
#     }
#
#     .menu_table thead {
#         display: none;
#     }
#
#     .clearfix {
#         clear: both;
#     }
#
#
#     /*----BLOCKS-------------*/
#
#     .rendered_html em del
#     {
#         text-decoration: none;
#         border: 1px solid gray;
#         border-radius: 10px;
#         padding: 2px;
#         background: bisque;
#         box-shadow: 1px 1px 3px grey;
#         font-style: italic;
#         font-weight: bold;
#         color: brown;
#         line-height: 30px;
#     }
#
#     .rendered_html del {
#         text-decoration: none !important;
#     }
#
#
#     .rendered_html strong em,
#     .rendered_html em strong
#     {
#
#         display: block;
#         border-radius: 5px;
#         padding: 15px;
#         font-style: normal !important;
#         text-decoration: none;
#     }
#
#     .rendered_html strong em
#     {
#         background: rgba(66, 165, 245, 0.2);
#         color: rgba(0, 0, 0, 0.8);
#         font-weight: normal;
#     }
#
#     .rendered_html em strong
#     {
#         background: rgba(232, 245, 233, 1);
#         color: rgba(0, 0, 0, 0.8);
#         font-weight: normal;
#     }
#
#     .rendered_html strong em code,
#     .rendered_html em strong code
#     {
#         background: white;
#         border-radius: 4px;
#         padding: 2px !important;
#     }
#
#
#     /*-----TABLE---------*/
#
#     .table_border {
#         border-radius: 10px;
#         border: 1px solid #ccc !important;
#         margin: 5px;
#         margin-top: 40px !important;
#         padding: 5px;
#         display: inline-block;
#         cursor: default;
#         box-shadow: 5px 4px 5px 1px rgba(0, 0, 0, 0.07);
#     }
#
#     .table_border:before,
#     p.value:before
#     {
#         content: attr(data-title);
#         position: absolute;
#         display: block;
#         margin-block: auto;
#         margin-top: -25px;
#         /*color: rgb(0 0 0 / 30%);*/
#         color: #4caf50;
#         font-size: 10px;
#     }
#
#     p:before
#     {
#         margin-top: -15px !important;
#     }
#
#     p.value
#     {
#         padding-top: 40px;
#     }
#
#     .table_border thead,
#     .table_border thead tr,
#     .table_border thead th {
#         color: #03a9f4;
#         vertical-align: middle;
#     }
#
#
#     .table_border thead tr
#     {
#         background: rgba(66, 165, 245, 0.2) !important;
#         border-bottom: 1px solid #b2ebf2 !important;
#         padding: 1px;
#     }
#
#     .table_border tbody td:hover
#     {
#         font-weight: bold;
#         color: #03a9f4;
#     }
#
#     .table_border thead tr:first-child th:first-child {
#         border-radius: 10px 0px 0px 0px;
#     }
#
#     .table_border thead tr:first-child th:last-child {
#         border-radius: 0px 10px 0px 0px;
#     }
#
#     .table_border tbody tr:last-child:hover
#     {
#         border-radius: 0px 0px 10px 10px;
#         padding: 0px;
#     }
#
#     .table_border tbody tr:last-child:hover th,
#     .table_border tbody tr:last-child:hover td {
#         background: antiquewhite !important;
#     }
#
#     .table_border tbody tr:hover,
#     .table_border tbody tr:hover th,
#     .table_border tbody tr:hover td,
#     .table_border tbody tr:hover > th,
#     .table_border tbody td.active
#     {
#         background: rgba(66, 165, 245, 0.2) !important;
#     }
#
#     .table_border tbody tr:last-child:hover th,
#     .table_border tbody tr:last-child:hover td:first-child {
#         border-radius: 0px 0px 0px 10px;
#         display: table-cell;
#     }
#
#     .table_border tbody tr:last-child:hover td:last-child {
#         border-radius: 0px 0px 10px 0px;
#         display: table-cell;
#     }
#
#     .table_border tbody tr,
#     .table_border tbody th,
#     .table_border tbody td
#     {
#         background: white;
#     }
#
#     .table_border tbody td {
#         min-width: 120px;
#     }
#
#     .table_border tbody tr .row_heading {
#         color: rgba(0,0,0,0.2)
#     }
#
#     .table_border td.table_border_td_nan {
#         font-weight: bold;
#         text-transform: capitalize;
#         color: red;
#     }
#
#     .table_border tbody tr:hover .row_heading {
#         color: #1565c0;
#     }
#
#     /*
#     ++++++++++++++++++++++
#     .table_border {
#         border-radius: 13px;
#         border: 1px solid #ccc !important;
#         margin: 5px;
#         padding: 5px;
#         display: inline-block;
#         cursor: default;
#         box-shadow: 5px 4px 5px 1px rgba(0, 0, 0, 0.07);
#     }
#
#     .table_border table,
#     {
#         border-collapse: separate;
#     }
#
#     .table_border thead,
#     .table_border thead tr,
#     .table_border thead th
#     {
#         text-align: center !important;
#         color: #03a9f4;
#     }
#
#
#     .table_border thead th
#     {
#         border-right: 1px solid;
#     }
#
#     .table_border thead th:last-child
#     {
#         border-right: none;
#     }
#
#     .table_border thead
#     {
#         display: table-caption;
#         border: none !important;
#     }
#
#     .table_border tbody
#     {
#         border: none !important;
#         display: table-cell;
#     }
#
#     ++++++++++++++++++++++
#     .table_border thead tr
#     {
#         background: rgba(66, 165, 245, 0.2) !important;
#         border-bottom: 1px solid #b2ebf2 !important;
#         display: table-row;
#         padding: 1px;
#     }
#
#     ++++++++++++++++++++++
#     .table_border thead tr:first-child th:first-child {
#         display: table-cell;
#         border-radius: 10px 0px 0px 0px;
#     }
#     ++++++++++++++++++++++
#     .table_border thead tr:first-child th:last-child {
#         display: table-cell;
#         border-radius: 0px 10px 0px 0px;
#     }
#
#     .table_border thead th
#     {
#         word-break: inherit;
#     }
#
#     .table_border th, .table_border tbody td {
#         width: 110px;
#         word-break: break-word;
#     }
#
#     .table_border tbody tr
#     {
#         background: none !important;
#     }
#
#     ++++++++++++++++++++++
#     .table_border tbody tr:hover,
#     .table_border tbody td.active
#     {
#         background: rgba(66, 165, 245, 0.2) !important;
#     }
#
#     ++++++++++++++++++++++
#     .table_border tbody td:hover
#     {
#         font-weight: bold;
#         color: #03a9f4;
#     }
#
#     .table_border tbody tr:last-child:hover
#     {
#         border-radius: 0px 0px 10px 10px;
#         display: block;
#         padding: 0px;
#         background: antiquewhite !important;
#     }
#
#     /*.table_border th,
#     .table_border td
#     {
#         width: 250px !important;
#         word-break: break-word;
#     }*/
#
#
#     .sea_war th,
#     .sea_war td
#     {
#         width: 26px !important;
#     }
#
#     .sea_war tbody th,
#     .sea_war tbody td
#     {
#         border: 1px solid rgba(0,0,0,0.1);
#     }
#
#     .sea_war tbody th
#     {
#         color: rgba(0,0,0,0.5);
#         text-align: center !important;
#     }
#
#     /*---------------Borders------------------------*/
#
#     /* border_horizont  */
#     .border_horizont tbody th,
#     .border_horizont tbody td
#     {
#         border-bottom: 1px solid rgba(0,0,0,0.04);
#     }
#
#     .border_horizont tbody tr:last-child th,
#     .border_horizont tbody tr:last-child td
#     {
#         border-bottom: none;
#     }
#
#     /* border_vertical  */
#     .border_vertical tbody th,
#     .border_vertical tbody td
#     {
#         border-right: 1px solid rgba(0,0,0,0.04);
#     }
#
#     .border_vertical tbody td:last-child
#     {
#         border-right: none;
#     }
#
#     /* border_display  */
#     .border_display tbody th,
#     .border_display tbody td
#     {
#         border: 1px solid rgba(0,0,0,0.04);
#     }
#     .border_display tbody th,
#     .border_display tbody td
#     {
#         border-left: none;
#         border-top: none;
#     }
#     .border_display tbody td:last-child
#     {
#        border-right: none;
#     }
#     .border_display tbody tr:last-child th,
#     .border_display tbody tr:last-child td
#     {
#         border-bottom: none;
#     }
#
#
#     /* positions  */
#
#     .position_left thead th,
#     .position_left tbody td {
#         text-align: left !important;
#     }
#
#     .position_center thead th,
#     .position_center tbody td {
#         text-align: center !important;
#     }
#
#     .position_right thead th,
#     .position_right tbody td {
#         text-align: right !important;
#     }
#
#     .position_left_header thead th {
#         text-align: left !important;
#     }
#
#     .position_center_header thead th {
#         text-align: center !important;
#     }
#     .position_right_header thead th {
#         text-align: right !important;
#     }
#
#     /*---------------Code------------------------*/
#     .rendered_html p code,
#     .rendered_html ul code,
#     .rendered_html pre code[class*="custom"]
#     {
#         background-color: #d9edfd;
#         color: #4c4c4c;
#         font-size: 16px !important;
#         border-radius: 10px;
#         font-weight: bold;
#         border: 1px solid #ccc !important;
#         padding: 5px !important;
#         line-height: 19px !important;
#         display: inline-block;
#         margin: 5px 0px 0px 0px;
#         word-break: break-word;
#     }
#
#     .rendered_html code span[class*="-bold"]
#     {
#         font-weight: bold;
#     }
#
#     .rendered_html code span[class*="-italic"]
#     {
#         font-style: italic;
#     }
#
#     .rendered_html code span[class*="-marker"]
#     {
#         background: #ffeb3b8c;
#         font-weight: bold;
#         border: 1px solid #9e9e9e;
#         box-shadow: 1px 1px 5px 0px #00000045;
#         border-radius: 4px;
#         padding: 2px;
#         opacity: 0.8;
#         line-height: 30px;
#     }
#
#     .rendered_html code[class*="error"] {
#         color: red !important;
#         background-color: rgba(244, 67, 54, 0.1) !important;
#         font-weight: normal !important;
#     }
#
#     .rendered_html code[class*="warning"] {
#         color: #ff9800 !important;
#         background-color: rgba(244, 243, 54, 0.1) !important;
#         font-weight: normal !important;
#     }
#
#     .rendered_html code[class*="info"] {
#         color: green !important;
#         background-color: rgb(54, 244, 91, 0.1) !important;
#         font-weight: normal !important;
#     }
#
#     .rendered_html code[class*="word"] {
#         color: #00bcd4 !important;
#         background-color: rgba(54, 195, 244, 0.1) !important;
#         font-weight: normal !important;
#     }
#
#     /*---------------Imgs------------------------*/
#     .rendered_html img
#     {
#         border-radius: 16px;
#         border: 1px solid rgb(0 0 0 / 25%);
#         box-shadow: 5px 6px 8px 1px hsl(0deg 0% 0% / 25%);
#         padding: 4px;
#         margin-bottom: 10px;
#         max-width: 65em;
#     }
#
#     #ipython_notebook:after {
#         content: '@alefair кодит';
#         position: relative;
#         color: #2196f3;
#         bottom: 7px;
#         right: -35px;
#     }
# </style>
# Out:
# <style>
#
#     div.ow_fl {
#         overflow: auto;
#     }
#
#     div.ow_fl p {
#         display:flex;
#     }
#
#     .rendered_html :link {
#         text-decoration: none;
#     }
#
#     a:hover, a:focus {
#         color: #1a466c;
#         text-decoration: underline !important;
#     }
#
#     #notebook-container {
#         /*width: 1700px;*/
#     }
#
#     #notebook-container .cell:nth-child(4) {
#         display: none;
#     }
#
#     #notebook-container .cell:nth-child(5) {
#         display: none;
#     }
#
#     table {float: left;}
#     table td, table th, table tr {
#         text-align:left !important;
#     }
#
#     .menu_table thead,
#     .menu_table tbody,
#     .menu_table tr
#     {
#         border: none !important;
#         background: none !important;
#         cursor: default;
#     }
#
#     .menu_table thead {
#         display: none;
#     }
#
#     .clearfix {
#         clear: both;
#     }
#
#
#     /*----BLOCKS-------------*/
#
# ...

# %% [markdown]
# **Импорт библиотек**

# %%
# %matplotlib inline

import pandas as pd
from IPython.display import Markdown as md
from matplotlib import pyplot as plt

# %% [markdown]
# **Вспомогательные функции и списки**

# %%
day_name = pd.Series([
    "7.Воскресенье",
    "1.Понедельник",
    "2.Вторник",
    "3.Среда",
    "4.Четверг",
    "5.Пятница",
    "6.Суббота",
])

month_name = pd.Series([
    "Месяц",
    "01.Январь",
    "02.Февраль",
    "03.Март",
    "04.Апрель",
    "05.Май",
    "06.Июнь",
    "07.Июль",
    "08.Август",
    "09.Сентябрь",
    "10.Октябрь",
    "11.Ноябрь",
    "12.Декабрь",
])

pivot_dict = {}

def floor_name(row):
    floors_total = row['floors_total']
    floor = row['floor']
    
    if floor == 1:
        return 'Первый'
    elif floor == floors_total:
        return 'Последний'
    elif 1 < floor < floors_total:
        return 'Другой'

# %% [markdown]
# ## Изучение данных из файла

# %%
#Открываем файл
data = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')
rows_count = len(data)

render(data.head(), name='Фрагмент источника данных (' + str(rows_count) + ' строк)')
# Out:
# <style  type="text/css" >
# #T_07651_row0_col9,#T_07651_row0_col13,#T_07651_row0_col21,#T_07651_row1_col5,#T_07651_row1_col9,#T_07651_row1_col18,#T_07651_row1_col20,#T_07651_row2_col5,#T_07651_row2_col9,#T_07651_row3_col5,#T_07651_row3_col7,#T_07651_row3_col9,#T_07651_row3_col12,#T_07651_row4_col9,#T_07651_row4_col13{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  red;
# ...

# %% [markdown]
# ### Описание данных
#
# _**` `<br>
# `::  total_images          ::` — число фотографий квартиры в объявлении<br>
# `::  last_price            ::` — цена на момент снятия с публикации<br>
# `::  total_area            ::` — площадь квартиры в квадратных метрах (м²)<br>
# `::  first_day_exposition  ::` — дата публикации<br>
# `::  rooms                 ::` — число комнат<br>
# `::  ceiling_height        ::` — высота потолков (м)<br>
# `::  floors_total          ::` — всего этажей в доме<br>
# `::  living_area           ::` — жилая площадь в квадратных метрах (м²)<br>
# `::  floor                 ::` — этаж<br>
# `::  is_apartment          ::` — апартаменты (булев тип)<br>
# `::  studio                ::` — квартира-студия (булев тип)<br>
# `::  open_plan             ::` — свободная планировка (булев тип)<br>
# `::  kitchen_area          ::` — площадь кухни в квадратных метрах (м²)<br>
# `::  balcony               ::` — число балконов<br>
# `::  locality_name         ::` — название населённого пункта<br>
# `::  airports_nearest      ::` — расстояние до ближайшего аэропорта в метрах (м)<br>
# `::  cityCenters_nearest   ::` — расстояние до центра города (м)<br>
# `::  parks_around3000      ::` — число парков в радиусе 3 км<br>
# `::  parks_nearest         ::` — расстояние до ближайшего парка (м)<br>
# `::  ponds_around3000      ::` — число водоёмов в радиусе 3 км<br>
# `::  ponds_nearest         ::` — расстояние до ближайшего водоёма (м)<br>
# `::  days_exposition       ::` — сколько дней было размещено объявление (от публикации до снятия)<br>
# ` `**_

# %% [markdown]
# ### Структура и типы данных в колонках

# %%
render("Структура и типы данных в колонках")
data.info()
# Out:
# <p class="value" ><code>Структура и типы данных в колонках</code></p>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Анализируя источник данных и, сравнивая данные с описанием данных, найдены следующие нарушения:
#
# **_Столбец `first_day_exposition (дата публикации)` - На первый взгляд данные выглядят корректно, однако тип данных указан, как <b>object</b>, а не как <b>datetime</b>_**
#
# _**Столбец `ceiling_height (высота потолков (м))` - Как и в таблице, так и в info() видим пропущенные значения**_
#
# **_Столбец `floors_total (всего этажей в доме)` - Подразумевает целое число, а не число с плавающей запятой, есть пропуски_**
#
# _**Столбец `living_area (жилая площадь в квадратных метрах (м²))` - Есть пропуски**_
#
# **_Столбец `is_apartment (апартаменты (булев тип))` - Мало того, что есть отсуствующие значения, так и тип данных <b>object</b>, а не <b>bool</b>_**
#
# _**Столбец `kitchen_area (площадь кухни в квадратных метрах (м²))` - Есть пропуски**_
#
# **_Столбец `balcony (число балконов)` - Есть пропуски и требуется тип int64_**
#
# _**Столбец `locality_name (название населённого пункта)` - Есть пропуски**_
#
# **_Столбец `airports_nearest (расстояние до ближайшего аэропорта в метрах (м))` - Есть пропуски_**
#
# _**Столбец `cityCenters_nearest (расстояние до центра города (м))` - Есть пропуски**_
#
# **_Столбец `parks_around3000 (число парков в радиусе 3 км)` - Есть пропуски и требуется тип int64_**
#
# _**Столбец `parks_nearest (расстояние до ближайшего парка (м))` - Есть пропуски**_
#
# **_Столбец `ponds_around3000 (число водоёмов в радиусе 3 км)` - Есть пропуски и требуется тип int64_**
#
# _**Столбец `ponds_nearest (расстояние до ближайшего водоёма (м))` - Есть пропуски**_
#
# **_Столбец `days_exposition (сколько дней было размещено объявление (от публикации до снятия))` - Есть пропуски и требуется тип int64_**

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# <div class="alert alert-warning">
#     <p>Попробуем подобрать альтернативное значение в пропущенных строчках проблемных столбцов</p>
# </div>

# %% [markdown]
# ### Анализ проблемных столбцов

# %% [markdown]
# #### Столбец ["first_day_exposition"]

# %%
column_name = "first_day_exposition"

render('Столбец "{}" - дата публикации'.format(column_name))

display(
    md(
        "Для анализа данных нам время не надо учитывать в дате публикации, по этому приведем к формату: `'%Y-%m-%d'`"
    )
)

data[column_name] = pd.to_datetime(data[column_name], format = '%Y-%m-%d')


display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
        +'<hr>'
    )
)
# Out:
# <p class="value" ><code>Столбец "first_day_exposition" - дата публикации</code></p>
# Для анализа данных нам время не надо учитывать в дате публикации, по этому приведем к формату: `'%Y-%m-%d'`
# Тип столбца стал: `datetime64[ns]`<hr>

# %% [markdown]
# #### Столбец ["ceiling_height"]

# %%
column_name = "ceiling_height"

render('Столбец "{}" - Высота потолков'.format(column_name))

print("Рассмотрим медину, минимальное и максимальное значение")

render(data[column_name].describe())

cell_min = data[column_name].min()
cell_max = data[column_name].max()


display(
    md(
        "_**Из таблицы видим, что есть слишком большое значение, которое скорее всего является ошибкой: <b>" + str(cell_max) + "</b><br>"
        + "Необходимо построить график, чтобы понять сколько таких отклонений**_"
    )
)

#Построим график высоты потолков
(
    data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 30, range=(cell_min, cell_max))
)

plt.show()

print()
print()

print('График показал, что таких вбросов мало, поэтому можем уменьшить диапазон до 6 метров по высоте')
print('Поэтому пока оставим все, как есть, но все равно посмотрим на эти отклонения')

(
    data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 30, range=(cell_min, 6))
)

plt.show()


display(
    md(
        "**_По графику видно, что максимальным значеним в этом диапазоне является 4.5м_**"
    )
)

print()
print()

print('И на всякий случай построим график по отклонениям от нормы')
(
    data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 30, range=(4.01, cell_max))
)

plt.show()

render('Количество таких отклонений: ', data[data[column_name] > 4][column_name].count())

display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "ceiling_height" - Высота потолков</code></p>
# Рассмотрим медину, минимальное и максимальное значение
# <style  type="text/css" >
# </style><table id="T_d3409_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ceiling_height</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d3409_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_d3409_row0_col0" class="data row0 col0" >14504.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d3409_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_d3409_row1_col0" class="data row1 col0" >2.771499</td>
#             </tr>
#             <tr>
#                         <th id="T_d3409_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# #### Столбец ["floors_total"]

# %%
column_name = "floors_total"

render('Столбец "{}" - всего этажей в доме'.format(column_name))


print('Проверим есть ли зависимость между данными и пропусками количества этажей:')

render(data[data[column_name].isna()].head(10))

render('На первый взгляд ничего общего нет. Оставим столбец без изменений')

display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "floors_total" - всего этажей в доме</code></p>
# Проверим есть ли зависимость между данными и пропусками количества этажей:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец ["living_area"]

# %%
column_name = "living_area"

render('Столбец "{}" - жилая площадь в квадратных метрах (м²)'.format(column_name))

print("Рассмотрим медину, минимальное и максимальное значение")

render(data[column_name].describe())

cell_min = data[column_name].min()
cell_max = data[column_name].max()

print('Мы могли бы посчитать средний процент от всей площади и заполнить пропуски, но в данном случае пока нет необходимости')
print('Еще при анализе данных, некоторые размеры имеют достаточно большое количество знаков после запятой:')
# Out:
# <p class="value" ><code>Столбец "living_area" - жилая площадь в квадратных метрах (м²)</code></p>
# Рассмотрим медину, минимальное и максимальное значение
# <style  type="text/css" >
# </style><table id="T_6f24e_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >living_area</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6f24e_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_6f24e_row0_col0" class="data row0 col0" >21796.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6f24e_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_6f24e_row1_col0" class="data row1 col0" >34.457852</td>
#             </tr>
#             <tr>
#                         <th id="T_6f24e_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# <hr>

# %% [markdown]
# #### Столбец ["is_apartment"]

# %%
column_name = "is_apartment"

render('Столбец "{}" - апартаменты (булев тип)'.format(column_name))

render(data[column_name].value_counts(), name='Было')

print()
print('Судя по количеству, а это явно не ошибка, скорее всего данный столбец введен недавно и мы все пропуски можем заменить на False')

data[column_name] = data[column_name].fillna(False)

render(data[column_name].value_counts(), name='Стало')
# Out:
# <p class="value" ><code>Столбец "is_apartment" - апартаменты (булев тип)</code></p>
# <style  type="text/css" >
# </style><table id="T_e4fab_" class="table_border position_center_header" data-title="Было" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >is_apartment</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e4fab_level0_row0" class="row_heading level0 row0" >False</th>
#                         <td id="T_e4fab_row0_col0" class="data row0 col0" >2725</td>
#             </tr>
#             <tr>
#                         <th id="T_e4fab_level0_row1" class="row_heading level0 row1" >True</th>
#                         <td id="T_e4fab_row1_col0" class="data row1 col0" >50</td>
#             </tr>
#     </tbody></table>
# Судя по количеству, а это явно не ошибка, скорее всего данный столбец введен недавно и мы все пропуски можем заменить на False
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Столбец ["kitchen_area"]

# %%
column_name = "kitchen_area"

render('Столбец "{}" - площадь кухни в квадратных метрах (м²)'.format(column_name))

print("Рассмотрим медину, минимальное и максимальное значение")

render(data[column_name].describe())

cell_min = data[column_name].min()
cell_max = data[column_name].max()

print('Мы могли бы посчитать средний процент от всей площади и заполнить пропуски, но в данном случае пока нет необходимости')

display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "kitchen_area" - площадь кухни в квадратных метрах (м²)</code></p>
# Рассмотрим медину, минимальное и максимальное значение
# <style  type="text/css" >
# </style><table id="T_8c252_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >kitchen_area</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c252_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_8c252_row0_col0" class="data row0 col0" >21421.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_8c252_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_8c252_row1_col0" class="data row1 col0" >10.569807</td>
#             </tr>
#             <tr>
#                         <th id="T_8c252_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# #### Столбец ["balcony"]

# %%
column_name = "balcony"

render('Столбец "{}" - число балконов'.format(column_name))

render(data[column_name].value_counts(ascending=False), name='Было')

print('Второй по популярности результат - отсуствие балкона, по этому можем смело заменить пропуски на 0')
print('А также заменим тип с плавающей запятой на целое')

data[column_name] = (
    data[column_name]
        .fillna(0)
        .astype('int')
)

render(data[column_name].value_counts(ascending=False), name='Стало')

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

print('Еще кажется, что 5 балконов и 4-ый по популярности результат не внушает доверия, но об этом можем сообщить')
display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "balcony" - число балконов</code></p>
# <style  type="text/css" >
# </style><table id="T_a219c_" class="table_border position_center_header" data-title="Было" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >balcony</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a219c_level0_row0" class="row_heading level0 row0" >1.0</th>
#                         <td id="T_a219c_row0_col0" class="data row0 col0" >4195</td>
#             </tr>
#             <tr>
#                         <th id="T_a219c_level0_row1" class="row_heading level0 row1" >0.0</th>
#                         <td id="T_a219c_row1_col0" class="data row1 col0" >3758</td>
#             </tr>
#             <tr>
#                         <th id="T_a219c_level0_row2" class="row_heading level0 row2" >2.0</th>
#                         <td id="T_a219c_row2_col0" class="data row2 col0" >3659</td>
# ...

# %% [markdown]
# #### Столбец ["locality_name"]

# %%
column_name = "locality_name"

render('Столбец "{}" - название населённого пункта'.format(column_name))

print('Причины для отсуствия строк не известны. По этому оставляем пока, как есть')
display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "locality_name" - название населённого пункта</code></p>
# Причины для отсуствия строк не известны. По этому оставляем пока, как есть
# <hr>

# %% [markdown]
# #### Столбец ["airports_nearest"]

# %%
column_name = "airports_nearest"

render('Столбец "{}" - расстояние до ближайшего аэропорта в метрах (м)'.format(column_name))

print('Причины для отсуствия строк не известны. По этому оставляем пока, как есть')
display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "airports_nearest" - расстояние до ближайшего аэропорта в метрах (м)</code></p>
# Причины для отсуствия строк не известны. По этому оставляем пока, как есть
# <hr>

# %% [markdown]
# #### Столбец ["cityCenters_nearest"]

# %%
column_name = "cityCenters_nearest"

render('Столбец "{}" - расстояние до центра города (м)'.format(column_name))

print('Причины для отсуствия строк не известны. По этому оставляем пока, как есть')
display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "cityCenters_nearest" - расстояние до центра города (м)</code></p>
# Причины для отсуствия строк не известны. По этому оставляем пока, как есть
# <hr>

# %% [markdown]
# #### Столбец ["parks_around3000"]

# %%
column_name = "parks_around3000"

render('Столбец "{}" - число парков в радиусе 3 км'.format(column_name))

render(data[column_name].value_counts(ascending=False), name='Было')

print('Причины для отсуствия строк может быть отсуствие парков в радиусе 3 км')
print('Переведем значения в int и заменим пустые строки на 0')

data[column_name] = (
    data[column_name]
        .fillna(0)
        .astype('int')
)

render(data[column_name].value_counts(ascending=False), name='Стало')

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "parks_around3000" - число парков в радиусе 3 км</code></p>
# <style  type="text/css" >
# </style><table id="T_46e18_" class="table_border position_center_header" data-title="Было" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >parks_around3000</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_46e18_level0_row0" class="row_heading level0 row0" >0.0</th>
#                         <td id="T_46e18_row0_col0" class="data row0 col0" >10106</td>
#             </tr>
#             <tr>
#                         <th id="T_46e18_level0_row1" class="row_heading level0 row1" >1.0</th>
#                         <td id="T_46e18_row1_col0" class="data row1 col0" >5681</td>
#             </tr>
#             <tr>
#                         <th id="T_46e18_level0_row2" class="row_heading level0 row2" >2.0</th>
# ...

# %% [markdown]
# #### Столбец ["parks_nearest"]

# %%
column_name = "parks_nearest"

render('Столбец "{}" - расстояние до ближайшего парка (м)'.format(column_name))

print('Причины для отсуствия строк не известны. По этому оставляем пока, как есть')
display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "parks_nearest" - расстояние до ближайшего парка (м)</code></p>
# Причины для отсуствия строк не известны. По этому оставляем пока, как есть
# <hr>

# %% [markdown]
# #### Столбец ["ponds_around3000"]

# %%
column_name = "ponds_around3000"

render('Столбец "{}" - число водоёмов в радиусе 3 км'.format(column_name))

render(data[column_name].value_counts(ascending=False), name='Было')

print('Причины для отсуствия строк может быть отсуствие водоемов в радиусе 3 км')
print('Переведем значения в int и заменим пустые строки на 0')

data[column_name] = (
    data[column_name]
        .fillna(0)
        .astype('int')
)

render(data[column_name].value_counts(ascending=False), name='Стало')

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "ponds_around3000" - число водоёмов в радиусе 3 км</code></p>
# <style  type="text/css" >
# </style><table id="T_8a9f8_" class="table_border position_center_header" data-title="Было" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ponds_around3000</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8a9f8_level0_row0" class="row_heading level0 row0" >0.0</th>
#                         <td id="T_8a9f8_row0_col0" class="data row0 col0" >9071</td>
#             </tr>
#             <tr>
#                         <th id="T_8a9f8_level0_row1" class="row_heading level0 row1" >1.0</th>
#                         <td id="T_8a9f8_row1_col0" class="data row1 col0" >5717</td>
#             </tr>
#             <tr>
#                         <th id="T_8a9f8_level0_row2" class="row_heading level0 row2" >2.0</th>
# ...

# %% [markdown]
# #### Столбец ["ponds_nearest"]

# %%
column_name = "ponds_nearest"

render('Столбец "{}" - расстояние до ближайшего водоёма (м)'.format(column_name))

print('Причины для отсуствия строк не известны. По этому оставляем пока, как есть')
display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "ponds_nearest" - расстояние до ближайшего водоёма (м)</code></p>
# Причины для отсуствия строк не известны. По этому оставляем пока, как есть
# <hr>

# %% [markdown]
# #### Столбец ["days_exposition"]

# %%
column_name = "days_exposition"

render('Столбец "{}" - сколько дней было размещено объявление (от публикации до снятия)'.format(column_name))

print('Заменим пропуски в днях на 0 и переведем в тип int')

data[column_name] = (
    data[column_name]
        .fillna(0)
        .astype('int')
)

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

display(md('<hr>'))
# Out:
# <p class="value" ><code>Столбец "days_exposition" - сколько дней было размещено объявление (от публикации до снятия)</code></p>
# Заменим пропуски в днях на 0 и переведем в тип int
# Тип столбца стал: `int64`
# <hr>

# %% [markdown]
# #### Столбец ["last_price"]

# %%
column_name = "last_price"

display(
    md(
        '_**Еще можем изменить столбец `{}` привести к типу <b>int</b>**_'.format(column_name)
    )
)

data[column_name] = data[column_name].astype('int')

display(
    md(
        'Тип столбца стал: `' + str(data[column_name].dtypes) + '`'
    )
)

display(md('<hr>'))
# Out:
# _**Еще можем изменить столбец `last_price` привести к типу <b>int</b>**_
# Тип столбца стал: `int64`
# <hr>

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ### Смотрим на результат изменений

# %%
display(
    md(
        '**_Посмотрим на наши изменения:_**'
    )
)
# Out:
# **_Посмотрим на наши изменения:_**

# %% [markdown]
# <div class="ow_fl">
#
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
#
# </div>
#
#
# <div class="ow_fl">
#
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)
#
# </div>
#
#
# <div class="ow_fl">
#
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)
#
# </div>
#
#
# <div class="ow_fl">
#
# ![image-14.png](attachment:image-14.png)
# ![image-15.png](attachment:image-15.png)
#
# </div>
#
#
# <div class="ow_fl">
#
# ![image-16.png](attachment:image-16.png)
# ![image-17.png](attachment:image-17.png)
#
# </div>
#
#
#
# <br><br>
#
#
# <div style="overflow: auto;">
#
# |Было|Стало|
# |----|-----|
# |![image-5.png](attachment:image-5.png)|![image-19.png](attachment:image-19.png)|
#
# </div>

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# _**Когда у нас есть общее представление о данных мы можем уже провести первичные вычисления:<br><br>
# *` ` цену квадратного метра*<br>
# *` ` день недели, месяц и год публикации объявления*<br>
# *` ` этаж квартиры; варианты — первый, последний, другой*<br>
# *` ` соотношение жилой и общей площади, а также отношение площади кухни к общей*<br>**_

# %% [markdown]
# ### Цена квадратного метра

# %%
#Цена квадратного метра. Поставим price_square_meter после столбца total_area и переведем в int и 
column_name = 'total_area'

data.insert(
    data.columns.get_loc(column_name) + 1, 
    'price_square_meter', 
    data['last_price'] / data['total_area']
)

data['price_square_meter'] = data['price_square_meter'].astype('int')

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %%
#день недели, месяц и год публикации объявления. Добавим столбцы после столбца first_day_exposition:

# - День недели(week_exposition) 
# - Месяц(month_exposition)
# - Год публикации(year_exposition)

#del data['week_exposition']
#del data['month_exposition']
#del data['year_exposition']

column_name = 'first_day_exposition'

#week_exposition
data.insert(
    data.columns.get_loc(column_name) + 1, 
    'week_exposition', 
    data[column_name].dt.weekday.map(day_name)
)

#month_exposition
data.insert(
    data.columns.get_loc(column_name) + 2, 
    'month_exposition', 
    data[column_name].dt.month.map(month_name)
)

#year_exposition
data.insert(
    data.columns.get_loc(column_name) + 3, 
    'year_exposition', 
    data[column_name].dt.year
)

# %% [markdown]
# ### Категория этажа квартиры

# %%
#этаж квартиры; варианты — первый, последний, другой. Добавим столбец floor_category_name после столбца floor - категория этажа
#del data['floor_category_name']

column_name = 'floor'

data.insert(
    data.columns.get_loc(column_name) + 1, 
    'floor_category_name', 
    data.apply(floor_name, axis=1)
)

# %% [markdown]
# ### Cоотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
#соотношение жилой и общей площади, а также отношение площади кухни к общей.
#Добавим столбцы соотношение жилой и общей площади(living_ratio)  после столбца living_area и отношение площади кухни к общей(kitchen_ratio) после столбца kitchen_area

#del data['living_ratio']
#del data['kitchen_ratio']

column_name = 'living_area'
data.insert(
    data.columns.get_loc(column_name) + 1, 
    'living_ratio', 
    data[column_name] / data['total_area']
)

column_name = 'kitchen_area'
data.insert(
    data.columns.get_loc(column_name) + 1, 
    'kitchen_ratio', 
    data[column_name] / data['total_area']
)

# %% [markdown]
# ### Смотрим на результат изменений

# %%
display(
    md(
        '**_Посмотрим на наши изменения:_**'
    )
)

render(data.loc[:, 
    [
        'last_price', 
        'total_area', 
        'price_square_meter', 
        'first_day_exposition', 
        'week_exposition', 
        'month_exposition', 
        'year_exposition',
        'floor',
        'floor_category_name',
        'living_area',
        'living_ratio',
        'kitchen_area',
        'kitchen_ratio'
    ]
].head(3))
# Out:
# **_Посмотрим на наши изменения:_**
# <style  type="text/css" >
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# _**Посмотрим по подробнее на следующие параметры:<br><br>
# *`::  площадь          ::`*<br>
# *`::  цена             ::`*<br>
# *`::  число комнат     ::`*<br>
# *`::  высота потолков  ::`***_

# %% [markdown]
# ### Площадь, цена, число комнат, высота потолков

# %% [markdown]
# #### Площадь квартиры в квадратных метрах

# %%
#Общая площадь

column_name = 'total_area'
item_init = 'м²'
item_type = 'площадь квартиры'

render('Столбец "{}" - площадь квартиры в квадратных метрах (м²)'.format(column_name))

print("Рассмотрим медину, минимальное и максимальное значение")

render(data[column_name].describe())

cell_min =    data[column_name].min()
cell_max =    data[column_name].max()
cell_median = data[column_name].median()
cell_mean =   data[column_name].mean()

display(
    md(
        "_**Из таблицы видим, что есть слишком большое значение, которое скорее всего является ошибкой: <b>" + str(cell_max) + " " + item_init + "</b><br>"
        + "И слишком маленькое значение: <b>" + str(cell_min) + " " + item_init + "</b><br>"
        + "Необходимо построить график, чтобы понять сколько таких отклонений**_"
    )
)

#Построим график
(
    data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 100, range=(cell_min, cell_max))
)

plt.show()

print('Посмотрим на топ чаще покупаемой общей площади')
render(data[column_name].value_counts(ascending=False).head(3))

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "*` ` В отчете `есть артефакты` в данных, но они не влияют на общую картину*<br>"
        + "*` ` Диаграмма показала `распределение данных Гаусса`*<br>"
        + "**_"
    )
)
# Out:
# <p class="value" ><code>Столбец "total_area" - площадь квартиры в квадратных метрах (м²)</code></p>
# Рассмотрим медину, минимальное и максимальное значение
# <style  type="text/css" >
# </style><table id="T_51611_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_area</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_51611_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_51611_row0_col0" class="data row0 col0" >23699.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_51611_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_51611_row1_col0" class="data row1 col0" >60.348651</td>
#             </tr>
#             <tr>
#                         <th id="T_51611_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Цена на недвижимость

# %%
#Цена на недвижимость

column_name = "last_price"
item_init = 'руб.'
item_type = 'цена на недвижимость'


render('Столбец "{}" - цена на момент снятия с публикации'.format(column_name))

print("Рассмотрим медину, минимальное и максимальное значение")

render(data[column_name].describe())

cell_min =    data[column_name].min()
cell_max =    data[column_name].max()
cell_median = data[column_name].median()
cell_mean =   data[column_name].mean()


display(
    md(
        "_**Из таблицы видим, что есть слишком большое значение, которое скорее всего является ошибкой: <b>" + str(cell_max) + " " + item_init + "</b><br>"
        + "И слишком маленькое значение: <b>" + str(cell_min) + " " + item_init + "</b><br>"
        + "Необходимо построить график, чтобы понять сколько таких отклонений**_"
    )
)

#Построим график
(
    data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 100, range=(cell_min, cell_max))
)

plt.show()

print('Посмотрим на цены чуть ближе, отсекая слишком большие артефакты')

#Построим график
(
    data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 100, range=(cell_min, cell_median))
)

plt.show()

print('Посмотрим на топ цен')
render(data[column_name].value_counts(ascending=False).head(3))

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "*` ` В отчете `есть артефакты` в данных, но они не влияют на общую картину*<br>"
        + "*` ` Диаграмма показала `распределение данных Гаусса`*<br>"
        + "**_"
    )
)
# Out:
# <p class="value" ><code>Столбец "last_price" - цена на момент снятия с публикации</code></p>
# Рассмотрим медину, минимальное и максимальное значение
# <style  type="text/css" >
# </style><table id="T_84158_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >last_price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_84158_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_84158_row0_col0" class="data row0 col0" >23699.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_84158_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_84158_row1_col0" class="data row1 col0" >6541548.771552</td>
#             </tr>
#             <tr>
#                         <th id="T_84158_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Число комнат

# %%
#Число комнат

column_name = 'rooms'
item_init = 'комнат(-ы)'
item_type = 'количество комнат'

render('Столбец "{}" - число комнат'.format(column_name))

print("Рассмотрим медину, минимальное и максимальное значение")

render(data[column_name].describe())

cell_min =    data[column_name].min()
cell_max =    data[column_name].max()
cell_median = data[column_name].median()
cell_mean =   data[column_name].mean()

display(
    md(
        "_**Из таблицы видим, что есть слишком большое значение, которое скорее всего является ошибкой: <b>" + str(cell_max) + " " + item_init + "</b><br>"
        + "И слишком маленькое значение: <b>" + str(cell_min) + " " + item_init + "</b><br>"
        + "Необходимо построить график, чтобы понять сколько таких отклонений**_"
    )
)

#Построим график
(
    data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 30, range=(cell_min, cell_max))
)

plt.show()

print('Посмотрим количество квартир по комнатам')

render(data[column_name].value_counts(ascending=False).head(3))

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "*` ` На вершине рейтинга преобладает количество однокомнатных квартир - <b>8047</b>*<br>"
        + "*` ` В отчете `есть артефакты` в данных, но они не влияют на общую картину*<br>"
        + "**_"
    )
)
# Out:
# <p class="value" ><code>Столбец "rooms" - число комнат</code></p>
# Рассмотрим медину, минимальное и максимальное значение
# <style  type="text/css" >
# </style><table id="T_334ca_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_334ca_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_334ca_row0_col0" class="data row0 col0" >23699.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_334ca_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_334ca_row1_col0" class="data row1 col0" >2.070636</td>
#             </tr>
#             <tr>
#                         <th id="T_334ca_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Высота потолков

# %%
#Высота потолков

column_name = 'ceiling_height'
item_init = 'м'
item_type = 'высота потолков'

render('Столбец "{}" - высота потолков (м)'.format(column_name))

print("Рассмотрим медину, минимальное и максимальное значение")

render(data[column_name].describe())

cell_min =    data[column_name].min()
cell_max =    data[column_name].max()
cell_median = data[column_name].median()
cell_mean =   data[column_name].mean()

display(
    md(
        "_**Из таблицы видим, что есть слишком большое значение, которое скорее всего является ошибкой: <b>" + str(cell_max) + " " + item_init + "</b><br>"
        + "И слишком маленькое значение: <b>" + str(cell_min) + " " + item_init + "</b><br>"
        + "Необходимо построить график, чтобы понять сколько таких отклонений**_"
    )
)

#Построим график
(
    data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 30, range=(cell_min, cell_max))
)

plt.show()

print('Посмотрим высоту чуть ближе, ограничив высоту до 5м')

(
    data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 30, grid=True, range=(cell_min, 5))
)

plt.show()

print('Посмотрим на топ количества квартир по высоте потолков...')

render(data[column_name].value_counts(ascending=False).head(3))

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "*` ` На вершине рейтинга преобладает количество квартир с высотой потолков - 2,5м*<br>"
        + "*` ` В отчете `есть артефакты` в данных, но они не влияют на общую картину*<br>"
        + "**_"
    )
)
# Out:
# <p class="value" ><code>Столбец "ceiling_height" - высота потолков (м)</code></p>
# Рассмотрим медину, минимальное и максимальное значение
# <style  type="text/css" >
# </style><table id="T_4187d_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ceiling_height</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4187d_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_4187d_row0_col0" class="data row0 col0" >14504.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4187d_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_4187d_row1_col0" class="data row1 col0" >2.771499</td>
#             </tr>
#             <tr>
#                         <th id="T_4187d_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Общий вывод по данным параметров

# %% [markdown]
# **_Чаще всего покуют небольшие квартиры - 1к - 2к общей площадью 42~45м² Скорее всего это связано с их стоимостью ~ 4000000 - 4500000 рублей. Попробуем в этом убедиться, создав небольшой срез:_**

# %%
render(
    data
        .query('(41 < total_area < 46) & (3900000 < last_price < 4600000)')
        .head(15)
        .sort_values(by=['total_area', 'last_price'], ascending=False)
        .loc[:, 
            [
                'last_price', 
                'total_area', 
                'price_square_meter', 
                'ceiling_height',
                'rooms',
                'first_day_exposition', 
                'locality_name'
            ]
        ]
)
# Out:
# <style  type="text/css" >
# #T_56dc3_row0_col3,#T_56dc3_row1_col3,#T_56dc3_row3_col3,#T_56dc3_row4_col3,#T_56dc3_row5_col3,#T_56dc3_row8_col3,#T_56dc3_row9_col3{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  red;
#         }</style><table id="T_56dc3_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >last_price</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >price_square_meter</th>        <th class="col_heading level0 col3" >ceiling_height</th>        <th class="col_heading level0 col4" >rooms</th>        <th class="col_heading level0 col5" >first_day_exposition</th>        <th class="col_heading level0 col6" >locality_name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_56dc3_level0_row0" class="row_heading level0 row0" >627</th>
# ...

# %% [markdown]
# <div class="alert alert-danger">
#     <p>
#         Во всех иследуемых столбцах присуствуют ошибки.<br>
#         В данных есть "нулевые" комнаты, или высота потолков 1м и 100м.<br>
#         В данных есть стоимость квартиры в 12190 рублей, что вряд ли может быть правдой.<br><br>
#         <b>Необходимо сообщить коллегам, что есть артефакты</b>
#     </p>
# </div>

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ### Время продажи квартиры

# %% [markdown]
# В этом разделе нам нужно будет ответить на следующие вопросы:
#
# **_Сколько обычно занимает продажа?_**
#
# _**Когда считать, что продажи прошли очень быстро?**_
#
# **_Когда считать, что продажи прошли очень медленно?_**

# %% [markdown]
# #### Теория

# %% [markdown]
# <br><br>
# Прежде чем анализировать данные по продажам в файле, необходимо собрать статистику по продажам квартир.<br><br>
#
# <div>
#
# ![image.png](attachment:image.png)
#
# <p style="padding:90px; font-size: 16px;">Чтобы понять, сколько времени занимает сделка купли-продажи квартиры, нужно понимать из чего она состоит.<br><br>Причем, для Продавца и для Покупателя это могут быть разные сроки!<br><br><br><br>Если не вдаваясь в детали, то – от 5 рабочих дней до полугода могут идти продажи.<br><br><br><br>Ведь Продавец может выставить в продажу и рекламировать свою квартиру на протяжении нескольких месяцев, пока не найдется Покупатель.<br><br>А Покупатель, наоборот, может быстро выбрать и посмотреть несколько подходящих квартир и принять решение о покупке в течение считанных дней.<br><br><br><br>Вот и получается, что продолжительность срока продажи-покупки квартиры для них разная.
#
# [Источник](https://kvartira-bez-agenta.ru/melochi/skolko-vremeni-zanimaet-prodazha-kvartiry/)
#
# </p>
#
# <p>Отсюда выходят 2 гипотезы:
#
# **_Количество дней, которое указано в столбце `days_exposition`(сколько дней было размещено объявление (от публикации до снятия)) плюс дата объявления - `не гарантируют дату продажи квартиры`_**
#
# _**У любого сайта агрегатора по работе с недвижимостью есть `свои временные рамки хранения объявления`. А это значит, что снятие объявления с публикации - не равно продажа квартиры**_
#
# </p>
#
# <p>Посмотрим на эти сроки(ТОП-5):</p>

# %%
site_days_expirity = pd.DataFrame(
    [
        ['https://avito.ru',         '30 дней', 'https://support.avito.ru/articles/2157'],
        ['https://cian.ru',          '30 дней', 'https://cian.zendesk.com/hc/ru/articles/4407829378196-%D0%A1%D1%80%D0%BE%D0%BA-%D0%B1%D0%B5%D1%81%D0%BF%D0%BB%D0%B0%D1%82%D0%BD%D0%BE%D0%B3%D0%BE-%D0%BE%D0%B1%D1%8A%D1%8F%D0%B2%D0%BB%D0%B5%D0%BD%D0%B8%D1%8F'], 
        ['https://youla.ru',         '30 дней', 'https://help.mail.ru/legal/terms/youla/adpacks'],
        ['https://domclick.ru',      '90 дней', 'https://blog.domclick.ru/post/gde-razmestit-obyavlenie-o-prodazhe-nedvizhimosti-besplatno-i-effektivno'],
        ['https://realty.yandex.ru', '7, 30, 45, 60, 90 дней в зависимости от условий', 'https://yandex.ru/support/realty/owner/home/add-ads-housing.html'],
    ],
    columns=['Сайт','Срок','Ссылка на источник']
)

render(site_days_expirity, format=[
    [['Сайт'], ['link', '']],
    [['Ссылка на источник'], ['link', 'ссылка']]
])
# Out:
# <style  type="text/css" >
# </style><table id="T_ff983_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Сайт</th>        <th class="col_heading level0 col1" >Срок</th>        <th class="col_heading level0 col2" >Ссылка на источник</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ff983_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ff983_row0_col0" class="data row0 col0" ><a href="https://avito.ru" title="https://avito.ru">https://avito.ru</a></td>
#                         <td id="T_ff983_row0_col1" class="data row0 col1" >30 дней</td>
#                         <td id="T_ff983_row0_col2" class="data row0 col2" ><a href="https://support.avito.ru/articles/2157" title="ссылка">ссылка</a></td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# При анализе данных нужно учитывать этот фактор! А также необходимо уточнить у коллег, о данных в эти дни(<b>30, 45, 60, 90</b>)
#
# Возможно, в эти дни могут быть артефакты в данных. Из-за снятия объявления с публикации.
#
# Но эту гипотезу можем потвердить или опровергнуть, построив гистограмму

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Срок объявления

# %%
#срок объявления

column_name = 'days_exposition'
item_init = 'дн.'
item_type = 'срок объявления'

render('Столбец "{}" - сколько дней было размещено объявление (от публикации до снятия)'.format(column_name))

print("Рассмотрим медину, минимальное и максимальное значение")

render(data[column_name].describe())

cell_min =    data[column_name].min()
cell_max =    data[column_name].max()
cell_median = data[column_name].median()
cell_mean =   data[column_name].mean()

display(
    md(
        "_**Из таблицы видим, что есть слишком большое значение, которое скорее всего является ошибкой: <b>" + str(cell_max) + " " + item_init + "</b><br>"
        + "И слишком маленькое значение: <b>" + str(cell_min) + " " + item_init + "</b><br>"
        + "Необходимо построить график, чтобы понять сколько таких отклонений**_"
    )
)

#Построим график
(
    data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 30, range=(cell_min, cell_max))
)

plt.show()

print('По диаграмме видим распределение данных Пуассона')
print()
print()
print('Посмотрим на топ(10) количества объявлений по сроку объявлений')

render(data[column_name].value_counts(ascending=False).head(10))
# Out:
# <p class="value" ><code>Столбец "days_exposition" - сколько дней было размещено объявление (от публикации до снятия)</code></p>
# Рассмотрим медину, минимальное и максимальное значение
# <style  type="text/css" >
# </style><table id="T_7a243_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >days_exposition</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7a243_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_7a243_row0_col0" class="data row0 col0" >23699.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_7a243_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_7a243_row1_col0" class="data row1 col0" >156.608844</td>
#             </tr>
#             <tr>
# ...

# %%
display(
    md(
        "_**Из таблицы видим, что в топе находятся количество `0, 45, 60, 7, 30, 90 дней`.<br><br>"
        + "Как и говорили ранее, скорее всего это анамалии и их нужно убрать из рассчетов.<br><br>"
        + "Но на всякий случай посмотрим на эти данные**_"
    )
)

print('Уберем из диаграммы "нулевые" значения. Уменьшим range диаграммы до среднего значения:{} и увеличим размер корзины до 100'.format(cell_mean))

#Построим график
(
    data
        .query('0 < {} <= {}'.format(column_name, cell_mean))[column_name]
            .sort_values()
            .plot(y=column_name, kind = 'hist', bins = 100, range=(cell_min, cell_mean), grid=True)
)

plt.show()

print('Что и требовалось доказать, видим, что 45 и 60 выбиваются из общего котла и эти дни можно считать аномалиями')

print()

print('Посмотрим на данные при количестве срока объявления в 45 дней')

render(
    data
        .query('days_exposition == 45')
        .head(20)
    , name='Фрагмент данных при условии количества срока объявления в 45 дней'
)

print()

print()

print('Ничего подозрительного не обнаружил, по этому можно смело убирать эти данные из рассчетов, так как это аномалии')
# Out:
# _**Из таблицы видим, что в топе находятся количество `0, 45, 60, 7, 30, 90 дней`.<br><br>Как и говорили ранее, скорее всего это анамалии и их нужно убрать из рассчетов.<br><br>Но на всякий случай посмотрим на эти данные**_
# Уберем из диаграммы "нулевые" значения. Уменьшим range диаграммы до среднего значения:156.60884425503187 и увеличим размер корзины до 100
# Что и требовалось доказать, видим, что 45 и 60 выбиваются из общего котла и эти дни можно считать аномалиями
#
# Посмотрим на данные при количестве срока объявления в 45 дней
# <style  type="text/css" >
# ...

# %%
display(
    md(
        "_**Посмотрим на самые короткие и долгие продажи квартиры**_"
    )
)

plt.boxplot(
    data
        .query('{} != 0'.format(column_name))[column_name]
)

plt.ylim(1,cell_max)
plt.show()

render(
    data
        .query('{} != 0'.format(column_name))[column_name]
        .describe()
)

display(
    md(
        "**_Как мы видим межквартильный диапазон колеблится от `45 до 232 дней`, "
        + "однако, диаграмма размаха показывает нам нормальные значения до 500 дней<br><br>"
        + "Таким образом с учетом аномалий с текущими данными можно утверждать, "
        + "что нормальные значения лежат в диапазоне `от 1 до 500 дней`.<br><br>"
        + "Ранее мы обнаружили, что в данных есть аномалии при количествах дней `7, 30, 45, 60, 90`, <br>"
        + "а значит сейчас пока `данные неправильные`, но `они нам нужны`, когда будем сравнивать данные без аномалий_**"
    )
)
# Out:
# _**Посмотрим на самые короткие и долгие продажи квартиры**_
# <style  type="text/css" >
# </style><table id="T_28515_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >days_exposition</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_28515_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_28515_row0_col0" class="data row0 col0" >20518.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_28515_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_28515_row1_col0" class="data row1 col0" >180.888634</td>
#             </tr>
#             <tr>
#                         <th id="T_28515_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_28515_row2_col0" class="data row2 col0" >219.727988</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Вывод по срокам объявлений

# %%
display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "*` ` На вершине рейтинга преобладает количество дней, которые являются аномальными - `0, 7, 30, 45, 60, 90 дн.` и их нужно убрать из расчетов*<br>"
        + "*` ` С `неправильными данными` нормальные значения количества дней находятся в диапозоне `от 1 до 500 дн`*<br>"
        + '<div class="alert alert-danger">Необходимо посоветоваться с коллегами и уточнить, какие данные мы можем оставить, которые попадают в список дней аномалий</div>'
        + "**_"
    )
)
# Out:
# _**<b>Вывод:</b><br><br>*` ` В отчете срок объявления находится в пределах `от 0 дн. до 1580 дн.`, средняя - `156.60884425503187 дн.`, а медиана - `74.0 дн.`*<br>*` ` На вершине рейтинга преобладает количество дней, которые являются аномальными - `0, 7, 30, 45, 60, 90 дн.` и их нужно убрать из расчетов*<br>*` ` С `неправильными данными` нормальные значения количества дней находятся в диапозоне `от 1 до 500 дн`*<br><div class="alert alert-danger">Необходимо посоветоваться с коллегами и уточнить, какие данные мы можем оставить, которые попадают в список дней аномалий</div>**_

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ### Работаем с "хорошим" источником данных

# %% [markdown]
# #### Очистка от аномалий

# %%
column_name = 'days_exposition'
ignore_days_exposition = [0, 7, 30, 45, 60, 90]

good_data = (
    data
        .query('{} not in @ignore_days_exposition'.format(column_name))
)

print()
print('Убедимся, что нет аномальных дней')

render(
    good_data
        .query('{} == 45'.format(column_name))
        .head(10)
    , name='Фрагмент данных при условии количества дней объявлений в 45 дней'
)

print()
print()
print('Все впорядке!')
# Out:
# Убедимся, что нет аномальных дней
# <style  type="text/css" >
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Анализ данных без учета аномальных дней

# %%
column_name = 'days_exposition'
item_init = 'дн.'
item_type = 'срок объявления'

render(good_data[column_name].describe())

cell_min =    good_data[column_name].min()
cell_max =    good_data[column_name].max()
cell_median = good_data[column_name].median()
cell_mean =   good_data[column_name].mean()

display(
    md(
        "_**Из таблицы видим, что есть слишком большое значение, которое скорее всего является ошибкой: <b>" + str(cell_max) + " " + item_init + "</b><br>"
        + "И слишком маленькое значение: <b>" + str(cell_min) + " " + item_init + "</b><br>"
        + "Необходимо построить график, чтобы понять сколько таких отклонений**_"
    )
)

#Построим график
(
    good_data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 30, range=(cell_min, cell_max))
)
plt.show()

#Средние значения
(
    good_data[column_name]
        .sort_values()
        .plot(y=column_name, kind = 'hist', bins = 100, range=(cell_min, cell_mean))
)

plt.show()

print('Посмотрим на топ(10)  количества объявлений быстрых продаж')
render(good_data[column_name].value_counts(ascending=False).head(10))

print('Посмотрим на топ(10)  количества объявлений долгих продаж')
render(
    good_data[column_name]
        .value_counts()
        .sort_index(ascending=False)
        .sort_values(ascending=True)
        .head(10)
)

print('Посмотрим на диаграмму размаха')

plt.boxplot(good_data['days_exposition'])
plt.ylim(1,cell_max)
plt.show()

print("Размах стал от 1 до 600 дней, вместо 500 дней с аномалией" )
# Out:
# <style  type="text/css" >
# </style><table id="T_44284_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >days_exposition</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_44284_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_44284_row0_col0" class="data row0 col0" >18454.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_44284_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_44284_row1_col0" class="data row1 col0" >195.803349</td>
#             </tr>
#             <tr>
#                         <th id="T_44284_level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_44284_row2_col0" class="data row2 col0" >226.760010</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Выводы по измененным данным по сроку объявления без аномалий

# %%
column_name = 'days_exposition'

print('Сравним До и После')
render (
    pd.merge(
        data
            .query('{} != 0'.format(column_name))[column_name]
            .describe(),
        good_data[column_name].describe(),
        left_index=True, 
        right_index=True, 
        suffixes=(' С аномалиями', ' Без аномалий')
    )
)

display(
    md(
        "**_Показатели среднего значения и медианы без аномалий существенно изменились `195 и 114 соответственно`_**"
    )
)

print()
print()

display(
    md(
        "_**<b>Вывод:</b><br><br>"
        + "*` ` В отчете {} находится в пределах `от {} {} до {} {}`, средняя - `{} {}`, а медиана - `{} {}`*<br>".format(
            item_type, 
            
            cell_min, 
            item_init,
            
            cell_max, 
            item_init,
            
            cell_mean, 
            item_init, 
            
            cell_median, 
            item_init)
        + "*` ` Судя по рейтингу квартиру можно продать за самое короткое время в течении 3-4 дней - отличный показатель!*<br>"
        + "*` ` С `правильными данными` нормальные значения количества дней изменились с `от 1 до 500 дн` на  `от 1 до 600 дн`*<br>"
        + "*` ` Показатели среднего значения и медианы тоже изменились с `180/95` на `195/114` соответственно*<br>"
        + "**_"
    )
)
# Out:
# Сравним До и После
# <style  type="text/css" >
# </style><table id="T_afba6_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >days_exposition С аномалиями</th>        <th class="col_heading level0 col1" >days_exposition Без аномалий</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_afba6_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_afba6_row0_col0" class="data row0 col0" >20518.000000</td>
#                         <td id="T_afba6_row0_col1" class="data row0 col1" >18454.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_afba6_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_afba6_row1_col0" class="data row1 col0" >180.888634</td>
#                         <td id="T_afba6_row1_col1" class="data row1 col1" >195.803349</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ### Факторы, влияющие на стоимость квартиры

# %% [markdown]
# #### Зависимость цены квадратного метра от общей площади

# %%
index_name           = 'total_area'
title_parameter_name = 'Общая площадь'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = data.query('{} > 0'.format(index_name)).pivot_table(
                                                    index   = index_name, 
                                                    values  = column_name, 
                                                    aggfunc = agg_func_list
                                                )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['median'].median()
cell_mean =   pivot['median'].mean()


#Добавим в словарь
pivot_dict[index_name] = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_dict[index_name]
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)


print()

#Построим диаграмму
(
    pivot
        .query('count > 0')
        .plot(
            y='median', 
            style='o', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)



#Нарисуем диаграмму
plt.show()


#Проверим корреляцию
corr_value = data[index_name].corr(data[column_name])


#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "Корреляция Пирсона: `{}`. График говорит, что чем больше {}, тем чуть выше стоимость квартиры<br>**_".format(corr_value, title_parameter_name)
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_4263d_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'Общая площадь'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >total_area</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4263d_level0_row0" class="row_heading level0 row0" >900.0</th>
#                         <td id="T_4263d_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_4263d_row0_col1" class="data row0 col1" >466666.00</td>
#                         <td id="T_4263d_row0_col2" class="data row0 col2" >466666.00</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от количества комнат

# %%
index_name           = 'rooms'
title_parameter_name = 'Количество комнат'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = data.query('{} > 0'.format(index_name)).pivot_table(
                                                    index   = index_name, 
                                                    values  = column_name, 
                                                    aggfunc = agg_func_list
                                                )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['count'].median()
cell_mean =   pivot['count'].mean()


#Добавим в словарь
pivot_dict[index_name] = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_dict[index_name]
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)



print()

#Построим диаграмму
(
    pivot
        .query('count > 0')
        .plot(
            y='median', 
            style='o', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)


#Нарисуем диаграмму
plt.show()

print()
print('Диаграмма получилась не совсем информативная из-за точечных артефактов')
print()
print('Построим Диаграмму с количеством квартир, хотя бы больше 100 по каждому номеру количества комнат')
print()
print()

cell_max =    pivot.query('count > 100')['median'].max()

#Построим диаграмму
(
    pivot
        .query('count > 100')
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)


#Нарисуем диаграмму
plt.show()


#Проверим корреляцию
corr_value = data[index_name].corr(data[column_name])


#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "Корреляция Пирсона: `{}`. На графике мы видим, что чем больше {}, но не больше или ровно 3,тем меньше стоимость квартиры<br>".format(corr_value, title_parameter_name)
        + "Однако, с увеличением парметра {} от 3-ех стоимость квадратного метра увеличивается**_".format(title_parameter_name)
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_8918a_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'Количество комнат'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >rooms</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8918a_level0_row0" class="row_heading level0 row0" >19</th>
#                         <td id="T_8918a_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_8918a_row0_col1" class="data row0 col1" >86091.00</td>
#                         <td id="T_8918a_row0_col2" class="data row0 col2" >86091.00</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от этажа(первого или последнего)

# %%
index_name           = 'floor_category_name'
title_parameter_name = 'Категория этажа'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = data.query('{} != "Другой"'.format(index_name)).pivot_table(
                                                    index   = index_name, 
                                                    values  = column_name, 
                                                    aggfunc = agg_func_list
                                                )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['count'].median()
cell_mean =   pivot['count'].mean()


#Добавим в словарь
pivot_dict[index_name] = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_dict[index_name]
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)

print()

#Построим диаграмму
(
    pivot
        .query('count > 0')
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),
            grid=True
        )
)


#Нарисуем диаграмму
plt.show()


#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "По графику сложно сделать какой-то вывод<br>"
        + "Разве что квартиры на первом этаже дешевле квартир на последних этажах на <b>{:.2f} руб.</b>**_".format(pivot.loc['Последний','median'] - pivot.loc['Первый','median'])
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_775fa_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'Категория этажа'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >floor_category_name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_775fa_level0_row0" class="row_heading level0 row0" >Последний</th>
#                         <td id="T_775fa_row0_col0" class="data row0 col0" >3336</td>
#                         <td id="T_775fa_row0_col1" class="data row0 col1" >87777</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от удаленности от центра

# %%
index_name           = 'cityCenters_nearest'
title_parameter_name = 'Удаленность от центра'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = data.query('{} > 0'.format(index_name))


print()


#Построим диаграмму
ax = (
    pivot
        .plot(
            x=index_name,
            y=column_name,
            
            kind='scatter',
            
            style='o', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',
            
            ylim=(50000,650000),
            
            alpha=0.55,
            c=index_name,
            cmap="magma", 
            s=2,
            
            
            grid=True
        )
)


#Нарисуем диаграмму
plt.show()


#Проверим корреляцию
corr_value = data[index_name].corr(data[column_name])


#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "Корреляция Пирсона: `{:.2f}`<br>".format(corr_value)
        + "На графике видна очевидная зависимость стоимости квадратного метра от параметра {}<br>".format(title_parameter_name)
        + "График показывает, что чем ближе к центру, тем стоимость квартиры становится больше. Но это мы и так знали :-)</b>**_"
    )
)
# Out:
# _**<b>Вывод: </b><br>Корреляция Пирсона: `-0.32`<br>На графике видна очевидная зависимость стоимости квадратного метра от параметра Удаленность от центра<br>График показывает, что чем ближе к центру, тем стоимость квартиры становится больше. Но это мы и так знали :-)</b>**_

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от дня даты размещения объявления

# %%
index_name           = 'week_exposition'
title_parameter_name = 'День недели'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = data.pivot_table(
                index   = index_name, 
                values  = column_name, 
                aggfunc = agg_func_list
            )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['median'].median()
cell_mean =   pivot['median'].mean()


#Добавим в словарь
pivot_dict[index_name] = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_dict[index_name]
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)


print()

#Построим диаграмму
(
    pivot
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)



#Нарисуем диаграмму
plt.show()



#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "График показывает, что самую высокую цену выставляют в Понедельник и ближе к пятнице сумма уменьшается, а вот ближе к выходным сумма растет<br><br>"
        + "Такой показатель - скорее всего психологический фактор и зависит от индивидуального поведения человека<br><br>"
        + "У меня есть теория, что в пн человек максимально сосредоточен, а в пятницу уже либо уставший от недели, либо наоборот.<br>"
        + "А в выходные его ничего не беспокоит, он в расслабленном состоянии обсуждает покупку квартиры. Но это только теория<br><br>"
        + "Еще сводная таблица показывает, что в среду публикуется самое большое количество объявлений, а самое малое - в субботу**_"
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_4c48c_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'День недели'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >week_exposition</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c48c_level0_row0" class="row_heading level0 row0" >7.Воскресенье</th>
#                         <td id="T_4c48c_row0_col0" class="data row0 col0" >3612</td>
#                         <td id="T_4c48c_row0_col1" class="data row0 col1" >94688.00</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от месяца даты размещения  объявления

# %%
index_name           = 'month_exposition'
title_parameter_name = 'Месяц'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = data.pivot_table(
                index   = index_name, 
                values  = column_name, 
                aggfunc = agg_func_list
            )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['median'].median()
cell_mean =   pivot['median'].mean()


#Добавим в словарь
pivot_dict[index_name] = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_dict[index_name]
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)


print()

#Построим диаграмму
(
    pivot
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)



#Нарисуем диаграмму
plt.show()



#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "График  показывает, что в топе лидирует `Апрель, Август, Сентябрь`<br><br>"
        + "Самые низкие цены - `в Октябре, Мае и Июне`<br><br>"
        + "Такое впечатление, что эти месяца выпадают на месяца отпуска. Получается и здесь - человеческий фактор!<br>"
        + "С нового года все просыпаются, есть предложения, которые тянутся с осени, весной не выгодно, потому что активизируются все и застройщики и продавцы. Летом у всех отпуска, а ближе к осени, многие хотят, встретить новый год в новой квартире, + есть скидки<br><br>"
        + "Сводная таблица показывает, что в феврале публикуется объявлений больше.**_"
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_4fd9b_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'Месяц'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >month_exposition</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4fd9b_level0_row0" class="row_heading level0 row0" >12.Декабрь</th>
#                         <td id="T_4fd9b_row0_col0" class="data row0 col0" >1641</td>
#                         <td id="T_4fd9b_row0_col1" class="data row0 col1" >94262</td>
#                         <td id="T_4fd9b_row0_col2" class="data row0 col2" >99574.28</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от года даты размещения  объявления

# %%
index_name           = 'year_exposition'
title_parameter_name = 'Год'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = data.pivot_table(
                index   = index_name, 
                values  = column_name, 
                aggfunc = agg_func_list
            )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['median'].median()
cell_mean =   pivot['median'].mean()


#Добавим в словарь
pivot_dict[index_name] = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_dict[index_name]
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)


print()

#Построим диаграмму
(
    pivot
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)



#Нарисуем диаграмму
plt.show()



#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "График  показывает резкое снижение активности, скорее всего это связано с экономическим кризисом 2014 года<br><br>"
        + "На рынке недвижимости сокращение спроса, снижение темпов строительства, уменьшение рублевых цен.<br><br>"
        + "С 2015 года покупатели перестали рассматривать вторичную недвижимость, как средство накоплений.<br>"
        + "Во втором полугодии 2015-го уже отмечено резкое снижение средней цены 1 кв. м для поддержания (а в реальности — увеличения) темпов продаж.<br><br>"
        + "В экономике РФ в начале 2016 года продолжались кризисные явления, доллар вырос до 80 рублей. Но постепенно макроэкономическая ситуация стабилизировалась – во втором квартале и далее уменьшилась волатильность нефтяных цен и курса доллара к рублю.<br><br>"
        + "И с 2017 года начали строиться массово новые дома и появился резкий интерес у населения к новостройкам.<br><br>"
        + "Также силами экономических структур появились льготные программы, материнский капитал увеличился в 2 раза и составлял 450000рублей, который можно было внести за счет покупки квартиры**_"
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_e10e3_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'Год'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >year_exposition</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e10e3_level0_row0" class="row_heading level0 row0" >2019</th>
#                         <td id="T_e10e3_row0_col0" class="data row0 col0" >2879</td>
#                         <td id="T_e10e3_row0_col1" class="data row0 col1" >103305.00</td>
#                         <td id="T_e10e3_row0_col2" class="data row0 col2" >107123.33</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ### 10 населенных пунктов с наибольшим числом объявлений

# %%
index_name           = 'locality_name'
title_parameter_name = '10 населенных пунктов'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "{} с наибольшим числом объявлений".format(title_parameter_name)

#Сводная таблица
pivot = data.pivot_table(
                index   = index_name, 
                values  = column_name, 
                aggfunc = agg_func_list
            )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['median'].median()
cell_mean =   pivot['median'].mean()


#Вывод ТОП-10
pivot = pivot.sort_values('count', ascending=False).head(10)

render(
    pivot
    , name='ТОП 10: ' + title_name
    , format='{:.2f}'
)

pivot.plot(
    y='count', 
    ylabel='количество',
    
    title=title_name,
    
    kind='pie', 
    figsize=(16,16)
)

plt.show()

#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "Как и предполагалось, что лидером будет `город Санкт-Пербург` с количеством `15721 объявлений(66%)`<br><br>"
        + "А закрывать лучшую десятку будет `город Выборг` с результатом `237 объявлений(1%)`**_"
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_32d9a_" class="table_border position_center_header" data-title="ТОП 10: 10 населенных пунктов с наибольшим числом объявлений" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >locality_name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_32d9a_level0_row0" class="row_heading level0 row0" >Санкт-Петербург</th>
#                         <td id="T_32d9a_row0_col0" class="data row0 col0" >15721</td>
#                         <td id="T_32d9a_row0_col1" class="data row0 col1" >104761.00</td>
#                         <td id="T_32d9a_row0_col2" class="data row0 col2" >114848.57</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ### Зависимость цены квадратного метра от удаленности от центра в г. Санкт-Петербург

# %%
title_parameter_name = 'Удаленность от центра в городе Санкт-Петербург'
title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Создадим столбец, где будем хранить целые числа расстояния до центра в км

column_name    = 'cityCenters_nearest'
city_name      = 'Санкт-Петербург'
city_name_clmn = 'locality_name'

agg_func_list  = ['count', 'median', 'mean']

#del data['cityCenters_nearest_km']

#week_exposition
data.insert(
    data.columns.get_loc(column_name) + 1, 
    'cityCenters_nearest_km', 
    data[column_name]/1000
)


#Мы должны привести столбец к int, но напомню, что некоторые строки у нас не заполнены в cityCenters_nearest.
#Надо заменить пустые значения на какое-то большое число, чтобы его потом можно было не исполоьзовать в рассчетах
#Сомневаюсь, что в столбце будет число 1234567 его и заменим на пустоту
column_name = 'cityCenters_nearest_km'
exclude_km  = 1234567

data[column_name] = data[column_name].fillna(exclude_km)
data[column_name] = data[column_name].astype('int')

pivot = (
    data
        .query('{} == @city_name & {} != @exclude_km'.format(city_name_clmn, column_name))
        .pivot_table(
            index=column_name,
            values='price_square_meter',
            aggfunc=agg_func_list
        )
)

pivot.columns = agg_func_list

render(pivot.describe())


#Максимальное и минимальное значение медианы
cell_min =    pivot['mean'].min()
cell_max =    pivot['mean'].max()
cell_median = pivot['mean'].median()
cell_mean =   pivot['mean'].mean()


#Вывод ТОП-20
render(
    pivot
        .sort_values('mean', ascending=False)
        .head(20)
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)


print()

#Построим диаграмму
(
    pivot
        .plot(
            y='mean', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)



#Нарисуем диаграмму
plt.show()


print()


#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "Судя по графику из тех данных, что у нас есть, граница, где график меняется находится в диапазоне от 3 до 6 км<br><br>"
        + "В дальнейших рассчетах будем считать -> 3 км**_"
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_98d32_" class="table_border position_center_header"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_98d32_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_98d32_row0_col0" class="data row0 col0" >30.000000</td>
#                         <td id="T_98d32_row0_col1" class="data row0 col1" >30.000000</td>
#                         <td id="T_98d32_row0_col2" class="data row0 col2" >30.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_98d32_level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_98d32_row1_col0" class="data row1 col0" >522.000000</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ### Факторы, влияющие на стоимость квартиры в центре Санкт-Петербурга

# %% [markdown]
# #### Анализ данных

# %%
spb_center = (
    data
        .query('cityCenters_nearest_km <= 3 and locality_name == "Санкт-Петербург"')
)

render(spb_center.head())
spb_center.info()
# Out:
# <style  type="text/css" >
# #T_e519f_row0_col9,#T_e519f_row1_col9,#T_e519f_row1_col26,#T_e519f_row2_col9,#T_e519f_row2_col26,#T_e519f_row2_col28,#T_e519f_row4_col9,#T_e519f_row4_col26{
#             font-weight: bold;
#             text-transform:  capitalize;
#             color:  red;
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от общей площади в центре Санкт-Петербурга

# %%
index_name           = 'total_area'
title_parameter_name = 'Общая площадь'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = spb_center.query('{} > 0'.format(index_name)).pivot_table(
                                                    index   = index_name, 
                                                    values  = column_name, 
                                                    aggfunc = agg_func_list
                                                )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['median'].median()
cell_mean =   pivot['median'].mean()

pivot_temp = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_temp
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)


print()

#Построим диаграмму
(
    pivot
        .query('count > 0')
        .plot(
            y='median', 
            style='o', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)



#Нарисуем диаграмму
plt.show()


#Проверим корреляцию
corr_value = spb_center[index_name].corr(data[column_name])


#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "Корреляция Пирсона: `{}`. Видим, что максимальные значения площади меньше, чем в общем отчете<br>**_".format(corr_value, title_parameter_name)
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_771f2_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'Общая площадь'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >total_area</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_771f2_level0_row0" class="row_heading level0 row0" >517.0</th>
#                         <td id="T_771f2_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_771f2_row0_col1" class="data row0 col1" >96711.00</td>
#                         <td id="T_771f2_row0_col2" class="data row0 col2" >96711.00</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от количества комнат в центре Санкт-Петербурга

# %%
index_name           = 'rooms'
title_parameter_name = 'Количество комнат'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = spb_center.query('{} > 0'.format(index_name)).pivot_table(
                                                    index   = index_name, 
                                                    values  = column_name, 
                                                    aggfunc = agg_func_list
                                                )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['count'].median()
cell_mean =   pivot['count'].mean()


#Добавим в словарь
pivot_temp = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_temp
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)



print()

#Построим диаграмму
(
    pivot
        .query('count > 0')
        .plot(
            y='median', 
            style='o', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)


#Нарисуем диаграмму
plt.show()

print()
print('Диаграмма получилась не совсем информативная из-за точечных артефактов')
print()
print('Построим Диаграмму с количеством квартир, хотя бы больше 100 по каждому номеру количества комнат')
print()
print()

cell_max =    pivot.query('count > 100')['median'].max()

#Построим диаграмму
(
    pivot
        .query('count > 100')
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)


#Нарисуем диаграмму
plt.show()


#Проверим корреляцию
corr_value = spb_center[index_name].corr(data[column_name])


#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "Корреляция Пирсона: `{}`. Корреляция очень маленькая, возможно, как таковой связи нет между количеством комнат и ценой за квадратный метр в городе Санкт-Петербург, в отличии от общего отчета<br>".format(corr_value)
        + "Однако, если не учитывать маленький коэффициент корреляции, то можно было бы предположить, судя по графику, что чем больше комнат - тем меньше стоимость за квадратный метр, что является абсурдной гипотизой**_"
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_783f7_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'Количество комнат'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >rooms</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_783f7_level0_row0" class="row_heading level0 row0" >19</th>
#                         <td id="T_783f7_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_783f7_row0_col1" class="data row0 col1" >86091.00</td>
#                         <td id="T_783f7_row0_col2" class="data row0 col2" >86091.00</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от этажа(первого или последнего) в центре Санкт Петербурга

# %%
index_name           = 'floor_category_name'
title_parameter_name = 'Категория этажа'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = spb_center.query('{} != "Другой"'.format(index_name)).pivot_table(
                                                    index   = index_name, 
                                                    values  = column_name, 
                                                    aggfunc = agg_func_list
                                                )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['count'].median()
cell_mean =   pivot['count'].mean()


#Добавим в словарь
pivot_temp = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_temp
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)

print()

#Построим диаграмму
(
    pivot
        .query('count > 0')
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),
            grid=True
        )
)


#Нарисуем диаграмму
plt.show()


#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "По графику сложно сделать какой-то вывод<br>"
        + "Разве что квартиры на первом этаже дешевле квартир на последних этажах также, как и в общем отчете**_"
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_41a26_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'Категория этажа'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >floor_category_name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_41a26_level0_row0" class="row_heading level0 row0" >Последний</th>
#                         <td id="T_41a26_row0_col0" class="data row0 col0" >268</td>
#                         <td id="T_41a26_row0_col1" class="data row0 col1" >114432.00</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от удаленности от центра города Санкт-Петербург

# %%
index_name           = 'cityCenters_nearest'
title_parameter_name = 'Удаленность от центра'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = spb_center.query('{} > 0'.format(index_name))


print()


#Построим диаграмму
ax = (
    pivot
        .plot(
            x=index_name,
            y=column_name,
            
            kind='scatter',
            
            style='o', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',
            
            ylim=(50000,250000),
            
            alpha=0.55,
            c=index_name,
            cmap="magma", 
            s=2,
            
            
            grid=True
        )
)


#Нарисуем диаграмму
plt.show()


#Проверим корреляцию
corr_value = spb_center[index_name].corr(data[column_name])


#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "Корреляция Пирсона: `{:.2f}`<br>".format(corr_value)
        + "Так как мы и так взяли центр города, результат такой**_"
    )
)
# Out:
# _**<b>Вывод: </b><br>Корреляция Пирсона: `-0.16`<br>Так как мы и так взяли центр города, результат такой**_

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от дня даты размещения объявления в центре Санкт-Петербурга

# %%
index_name           = 'week_exposition'
title_parameter_name = 'День недели'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = spb_center.pivot_table(
                index   = index_name, 
                values  = column_name, 
                aggfunc = agg_func_list
            )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['median'].median()
cell_mean =   pivot['median'].mean()


#Добавим в словарь
pivot_temp = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_temp
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)


print()

#Построим диаграмму
(
    pivot
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)



#Нарисуем диаграмму
plt.show()



#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "График отличается от общей выборки<br><br>"
        + "'Видно в понедельник их мама родила...'<br><br>"
        + "Высокие цены ставим в центре Санкт-Петербурга `по пятницам и воскресениям`<br><br>"
        + "А вот низкие - `по понедельникам, в среду и в субботу`, видимо, со скидками :-)<br><br>"
        + "Еще сводная таблица показывает, что среда попрежнему фаворит по количеству объявлений, а по субботам люди отдыхают**_"
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_9ff44_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'День недели'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >week_exposition</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9ff44_level0_row0" class="row_heading level0 row0" >7.Воскресенье</th>
#                         <td id="T_9ff44_row0_col0" class="data row0 col0" >170</td>
#                         <td id="T_9ff44_row0_col1" class="data row0 col1" >121354.00</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от месяца даты размещения объявления в центре Санкт Петербурга

# %%
index_name           = 'month_exposition'
title_parameter_name = 'Месяц'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = spb_center.pivot_table(
                index   = index_name, 
                values  = column_name, 
                aggfunc = agg_func_list
            )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['median'].median()
cell_mean =   pivot['median'].mean()


#Добавим в словарь
pivot_temp = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_temp
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)


print()

#Построим диаграмму
(
    pivot
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)



#Нарисуем диаграмму
plt.show()



#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "График  показывает, что в топе лидирует `Апрель, Август, Сентябрь`<br><br>"
        + "Самые низкие цены - `в Октябре, Мае и Июне`<br><br>"
        + "График особо не изменился по сравнению с общей выборкой**_"
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_5d96a_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'Месяц'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >month_exposition</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5d96a_level0_row0" class="row_heading level0 row0" >12.Декабрь</th>
#                         <td id="T_5d96a_row0_col0" class="data row0 col0" >83</td>
#                         <td id="T_5d96a_row0_col1" class="data row0 col1" >121568.00</td>
#                         <td id="T_5d96a_row0_col2" class="data row0 col2" >162849.84</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# #### Зависимость цены квадратного метра от года даты размещения объявления в центре Санкт-Петербурга

# %%
index_name           = 'year_exposition'
title_parameter_name = 'Год'

column_name          = 'price_square_meter'
agg_func_list        = ['count', 'median', 'mean']

title_name           = "Зависимость цены квадратного метра от параметра '{}'".format(title_parameter_name)

#Сводная таблица
pivot = spb_center.pivot_table(
                index   = index_name, 
                values  = column_name, 
                aggfunc = agg_func_list
            )

#Заменим столбцы
pivot.columns = agg_func_list


#Максимальное и минимальное значение медианы
cell_min =    pivot['median'].min()
cell_max =    pivot['median'].max()
cell_median = pivot['median'].median()
cell_mean =   pivot['median'].mean()


#Добавим в словарь
pivot_temp = (
    pivot
        .sort_values('median', ascending=True)
        .sort_index(ascending=False)
        .head(20)
)

#Вывод ТОП-20
render(
    pivot_temp
    , name='ТОП 20: ' + title_name
    , format='{:.2f}'
)


print()

#Построим диаграмму
(
    pivot
        .plot(
            y='median', 
            style='o-', 
            figsize=(16,8),

            title=title_name, 

            xlabel=title_parameter_name, 
            ylabel='Сумма',

            ylim=(cell_min, cell_max),

            grid=True
        )
)



#Нарисуем диаграмму
plt.show()



#Вывод
display(
    md(
        "_**<b>Вывод: </b><br>"
        + "График  ничего нового не показал, разве что цены в периоде 2015-2018 росли очень медленно<br><br>**_"
    )
)
# Out:
# <style  type="text/css" >
# </style><table id="T_df378_" class="table_border position_center_header" data-title="ТОП 20: Зависимость цены квадратного метра от параметра 'Год'" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >mean</th>    </tr>    <tr>        <th class="index_name level0" >year_exposition</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_df378_level0_row0" class="row_heading level0 row0" >2019</th>
#                         <td id="T_df378_row0_col0" class="data row0 col0" >127</td>
#                         <td id="T_df378_row0_col1" class="data row0 col1" >131432</td>
#                         <td id="T_df378_row0_col2" class="data row0 col2" >173593.07</td>
# ...

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Исходный файл содержит ошибки и пропущенные строки, об этом нужно сказать коллегам!
#
# - Там, где можно было мы заменили значения и заполнили пустые строчки
# - Заменили тип данных в столбцах
# - Добавили новые столбцы
# - Из столбца с датой публикации, дату разделили на 3 столбца:
#     * День недели
#     * Месяц
#     * Год
# - Создали категорию для первого и последнего этажа
# - Сформировали графики и провели анализ по параметрам зависимости цены за метр квадратный, в зависимости от:
#     * общей площади
#     * количества комнат
#     * категории этажа
#     * удаленности от центра
#     * от дня недели
#     * от месяца
#     * от года
# - Такие же операции выполнили и с объявлениями в центре Санкт-Петербурга
#
# - При анализе данных по количеству дней с последней публикации мы обнаружили аномалии, о которых надо сообщить коллегам
# - Там же узнали, что нормальный диапазон данных должен варьироваться от 1 до 600 дней
#
# **_На стоимость огромное влияние оказывает количество комнат и удаленность от центра_**<br><br>
#
# _**Из-за того, что в России произошел кризис, на графике явно отразился всплеск в районе 2016-2017 года, по этому всплеску мы обнаружили среднее расстояние от центра города - 3км**_<br><br>

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод

# %% [markdown]
# <hr>
#
# [| Назад к содержанию](#Содержание)
